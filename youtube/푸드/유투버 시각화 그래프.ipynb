# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm            # 폰트 지정방법
font_name=fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()     
plt.rc('font',family=font_name)


mpl.rcParams['axes.unicode_minus']=False

# %%
youtuber=pd.read_csv('C:\\Users\\acorn\\mywork\\pythonwork\\푸드\\푸드유트버4.csv',encoding='cp949')
youtuber.set_index('유투버',inplace=True)
youtuber
# Out:
#                   구독자수      조회수합    조회수평균   댓글수합    댓글수평균     좋아요합     좋아요평균  \
# 유투버
# 01.백종원         4010000  12910000   645500  15226   761.30   219300  10965.00
# 02.떵개떵         3980000   6156000   307800  14071   703.55   149300   7465.00
# 03.문복희         3850000  45930000  2296500  60336  3016.80   971000  48550.00
# 04.하루한끼        3250000  34890000  1744500  50699  2534.95  1097000  54850.00
# 05.햄지          3220000  50520000  2526000  47371  2368.55  1042000  52100.00
# 06.쿠킹트리        3190000   4033000   201650   6810   340.50   204500  10225.00
# 07.FRAN        2830000   3390000   169500   5125   256.25    85600   4280.00
# 08.쯔양          2500000  24250000  1212500  36909  1845.45   402100  20105.00
# 09.유디티         2490000   5658000   282900   8388   419.40   156200   7810.00
# 10.한세          2410000  15320000   766000  14302   715.10   338800  16940.00
# 11.푸메          2350000  18410000   920500  20363  1018.15   422700  21135.00
# 12.꿀키          2130000   4600000   230000   4951   247.55   121500   6075.00
# 13.MINEE EATS  1670000   4320000   216000  17359   867.95   139300   6965.00
# 14.엠브로         1600000  10380000   519000  11447   572.35   148000   7400.00
# 15.나름          1580000  12220000   611000  64401  3220.05   257900  12895.00
# 16.아리키친        1390000   7243000   362150  15343   767.15   190000   9500.00
# 17.애주가         1270000  11246000   562300  14484   724.20    96200   4810.00
# 18.SOF         1060000    787000    39350   2963   148.15    14622    731.10
# 19.입짧은햇님       1050000   3102000   155100   3809   190.45    50300   2515.00
# 20.상윤쓰          952000  17140000   857000  79291  3964.55   435000  21750.00
# 21.야식이          896000   5294000   264700  12474   623.70   122000   6100.00
# 22.산적TV         853000   6530000   326500   8484   424.20    65200   3260.00
# 23.아내의식탁        828000   3135000   156750   2820   141.00    67264   3363.20
# 24.권회훈          694000    488000    24400   1736    86.80    11267    563.35
# 25.수빙수          676000  15860000   793000  47189  2359.45   335000  16750.00
# 26.먹어볼래         661000  10020000   501000  24268  1213.40   109300   5465.00
# 27.신쿡           597000   1364000    68200   3717   185.85    47132   2356.60
# 28.가르마          595000   2788000   139400   2985   149.25    58300   2915.00
# 29.시니           586000   3190000   159500   4076   203.80    65400   3270.00
# 30.맛상무          578000   2601000   130050   5784   289.20    32022   1601.10
#
#                 싫어요합    싫어요평균  영상길이합   영상길이평균
# 유투버
# 01.백종원          4958   247.90  13971   698.55
# 02.떵개떵          5803   290.15  15432   771.60
# 03.문복희         27929  1396.45  13747   687.35
# 04.하루한끼        17246   862.30   4245   212.25
# 05.햄지          35900  1795.00  14847   742.35
# 06.쿠킹트리         1258    62.90  10838   541.90
# 07.FRAN         6698   334.90  11061   553.05
# 08.쯔양          10202   510.10  16716   835.80
# 09.유디티          6372   318.60  17717   885.85
# 10.한세           4003   200.15   8911   445.55
# 11.푸메          15459   772.95  17118   855.90
# 12.꿀키           1373    68.65  12593   629.65
# 13.MINEE EATS   3447   172.35  12085   604.25
# 14.엠브로          5217   260.85  12825   641.25
# 15.나름           7144   357.20  15394   769.70
# 16.아리키친         2917   145.85  12166   608.30
# 17.애주가          4252   212.60  13182   659.10
# 18.SOF           810    40.50  13750   687.50
# 19.입짧은햇님        1490    74.50  45174  2258.70
# 20.상윤쓰         10120   506.00  12304   615.20
# 21.야식이          3181   159.05  20009  1000.45
# 22.산적TV         2659   132.95  14378   718.90
# 23.아내의식탁         929    46.45   9716   485.80
# 24.권회훈           608    30.40  12004   600.20
# 25.수빙수          6439   321.95  12765   638.25
# 26.먹어볼래         5759   287.95  10783   539.15
# 27.신쿡            999    49.95  13370   668.50
# 28.가르마          3081   154.05  16172   808.60
# 29.시니           1973    98.65  20484  1024.20
# 30.맛상무          1522    76.10  11793   589.65

# %%
youtuber.to_csv('푸트유트버5.csv',encoding='utf-8')

# %%
youtuber['구독자수'].plot(kind='bar')
#data_result['소계'].plot.bar()
#data_result['소계'].plot(kind='bar',figsize=(10,5),grid=True)    #grid =눈금, figsize=그래프크기?

# %%
youtuber['구독자수'].plot(kind='barh',figsize=(10,5),grid=True)

# %%
youtuber['구독자수'].sort_values().plot(kind='barh',figsize=(10,5),grid=True)

# %% [markdown]
# ### 조회수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['조회수평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['조회수평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [9.76200964e-01 1.23221086e+06]
#
# 0.9762 x + 1.232e+06

# %%
fx=np.linspace(0,2500000,1000)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['조회수평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['조회수평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 댓글수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['댓글수평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['댓글수평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [2.60695833e+02 1.52771741e+06]
#
# 260.7 x + 1.528e+06

# %%
fx=np.linspace(0,4000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['댓글수평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['댓글수평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 좋아요평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['좋아요평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['좋아요평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [4.42635277e+01 1.24161750e+06]
#
# 44.26 x + 1.242e+06

# %%
fx=np.linspace(0,60000,1000)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['좋아요평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')                

plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['좋아요평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 싫어요평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['싫어요평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['싫어요평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [   1529.87357255 1282218.02271738]
#
# 1530 x + 1.282e+06

# %%
fx=np.linspace(0,2000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['싫어요평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['싫어요평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 영상길이평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['영상길이평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['영상길이평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [-5.78163232e+02  2.21123166e+06]
#
# -578.2 x + 2.211e+06

# %%
fx=np.linspace(0,2000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['영상길이평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['영상길이평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# # 정규화

# %%
## Normalization (정규화) : MinMaxScaler() 

from sklearn import preprocessing         #sklearn 파이썬의 머신러닝 모듈

min_max_scaler = preprocessing.MinMaxScaler()

col1=['조회수평균','댓글수평균','좋아요평균','싫어요평균','영상길이평균','구독자수']
x=youtuber[col1].values
x


#정규화시키기        
x_scaled=min_max_scaler.fit_transform(x.astype(float))               #fit_transform 은 실수형태만 받는다. 
x_scaled
# Out:
# array([[0.2482811 , 0.17394107, 0.19160604, 0.1232574 , 0.23763102,
#         1.        ],
#        [0.1132875 , 0.15904842, 0.12713347, 0.1472005 , 0.27332698,
#         0.99125874],
#        [0.90825871, 0.75559281, 0.88394937, 0.77414145, 0.23215813,
#         0.95337995],
#        [0.68759994, 0.6313326 , 1.        , 0.47143829, 0.        ,
#         0.77855478],
#        [1.        , 0.58842112, 0.94934298, 1.        , 0.25903394,
#         0.76981352],
#        [0.07085465, 0.06542454, 0.1779747 , 0.01841777, 0.16108383,
#         0.76107226],
#        [0.05800288, 0.04369802, 0.06846343, 0.17256035, 0.16653229,
#         0.65617716],
#        [0.47493604, 0.45352331, 0.35997156, 0.27184631, 0.30469838,
#         0.56002331],
#        [0.10333387, 0.08577139, 0.13348862, 0.16332313, 0.32915537,
#         0.55710956],
#        [0.29645027, 0.16202695, 0.30166993, 0.09619744, 0.1140023 ,
#         0.53379953],
#        [0.35821075, 0.24017794, 0.37894492, 0.42080358, 0.31452027,
#         0.51631702],
#        [0.0821874 , 0.04145445, 0.10152864, 0.0216763 , 0.20396296,
#         0.45221445],
#        [0.07659098, 0.20144414, 0.1179231 , 0.08044316, 0.19155122,
#         0.31818182],
#        [0.19771346, 0.12521436, 0.12593612, 0.13059617, 0.20963131,
#         0.29778555],
#        [0.23448993, 0.80800722, 0.22715806, 0.18519778, 0.27239854,
#         0.29195804],
#        [0.13501359, 0.17544968, 0.16461966, 0.06542559, 0.19353026,
#         0.23659674],
#        [0.21502239, 0.16437367, 0.07822641, 0.10325286, 0.21835373,
#         0.2016317 ],
#        [0.00597618, 0.01582103, 0.00309008, 0.00572368, 0.23223143,
#         0.14044289],
#        [0.05224656, 0.02672942, 0.03595083, 0.0249915 , 1.        ,
#         0.13752914],
#        [0.33282699, 1.        , 0.39027367, 0.26952284, 0.19690195,
#         0.10897436],
#        [0.09605852, 0.13845658, 0.10198916, 0.07290604, 0.38515478,
#         0.09265734],
#        [0.12076271, 0.08700922, 0.04967428, 0.05811515, 0.24757507,
#         0.08012821],
#        [0.05290614, 0.01397718, 0.0515753 , 0.00909555, 0.1336705 ,
#         0.07284382],
#        [0.        , 0.        , 0.        , 0.        , 0.18957219,
#         0.03379953],
#        [0.30724336, 0.5860744 , 0.29816999, 0.16522158, 0.20816536,
#         0.02855478],
#        [0.19051807, 0.2905293 , 0.090292  , 0.14595376, 0.15974004,
#         0.02418415],
#        [0.01750879, 0.02554316, 0.03303298, 0.011079  , 0.22294705,
#         0.00553613],
#        [0.04597058, 0.0161047 , 0.04331912, 0.07007254, 0.29140707,
#         0.00495338],
#        [0.05400544, 0.03017214, 0.04985848, 0.03867732, 0.39676024,
#         0.002331  ],
#        [0.04223297, 0.05219522, 0.01911612, 0.02589822, 0.18441692,
#         0.        ]])

# %%
#정규화 시킨 후의 데이터프레임
youtuber2=pd.DataFrame(x_scaled,columns=col1,index=youtuber.index)
youtuber2
#youtuber2['구독자수']=youtuber['구독자수']
#youtuber2=youtuber2.round(3)
# Out:
#                   조회수평균     댓글수평균     좋아요평균     싫어요평균    영상길이평균      구독자수
# 유투버
# 01.백종원         0.248281  0.173941  0.191606  0.123257  0.237631  1.000000
# 02.떵개떵         0.113287  0.159048  0.127133  0.147200  0.273327  0.991259
# 03.문복희         0.908259  0.755593  0.883949  0.774141  0.232158  0.953380
# 04.하루한끼        0.687600  0.631333  1.000000  0.471438  0.000000  0.778555
# 05.햄지          1.000000  0.588421  0.949343  1.000000  0.259034  0.769814
# 06.쿠킹트리        0.070855  0.065425  0.177975  0.018418  0.161084  0.761072
# 07.FRAN        0.058003  0.043698  0.068463  0.172560  0.166532  0.656177
# 08.쯔양          0.474936  0.453523  0.359972  0.271846  0.304698  0.560023
# 09.유디티         0.103334  0.085771  0.133489  0.163323  0.329155  0.557110
# 10.한세          0.296450  0.162027  0.301670  0.096197  0.114002  0.533800
# 11.푸메          0.358211  0.240178  0.378945  0.420804  0.314520  0.516317
# 12.꿀키          0.082187  0.041454  0.101529  0.021676  0.203963  0.452214
# 13.MINEE EATS  0.076591  0.201444  0.117923  0.080443  0.191551  0.318182
# 14.엠브로         0.197713  0.125214  0.125936  0.130596  0.209631  0.297786
# 15.나름          0.234490  0.808007  0.227158  0.185198  0.272399  0.291958
# 16.아리키친        0.135014  0.175450  0.164620  0.065426  0.193530  0.236597
# 17.애주가         0.215022  0.164374  0.078226  0.103253  0.218354  0.201632
# 18.SOF         0.005976  0.015821  0.003090  0.005724  0.232231  0.140443
# 19.입짧은햇님       0.052247  0.026729  0.035951  0.024991  1.000000  0.137529
# 20.상윤쓰         0.332827  1.000000  0.390274  0.269523  0.196902  0.108974
# 21.야식이         0.096059  0.138457  0.101989  0.072906  0.385155  0.092657
# 22.산적TV        0.120763  0.087009  0.049674  0.058115  0.247575  0.080128
# 23.아내의식탁       0.052906  0.013977  0.051575  0.009096  0.133671  0.072844
# 24.권회훈         0.000000  0.000000  0.000000  0.000000  0.189572  0.033800
# 25.수빙수         0.307243  0.586074  0.298170  0.165222  0.208165  0.028555
# 26.먹어볼래        0.190518  0.290529  0.090292  0.145954  0.159740  0.024184
# 27.신쿡          0.017509  0.025543  0.033033  0.011079  0.222947  0.005536
# 28.가르마         0.045971  0.016105  0.043319  0.070073  0.291407  0.004953
# 29.시니          0.054005  0.030172  0.049858  0.038677  0.396760  0.002331
# 30.맛상무         0.042233  0.052195  0.019116  0.025898  0.184417  0.000000

# %%
## 지금까지 내용을 파일로 저장
youtuber2.to_csv('푸드유투버정규화.csv',encoding='utf-8',
                      sep=',')

# %%
sns.pairplot(youtuber2,vars=['구독자수','조회수평균','좋아요평균','댓글수평균'],size=4,kind='reg')   # kind='reg' -> 회귀선
# Out:
# C:\Users\acorn\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## 구독자수와 조회수, 좋아요수와 댓글수에 대한 상관관계

sns.pairplot(youtuber2,x_vars=['구독자수','조회수평균'],
            y_vars=['댓글수평균','좋아요평균'])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(youtuber2[['조회수평균','댓글수평균','좋아요평균','싫어요평균','영상길이평균']],
           annot=True,fmt='f',cmap='RdPu',linewidths=5)             #annot=     fmt=숫자표시     camp =색     linewidths=테두리 
plt.title('푸드유투브상관관계',size=20)
# Out:
# Text(0.5, 1, '푸드유투브상관관계')

# %% [markdown]
# ### 영상길이평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['영상길이평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber2['영상길이평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [-0.34475004  0.44012719]
#
# -0.3448 x + 0.4401

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['영상길이평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('영상길이평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('푸드유튜버 영상길이와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['영상길이평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 조회수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['조회수평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber2['조회수평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.71155721 0.19756124]
#
# 0.7116 x + 0.1976

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['조회수평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('조회수평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('푸드유튜버 조회수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['조회수평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 댓글수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['댓글수평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['댓글수평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.29455515 0.28331754]
#
# 0.2946 x + 0.2833

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['댓글수평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('댓글수평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('푸드유튜버 댓글수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['댓글수평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 좋아요수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['좋아요평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['좋아요평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.70015112 0.20062744]
#
# 0.7002 x + 0.2006

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['좋아요평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('좋아요평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('푸드유튜버 좋아요수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['좋아요평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 싫어요수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['싫어요평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['싫어요평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.78660108 0.21874306]
#
# 0.7866 x + 0.2187

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['싫어요평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('싫어요평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('푸드유튜버 싫어요수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['싫어요평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')
