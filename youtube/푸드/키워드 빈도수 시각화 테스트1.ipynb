# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import os
import glob
from pandas import DataFrame


import matplotlib as mpl
import matplotlib.pylab as plt

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
font_name = fm.FontProperties(fname = "C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc('font',family = font_name)

# %%
# r1 = pd.read_csv('dongjun_IT20/result.csv', index_col = '날짜')

# r1[r1["댓글"].str.contains("아이폰")]
# # r1["댓글"].str.contains("아이폰")
# Out:
#                           닉네임  \
# 날짜
# ['2020. 5. 21.']     jang2014
# ['2020. 5. 20.']         웰시코기
# ['2020. 5. 19.']          이승훈
# ['2020. 5. 19.']          전지훈
# ['2020. 5. 12.']         LHML
# ['2020. 5. 11.']          조예찬
# ['2020. 5. 11.']       놀공하는중2
# ['2020. 5. 5.']            시리
# ['2020. 5. 27.']           동키
# ['2020. 5. 27.']      0413박현진
# ['2020. 5. 26.']         RedF
# ['2020. 5. 26.']     Kodawary
# ['2020. 5. 26.']   ubisolanum
# ['2020. 5. 26.']           호오
# ['2020. 5. 26.']  JunSeokSung
# ['2020. 5. 26.']         할께없네
# ['2020. 5. 25.']          고현수
# ['2020. 5. 25.']          NaN
# ['2020. 5. 25.']         룰루랄라
# ['2020. 5. 25.']     Kodawary
# ['2020. 5. 25.']          순두부
# ['2020. 5. 24.']           민준
# ['2020. 5. 24.']    TeddyJeon
# ['2020. 5. 22.']           월리
# ['2020. 5. 22.']      이미지트레이닝
#
#                                                                  댓글 좋아요수
# 날짜
# ['2020. 5. 21.']            아이폰에 boe가 탑재되려면 애플의 검수를 통과해야함 탑재되도 걱정없음   1개
# ['2020. 5. 20.']  사진을 보고\n아이폰8 그리고 아이폰Se와 다른점은......\n거의 없습니다 다만...   1개
# ['2020. 5. 19.']                               아이폰SE 컬러 진짜 잘 빠졌ㅇㅓ요!   1개
# ['2020. 5. 19.']                    근데 아이폰 se중고로 판매할려면 언제 파는게 좋을까요?   1개
# ['2020. 5. 12.']  아이폰12pro정말 갖고싶다 아이폰답지않은 6기가 램에 128기가 부터 시작한다니 ...   1개
# ['2020. 5. 11.']        2:27 아이폰 11, 11pro, 11pro max 인치 오타 난 거 같아용   1개
# ['2020. 5. 11.']                           아이폰 se2로 아걸 보는 내 인생이 레전드   1개
# ['2020. 5. 5.']   민서야 내 아이폰 수리비 갚아라 산지 얼마 안 된 1개월 된 새삥 이였다 인간아 니...   0개
# ['2020. 5. 27.']  통화 녹음이랑 애플페이만 정말 된다면\n아이폰 안 쓸 이유가 없군요 \n만년 앱등이...   1개
# ['2020. 5. 27.']  그런데 아이폰 12 프로 맥스가 s20 울트라 카메라 \n보다 더 좋을까요?\n\n...   0개
# ['2020. 5. 26.']       아이폰 13 구성품=> 이어폰, 이어폰 커넥터, 아이폰 13 * 무선충전기 별매   3개
# ['2020. 5. 26.']  지금은 아이폰하고 에어팟이랑 아이패드프로 쓰고있어서 아이패드때문에 충전기가 하나 더...   3개
# ['2020. 5. 26.']                                          아이폰 Xr 오열   2개
# ['2020. 5. 26.']                   아이폰12와 갤럭시버즈X하고 \n만약 쓰면 괜찮을까요?ㅠㅠ   2개
# ['2020. 5. 26.']  아이폰 12프로에 스마트폰 최초로 10비트가 들어갈수 있다고 하네요 8비트는 현제 ...   2개
# ['2020. 5. 26.']  아이폰 이야기에서 삼성폰 물어봐서 죄송한데.. 삼성s10 이후부터 몇비트인가요? 아...   0개
# ['2020. 5. 25.']                                    저렇게 나오면 아이폰감 ㄹㅇ   2개
# ['2020. 5. 25.']  카툭튀 진짜 저정도로 두껍게 나오면 s21이랑 아이폰12랑 고민해보고 골라야겠다. ...   1개
# ['2020. 5. 25.']  항상 빠른소식 감사드려요. \n삼성만 써왔고, 그냥 노트12만 기다리는중이었는데, ...   1개
# ['2020. 5. 25.']  S20이랑 노트20 보니까 아이폰11 시리즈의 타피오카 발칸포가 선녀처럼 느껴지기 ...   1개
# ['2020. 5. 25.']  라이다 센서가 ar기술인데 이걸 아이패드에 적용해서 판매하고 있고, 아이폰12에도 ...   1개
# ['2020. 5. 24.']  ㅋㅋㅋㅋㅋㅋㅋㅋ 기본노트20가격이 아이폰12시리즈중 가장비싼 아이폰프로맥스 가격이랄...   3개
# ['2020. 5. 24.']                                           아이폰 사야겠다   3개
# ['2020. 5. 22.']                             아이폰에 소니센서는 원래 안들어갔었나요?   1개
# ['2020. 5. 22.']  아이폰 12는 boe display 아니고 max만 boe라던데 좀 다르게 적혀있네...   0개

# %%
# r1["count"] = r1["댓글"].str.contains("아이폰")
# r1
# Out:
#                          닉네임  \
# 날짜
# ['2020. 5. 31.']       노을빛창가
# ['2020. 5. 31.']  아름다운갤워치액티브
# ['2020. 5. 31.']        웰시코기
# ['2020. 5. 31.']          월리
# ['2020. 5. 31.']         이정호
# ...                      ...
# ['2020. 5. 22.']   109이승엽25번
# ['2020. 5. 22.']          월리
# ['2020. 5. 22.']   109이승엽25번
# ['2020. 5. 22.']    jang2014
# ['2020. 5. 22.']     이미지트레이닝
#
#                                                                  댓글 좋아요수  \
# 날짜
# ['2020. 5. 31.']                                        0:10 서티는 30   2개
# ['2020. 5. 31.']                                아냐 안찾았어 다시 들어가 내눈썩어   2개
# ['2020. 5. 31.']                             아 내누 아..내눈..아ㅏㅏㅏㅏㅏㅏ내눈!   1개
# ['2020. 5. 31.']                   13에서 포트 싹다 없앤다는 말이 계속 들려서 불안....   1개
# ['2020. 5. 31.']                              네이비블루 되게 고급스럽고 이쁜거같아용   1개
# ...                                                             ...  ...
# ['2020. 5. 22.']                                            까비...2빠   1개
# ['2020. 5. 22.']                             아이폰에 소니센서는 원래 안들어갔었나요?   1개
# ['2020. 5. 22.']                      일본,중국에서 만든 카메라여도 11보다는 좋은거겠죠?   1개
# ['2020. 5. 22.']                                                 1빠   1개
# ['2020. 5. 22.']  아이폰 12는 boe display 아니고 max만 boe라던데 좀 다르게 적혀있네...   0개
#
#                   count
# 날짜
# ['2020. 5. 31.']  False
# ['2020. 5. 31.']  False
# ['2020. 5. 31.']  False
# ['2020. 5. 31.']  False
# ['2020. 5. 31.']  False
# ...                 ...
# ['2020. 5. 22.']  False
# ['2020. 5. 22.']   True
# ['2020. 5. 22.']  False
# ['2020. 5. 22.']  False
# ['2020. 5. 22.']   True
#
# [213 rows x 4 columns]

# %%
# list1 = np.array(r1["댓글"].str.contains("아이폰"))
# list1*1
# r1["count2"] = list1*1
# r1
# Out:
#                          닉네임  \
# 날짜
# ['2020. 5. 31.']       노을빛창가
# ['2020. 5. 31.']  아름다운갤워치액티브
# ['2020. 5. 31.']        웰시코기
# ['2020. 5. 31.']          월리
# ['2020. 5. 31.']         이정호
# ...                      ...
# ['2020. 5. 22.']   109이승엽25번
# ['2020. 5. 22.']          월리
# ['2020. 5. 22.']   109이승엽25번
# ['2020. 5. 22.']    jang2014
# ['2020. 5. 22.']     이미지트레이닝
#
#                                                                  댓글 좋아요수  \
# 날짜
# ['2020. 5. 31.']                                        0:10 서티는 30   2개
# ['2020. 5. 31.']                                아냐 안찾았어 다시 들어가 내눈썩어   2개
# ['2020. 5. 31.']                             아 내누 아..내눈..아ㅏㅏㅏㅏㅏㅏ내눈!   1개
# ['2020. 5. 31.']                   13에서 포트 싹다 없앤다는 말이 계속 들려서 불안....   1개
# ['2020. 5. 31.']                              네이비블루 되게 고급스럽고 이쁜거같아용   1개
# ...                                                             ...  ...
# ['2020. 5. 22.']                                            까비...2빠   1개
# ['2020. 5. 22.']                             아이폰에 소니센서는 원래 안들어갔었나요?   1개
# ['2020. 5. 22.']                      일본,중국에서 만든 카메라여도 11보다는 좋은거겠죠?   1개
# ['2020. 5. 22.']                                                 1빠   1개
# ['2020. 5. 22.']  아이폰 12는 boe display 아니고 max만 boe라던데 좀 다르게 적혀있네...   0개
#
#                   count  count2
# 날짜
# ['2020. 5. 31.']  False       0
# ['2020. 5. 31.']  False       0
# ['2020. 5. 31.']  False       0
# ['2020. 5. 31.']  False       0
# ['2020. 5. 31.']  False       0
# ...                 ...     ...
# ['2020. 5. 22.']  False       0
# ['2020. 5. 22.']   True       1
# ['2020. 5. 22.']  False       0
# ['2020. 5. 22.']  False       0
# ['2020. 5. 22.']   True       1
#
# [213 rows x 5 columns]

# %%
pdf=r1.pivot_table("count2", "날짜", aggfunc="sum")
pdf
# Out:
#                   count2
# 날짜
# ['2020. 5. 1.']        0
# ['2020. 5. 11.']       2
# ['2020. 5. 12.']       1
# ['2020. 5. 14.']       0
# ['2020. 5. 19.']       2
# ['2020. 5. 20.']       1
# ['2020. 5. 21.']       1
# ['2020. 5. 22.']       2
# ['2020. 5. 24.']       2
# ['2020. 5. 25.']       5
# ['2020. 5. 26.']       6
# ['2020. 5. 27.']       2
# ['2020. 5. 28.']       0
# ['2020. 5. 3.']        0
# ['2020. 5. 31.']       0
# ['2020. 5. 5.']        1
# ['2020. 5. 8.']        0
# []                     0

# %%
# r1.pivot_table("count", "날짜", aggfunc="count")
# Out:
#                   count
# 날짜
# ['2020. 5. 1.']      10
# ['2020. 5. 11.']      7
# ['2020. 5. 12.']     13
# ['2020. 5. 14.']      7
# ['2020. 5. 19.']      7
# ['2020. 5. 20.']     11
# ['2020. 5. 21.']      8
# ['2020. 5. 22.']      5
# ['2020. 5. 24.']     10
# ['2020. 5. 25.']     31
# ['2020. 5. 26.']     19
# ['2020. 5. 27.']     24
# ['2020. 5. 28.']     10
# ['2020. 5. 3.']       9
# ['2020. 5. 31.']     10
# ['2020. 5. 5.']      10
# ['2020. 5. 8.']      12
# []                   10

# %%
ax = pdf.plot()

# ax.scatter(pdf["날짜"],pdf["count2"])
# ax.set_title("아이폰 빈도수")
# ax.set_xlabel("날짜")
# ax.set_ylabel("빈도수")

# %%
# df = pd.DataFrame(np.random.randint(low = -3, high =3, size = (3, 3)))


# df.loc[df[0] == 0, 'count'] = 0


# df['count'].fillna(1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc6dfc405080> in <module>
# ----> 1 df = pd.DataFrame(np.random.randint(low = -3, high =3, size = (3, 3)))
#       2
#       3
#       4 df.loc[df[0] == 0, 'count'] = 0
#       5
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # 여기부터가 시작 ~~~~~~~~

# %%
## 댓글 파일이 있는 유튜버만 만들어주세요.
df = pd.read_csv('푸드리스트.csv',encoding='cp949')
name_list = df['이름'].values
name_list
allData = []

for name in name_list:
     df = pd.read_csv(f'{name}/result.csv')
     allData.append(df)
      
dataCombine = pd.concat(allData,axis =0, ignore_index = True)
dataCombine.to_csv('test.csv', index = False, encoding = 'utf-8-sig')

# %%
testdf = pd.read_csv('test.csv')
real_date=[]
for i in testdf['날짜']:
    dd = datetime.strptime(i, '%Y. %m. %d.').date()
    real_date.append(dd)
real_date
testdf['날짜'] = real_date
testdf =testdf.set_index('날짜')



# testdf = pd.read_csv('test.csv',index_col = '날짜')
# testdf

# %%
list_ = np.array(testdf["댓글"].str.contains("김치"))
list_*1
testdf["count2"] = list_*1
testdf
# Out:
#                          닉네임  \
# 날짜
# 2020-06-02        VannieEats
# 2020-06-02         JanaSeada
# 2020-06-02    EnyuZeeMukbang
# 2020-06-02       아담Adam자취생먹방
# 2020-06-02               김구라
# ...                      ...
# 2020-05-18          MennaAli
# 2020-05-18             Lee나나
# 2020-05-18               정한별
# 2020-05-18            DooRee
# 2020-05-18  MuhdAzmiMohdZaki
#
#                                                            댓글 좋아요수  count2
# 날짜
# 2020-06-02  Noodles, egg, sausage and kimchi. This is the ...  28개       0
# 2020-06-02     Noddels egg  sausage  this is the perfect meal   4개       0
# 2020-06-02                   Fran is the queen of noodles! 😍🍜  34개       0
# 2020-06-02  짜파게티에 계란도 좋지만 전 저 소세지랑 조합이 진짜 좋을 거 같아요 ㅠㅠ 진짜 맛...  20개       0
# 2020-06-02                        짜파게티가 마르지 않고 촉촉해서 좋네요 후룩후루룩  17개       0
# ...                                                       ...  ...     ...
# 2020-05-18                                 Your so beautiful❤   0개       0
# 2020-05-18  햄지님 300만 축하드려요~^^🎁🎉🎉🎊 햄지님^~장점중 최강은 모든 구독자분들과^^...   1개       0
# 2020-05-18                 식용유 다써가서 삐귝삐슉 거리는거 ㄹㅇ현실적이여ㅠㅠㅠㅠ 사랑해   0개       0
# 2020-05-18  시작부터 한8분?까지 짜장이가 안보여서 다른방에서 자나?했는데 오른쪽 탁자아래 있었...   1개       0
# 2020-05-18  Hi hamzy....i just wanted to tell you that bef...   0개       0
#
# [63674 rows x 4 columns]

# %%
pdf=testdf.pivot_table("count2", "날짜", aggfunc="sum")
pdf
# Out:
#             count2
# 날짜
# 2020-04-01       0
# 2020-04-04       0
# 2020-04-05       1
# 2020-04-08       0
# 2020-04-09       0
# ...            ...
# 2020-06-05       0
# 2020-06-06       0
# 2020-06-07       0
# 2020-06-08       2
# 2020-06-09       3
#
# [66 rows x 1 columns]

# %%
# ['[\'2019. 12. 27.\']','[\'2020. 1. 23.\']','[\'2020. 5. 8.\']','[\'2020. 6. 2.\']']
ax = pdf.plot(figsize =(20,10))
ticks = list(pdf.index)
plt.xticks(ticks, rotation = 'vertical')
plt.xlabel('김치',size = 20)
plt.ylabel('키워드 빈도수',size = 20)
plt.title('\'김치\' 키워드 댓글 날짜별 빈도수',size =30)
# plt.savefig('불닭빈도수.png', dpi=300)
# Out:
# Text(0.5, 1.0, "'김치' 키워드 댓글 날짜별 빈도수")
