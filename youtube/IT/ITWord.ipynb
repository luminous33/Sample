# %%
from gensim.models.word2vec import Word2Vec
import ast
import pandas as pd
import logging
import time
import re     
#한글 형태소 분석기인 konlpy사용 
#이때 konlpy에는 hannanum, kommoran, kkma, twitter이 있는데 해당 분석에서는 kkma사용
from konlpy.tag import Kkma
from konlpy.tag import Mecab
from konlpy.tag import Twitter
#apply lambda사용

import time
#한글 형태소 분석기인 konlpy사용 
#이때 konlpy에는 hannanum, kommoran, kkma, twitter이 있는데 해당 분석에서는 kkma사용
#apply lambda사용
import squarify

# 참고 https://stackoverflow.com/questions/43776572/visualise-word2vec-generated-from-gensim
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
import gensim 
import gensim.models as g
import seaborn as sns
import matplotlib.font_manager as fm
from PIL import Image
from sklearn.cluster import KMeans
import nltk

font_name = fm.FontProperties(fname='C:/windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family =font_name)
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# %% [markdown]
# ## 트리맵 출력(word_to_vector과 관련없음)

# %%
squarify.plot(sizes=values, label=keys, alpha=.9,color = colors)
plt.axis('off')
fig = plt.gcf()
ax = fig.add_subplot()
fig.set_size_inches(15, 15)
plt.show()
plt.rc('font',size=25)
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
a= {'언니': 7444, '진짜': 4846, '영상': 3579,  '오늘': 1370, '보고': 1250, '사랑': 1098, '메이크업': 1025, '정말': 881, '항상': 772, '옷': 728, '피부': 720, '완전': 676, '생각': 651, '사람': 647, '화장': 600, '제품': 597, '느낌': 567, '이번': 495, '말': 485, '요즘': 478,'젤라': 458, '정보': 450, '대박': 440, '얼굴': 436, '그냥': 433,  '하나': 430, '머리': 419,'추천': 409}

# %%
values = a.values()
values
# Out:
# dict_values([7444, 4846, 3579, 1370, 1250, 1098, 1025, 881, 772, 728, 720, 676, 651, 647, 600, 597, 567, 495, 485, 478, 458, 450, 440, 436, 433, 430, 419, 409])

# %%
keys = a.keys()
keys
# Out:
# dict_keys(['언니', '진짜', '영상', '오늘', '보고', '사랑', '메이크업', '정말', '항상', '옷', '피부', '완전', '생각', '사람', '화장', '제품', '느낌', '이번', '말', '요즘', '젤라', '정보', '대박', '얼굴', '그냥', '하나', '머리', '추천'])

# %%
data = pd.DataFrame({'키워드':aa,'빈도수':bb})

# %%
aa=  list(keys)
bb = list(values)

# %%
dataGoals= data[data['빈도수']>500]
norm = mpl.colors.Normalize(vmin=min(dataGoals.빈도수), vmax=max(dataGoals.빈도수))
colors =  [mpl.cm.Blues(norm(value)) for value in dataGoals.빈도수]

# %%
norm = mpl.colors.Normalize(vmin=min(dataGoals.G), vmax=max(dataGoals.G))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9c488856e937> in <module>
# ----> 1 norm = mpl.colors.Normalize(vmin=min(dataGoals.G), vmax=max(dataGoals.G))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'G'

# %% [markdown]
# ## 여기부터 Word_To_Vector시작

# %%
df = pd.read_csv('IT리스트.csv',encoding='cp949')
name_list = df['이름'].values
name_list

All_file = []
for name in name_list:
# 각 이름에 맞는 info 파일 불러와서 데이터프레임에 저장
    df = pd.read_csv(f'{name}/result.csv')
    All_file.append(df)
    
    dataCombine = pd.concat(All_file,axis =0, ignore_index = True)

    dataCombine.to_csv('testword_IT.csv', index = False)

# %%
comment_data = pd.read_csv('testword_IT.csv')
comment_data
# Out:
#                 닉네임                                                 댓글 좋아요수  \
# 0               권현수  윈도우 홈피에서 '지금 업데이트'와 도구 다운로드 후 팝업창에서 나오는 ' 이 PC...   2개
# 1            OwenOh  설치 usb로 만들면 그 버전도 최신 2004 버전으로 만들어지는건가요? 아님 업데...   0개
# 2              cota  왜 업데이트가 안 될까 했는데 툴이 필요했군요. \n아직은 IE로 페이지사 열리는 ...   2개
# 3      luckyclassic          코타나 버튼 생겨서 한국어 지원하는줄 알았는데 그냥 버튼만 생긴거였네요ㅠㅠ   0개
# 4               조범준                참 잘나왔는데 skt한정으로만 나온게 너무나도 아쉬운 모델...   4개
# ...             ...                                                ...  ...
# 22748           윤지용                                  영태형 비데 공구는 다시 없나요   0개
# 22749         ChanP  화면전환이 전보다는 조금 줄어들긴 했지만 여전히 정신 없어요 ㅠ 화면전환이 많으면 ...   0개
# 22750           이영선                                영태형 안망하는거죠\n오래보고싶어요   0개
# 22751           키키짱  이번 리뷰에는 없지만 샤오미 구강세정기와 초음파 세척기 가지고 있어요. 강추합니다....   0개
# 22752           키키짱  초음파 구강세정기는 신제품같네요. 요 제품의 가장 큰 단점은 물을 사용하다보니 물이...   0개
#
#                  날짜
# 0       2020. 6. 2.
# 1       2020. 6. 2.
# 2       2020. 6. 2.
# 3       2020. 6. 2.
# 4      2020. 5. 13.
# ...             ...
# 22748   2020. 4. 6.
# 22749   2020. 4. 6.
# 22750   2020. 4. 6.
# 22751   2020. 4. 6.
# 22752   2020. 4. 6.
#
# [22753 rows x 4 columns]

# %%
#이모티콘 제거
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

#분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~,".\n\r#\ufeff\u200d]')

# %%
# 댓글만 출력해서 리스트에 저장
comment_list = []
for i in range(len(comment_data)):
    comment_list.append(comment_data['댓글'].iloc[i])
comment_result = []

# 토큰작업
for i in comment_list:
    tokens = re.sub(emoji_pattern,"",i)
    tokens = re.sub(han,"",tokens)
    comment_result.append(tokens)

comment_result = pd.DataFrame(comment_result, columns=["comment"])

# 댓글중에서 명사인 단어만 추출하는 함수생성
def get_noun(comment_txt):
    twitter = Twitter()
    noun = []
    
    if len(comment_txt)>0:
        tw = twitter.pos(comment_txt)
        for i,j in tw:
            if j == 'Noun':
                noun.append(i) #명사인 단어만 추출
    return noun
 
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
comment_result.head()
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
#                                              comment  \
# 0  윈도우 홈피에서 '지금 업데이트'와 도구 다운로드 후 팝업창에서 나오는 ' 이 PC...
# 1  설치 usb로 만들면 그 버전도 최신 2004 버전으로 만들어지는건가요 아님 업데이...
# 2  왜 업데이트가 안 될까 했는데 툴이 필요했군요 아직은 IE로 페이지사 열리는 경우가...
# 3            코타나 버튼 생겨서 한국어 지원하는줄 알았는데 그냥 버튼만 생긴거였네요
# 4                   참 잘나왔는데 skt한정으로만 나온게 너무나도 아쉬운 모델
#
#                                                token
# 0  [윈도우, 홈피, 지금, 업데이트, 도구, 다운로드, 후, 팝업창, 이, 를, 업그...
# 1  [설치, 로, 그, 버전, 최신, 버전, 가요, 업데이트, 버전, 가요, 현재, 제...
# 2  [왜, 업데이트, 안, 툴, 은, 로, 페이, 지사, 경우, 엣지, 구글드라이브, ...
# 3                          [코타, 버튼, 한국어, 지원, 그냥, 버튼]
# 4                                           [한정, 모델]

# %%
# Vec화 작업
vec = []
for i in range(len(comment_result)):
    vec2 = []
    tm_ls = comment_result['token'].iloc[i]
    if len(tm_ls) == 0: #비어있는 리스트 삭제
        pass
    else:
        for j in range(len(tm_ls)): #비어있지 않은 리스트 중에서 단어가 한 음절인 것은 pass
            if len(tm_ls[j]) > 1:
                vec2.append(tm_ls[j])
            else:
                pass
    if len(vec2) == 0:
        pass
    else:
        vec.append(vec2)
vec
# Out:
# [['윈도우', '홈피', '지금', '업데이트', '도구', '다운로드', '팝업창', '업그레이드', '차이점'],
#  ['설치',
#   '버전',
#   '최신',
#   '버전',
#   '가요',
#   '업데이트',
#   '버전',
#   '가요',
#   '현재',
#   '설치',
#   '버전',
#   '그것',
#   '최신',
#   '버전'],
#  ['업데이트',
#   '페이',
#   '지사',
#   '경우',
#   '엣지',
#   '구글드라이브',
#   '용량',
#   '영상',
#   '파일',
#   '아주',
#   '크롬',
#   '달리',
#   '업로드',
#   '마무리',
#   '다시',
#   '시작',
#   '업데이트',
#   '개선',
#   '제일',
#   '수도'],
#  ['코타', '버튼', '한국어', '지원', '그냥', '버튼'],
#  ['한정', '모델'],
#  ['혹시', '퀀텀', '강화유리', '리뷰', '가요'],
#  ['자급'],
#  ['타로', '화면', '영상'],
#  ['혹시'],
#  ['보안', '강화', '모델', '면서', '실사', '과정', '다만', '정말'],
#  ['퀀텀', '이름', '우리나라', '보안', '칩셋', '추가'],
#  ['무선', '충전', '방수', '방진', '패스'],
#  ['배경음악'],
#  ['요새', '가폰', '메인', '차이', '별로'],
#  ['갤럭시', '퀀텀', '보안', '위협', '보안', '혁신', '생각'],
#  ['지법', '뭔가', '발동'],
#  ['그냥', '자급', '제라'],
#  ['크기', '좀더'],
#  ['통신', '보안', '프로그램', '암호', '데이터', '강제', '추출'],
#  ['요금', '제만'],
#  ['양자',
#   '보안',
#   '기술',
#   '일부',
#   '기능',
#   '발동',
#   '다른',
#   '작업',
#   '삼성',
#   '녹스',
#   '안드로이드',
#   '샌드박스',
#   '의존',
#   '사실',
#   '실패',
#   '아이디어',
#   '방식',
#   '달라',
#   '취약'],
#  ['씨디', '리뷰', '일루', '선셋', '자급', '예약'],
#  ['디자인', '성능', '가격', '카메라', '쿼드덱', '구리', '듀얼', '스크린', '포함', '대체', '생각'],
#  ['역쉬', '씨디', '리뷰', '항상', '보고', '듀얼', '스크린', '컨셉', '디자인', '일체'],
#  ['디자인',
#   '정말',
#   '관심',
#   '반면',
#   '가격',
#   '때문',
#   '기능',
#   '대한',
#   '관심',
#   '체험',
#   '버벅임',
#   '정말',
#   '기능',
#   '가장',
#   '활용'],
#  ['사망', '망사'],
#  ['진짜', '가격'],
#  ['차포', '왕만', '장기판', '가요'],
#  ['씨디', '애기'],
#  ['갤럭시', '카메라'],
#  ['고정관념'],
#  ['조명', '때문', '런가', '사이드', '곡률', '조명', '계속'],
#  ['실물',
#   '외관',
#   '정도',
#   '장점',
#   '어차피',
#   '모바일',
#   '사업',
#   '부도',
#   '생각',
#   '그냥',
#   '플래그',
#   '시장',
#   '맞짱',
#   '출시',
#   '시점',
#   '최적화',
#   '제대로',
#   '점도'],
#  ['장가',
#   '실물',
#   '직접',
#   '보고',
#   '지고',
#   '보고',
#   '진짜',
#   '가격',
#   '때문',
#   '개인',
#   '생각',
#   '이나',
#   '와콤',
#   '지원',
#   '기능',
#   '스펙',
#   '보고',
#   '하니',
#   '아쉬움',
#   '가격',
#   '스냅',
#   '정도',
#   '은평',
#   '방정',
#   '도야',
#   '짐벌',
#   '얼마',
#   '커버',
#   '드덱',
#   '그거',
#   '요즘',
#   '누가',
#   '유선',
#   '쿼드덱',
#   '불구',
#   '유선',
#   '음질',
#   '쟁기',
#   '아무',
#   '모로',
#   '나라'],
#  ['전면', '카메라', '기능'],
#  ['엘지',
#   '유플러스',
#   '벨벳',
#   '구매',
#   '금제',
#   '기기',
#   '무료',
#   '할인',
#   '신청',
#   '피코',
#   '리얼',
#   '플러스',
#   '제품',
#   '휴대폰',
#   '직접',
#   '기기',
#   '벨벳',
#   '사용',
#   '보고',
#   '신청',
#   '처음',
#   '사전예약',
#   '이벤트',
#   '신청',
#   '페이지',
#   '보지',
#   '벨벳',
#   '유뿔',
#   '제공',
#   '컨텐츠',
#   '게임',
#   '이용',
#   '유의사항',
#   '문구',
#   '발견',
#   '갑자기',
#   '문구',
#   '추가',
#   '만약',
#   '갑자기',
#   '추가',
#   '라면',
#   '목적',
#   '벨벳',
#   '구매',
#   '사람',
#   '허위',
#   '광고',
#   '리뷰'],
#  ['사자'],
#  ['물방울', '노치'],
#  ['엣지', '크로미움', '기반', '기존'],
#  ['콜렉션', '기능', '정보', '페이지'],
#  ['하드웨어', '리뷰', '역시', '시디', '근본', '소프트웨어'],
#  ['크롬', '개선'],
#  ['기존', '엣지', '주로', '버전', '영상'],
#  ['크롬', '네이버', '웨일', '엣지', '네이버', '웨일', '비교', '엣지', '사용'],
#  ['덕분',
#   '프로그램',
#   '요즘',
#   '크롬',
#   '엣지',
#   '사양',
#   '데스크탑',
#   '체감',
#   '크게',
#   '사양',
#   '노트북',
#   '인터넷',
#   '서핑',
#   '문서',
#   '크롬',
#   '유튜브',
#   '구독'],
#  ['이제', '마이크로', '네이버', '웨일', '썻는데', '이제'],
#  ['진짜'],
#  ['영상', '바로', '설치', '사용', '있브니', '정보', '브라우저', '파이어폭스', '사용'],
#  ['설치', '크롬', '느낌', '계속', '사용', '정보'],
#  ['제일', '장점', '크롬', '용량', '점저', '때문', '크로미움', '엣지'],
#  ['정보'],
#  ['혹시', '실행', '가요', '크롬', '실행'],
#  ['엣지', '보고', '바로', '크롬'],
#  ['크롤', '위아래', '움직임', '크롬'],
#  ['다운로드', '표시', '몰입', '리더'],
#  ['생각', '마소', '크롬', '엣지', '업데이트', '하니', '마소', '엣지', '평이'],
#  ['쩐닷'],
#  ['네이버', '웨일', '비교', '가요'],
#  ['국산', '관공서', '사이트', '액티브엑스', '문제'],
#  ['번역', '기능', '메뉴', '어디', '설명'],
#  ['회사', '엣지', '사용', '크롬', '확실'],
#  ['아보'],
#  ['네이버',
#   '웨일',
#   '브라우저',
#   '유저',
#   '편의',
#   '기능',
#   '여러가지',
#   '국산',
#   '신분',
#   '웨일',
#   '브라우저',
#   '추천',
#   '드림'],
#  ['크롬', '가장'],
#  ['바로', '설치', '크롬', '인터넷', '그대로', '브라우저', '인터넷', '그대로'],
#  ['혹시', '추천', '모바일', '브라우저', '가요'],
#  ['크롬',
#   '대안',
#   '예전',
#   '브라우저',
#   '웨일',
#   '오페라',
#   '예전',
#   '스윙',
#   '별거',
#   '보고',
#   '경험',
#   '이번',
#   '의심',
#   '씨디',
#   '영상',
#   '이유',
#   '말씀',
#   '크롬',
#   '동기화',
#   '클릭',
#   '몇번',
#   '방금',
#   '기존',
#   '확장',
#   '익스',
#   '텐션',
#   '가장',
#   '이사',
#   '말씀',
#   '포멧',
#   '직후',
#   '누더기',
#   '체감',
#   '구형',
#   '노트북',
#   '체감',
#   '향상',
#   '테스트'],
#  ['바로', '설치', '정말', '세팅', '별로', '아이디', '마소', '껀데', '확장', '프로그램', '저절로'],
#  ['아이패드', '갤럭시', '에지', '아주'],
#  ['파폭', '비교'],
#  ['혹시', '브라우져', '비교', '영상'],
#  ['크롬', '소프트웨어', '리포트', '때매'],
#  ['엣지', '사용', '우선', '도면', '가장', '익스플로러', '크롬'],
#  ['네이버', '웨일', '브라우저'],
#  ['네이버', '웨일'],
#  ['익스플로러', '지원', '종료', '예전', '좀더', '업데이트'],
#  ['마침',
#   '크롬',
#   '엣지',
#   '브라우저',
#   '반정',
#   '거의',
#   '매일',
#   '바로',
#   '크롬',
#   '래시',
#   '프리징',
#   '버그',
#   '전혀',
#   '고요'],
#  ['크롬', '이유', '안드로이드', '호환', '공유', '문제', '무시', '그것'],
#  ['콜렉션'],
#  ['크롬', '크게', '보이', '그거'],
#  ['크로미움',
#   '엣지',
#   '즐겨찾기',
#   '드롭',
#   '기능',
#   '지원',
#   '안함',
#   '즐겨찾기',
#   '탐색기',
#   '편집',
#   '불가능',
#   '즐겨찾기',
#   '익스플로러',
#   '즐겨찾기',
#   '화면',
#   '고정',
#   '기능',
#   '삭제',
#   '컬렉션',
#   '기능'],
#  ['그냥', '웨일'],
#  ['마소', '브라우저', '도전', '마소', '브로', '이미지', '어낙', '크롬', '명성', '사실'],
#  ['버전', '스크린', '캡쳐', '기능', '사용', '기능', '가요'],
#  ['마소', '인수', '오픈소스', '대한', '자세'],
#  ['크롬', '기반', '역시', '웨일', '기능', '때문'],
#  ['엣지', '페이지', '게임', '실행', '그냥', '익스', '라우', '엣지', '가요'],
#  ['넷플릭스', '때문'],
#  ['호기심',
#   '엣지',
#   '애시',
#   '당초',
#   '크롬',
#   '대중',
#   '찬양',
#   '왤케',
#   '최근',
#   '정지',
#   '의문',
#   '지금',
#   '엣지',
#   '로써',
#   '아주',
#   '안나',
#   '듭니'],
#  ['크롬', '익스', '텐션', '사용'],
#  ['다음', '카페', '오류', '크롬'],
#  ['콜렉션', '진짜', '갠찮은거같', '크롬', '동기화', '문제'],
#  ['크롬', '처럼', '사용자', '추가', '기능'],
#  ['영상', '보고', '윈도우', '초기', '한번', '다운로드', '도중', '오류', '면서', '업데이트', '다시', '크롬'],
#  ['엣지',
#   '진작',
#   '점유',
#   '크롬',
#   '엣지',
#   '최근',
#   '기존',
#   '정보',
#   '전부',
#   '연동',
#   '불편',
#   '사용',
#   '중이',
#   '장점'],
#  ['크롬', '브라우저', '구글', '페이지', '바로가기', '방법', '엣지', '기능', '지원'],
#  ['크롬', '앱스토어', '확장', '프로그램', '사용'],
#  ['모바일'],
#  ['크롬', '사용', '확장', '프로그램', '그대로', '엣지', '사용', '자동', '동기화', '다시'],
#  ['엣지', '프릭스', '재생', '이건', '넷플릭스', '인정', '크로미움', '재생'],
#  ['기능', '장애인', '사람', '기능', '외국어', '공부', '외국어', '원서', '페이지', '기능', '주로', '사용'],
#  ['사실', '굳이', '느낌', '구글', '자체', '기능', '사람', '크롬'],
#  ['파폭', '네이버', '웨일'],
#  ['별로',
#   '사용',
#   '시작',
#   '지금',
#   '네이버',
#   '웨일',
#   '유튜브',
#   '볼때',
#   '웹서핑',
#   '웨일',
#   '뭔가',
#   '크롬',
#   '증상',
#   '익스플로러',
#   '증상',
#   '엣지',
#   '다운',
#   '웨일',
#   '기능',
#   '지금',
#   '아주',
#   '사용',
#   '진짜',
#   '추천'],
#  ['크롬', '이유', '크롬', '속도', '범용', '사후', '지원', '생각', '크롬', '구글', '느님', '사랑'],
#  ['업무'],
#  ['이틀',
#   '원거리',
#   '셋팅',
#   '주신',
#   '성심',
#   '감사',
#   '독자',
#   '배려',
#   '마음',
#   '감동',
#   '전자',
#   '젬병',
#   '영상',
#   '보고',
#   '진심',
#   '감사',
#   '꾸벅'],
#  ['크롬', '선호', '엣지', '성애자', '엣지'],
#  ['확장', '프로그램', '조건', '실험'],
#  ['혹시',
#   '서피스',
#   '엑스',
#   '윈도',
#   '계열',
#   '네이티',
#   '오페라',
#   '북마크',
#   '즐겨찾기',
#   '크롬북',
#   '마크',
#   '크롬',
#   '모바일',
#   '북마크',
#   '동기화',
#   '동기화',
#   '기존',
#   '한번',
#   '방법',
#   '무엇',
#   '모두',
#   '바이',
#   '필기',
#   '블릿',
#   '윈도',
#   '계열',
#   '필기',
#   '블릿',
#   '윈도',
#   '계열',
#   '필기',
#   '블릿',
#   '안드계열',
#   '동기화'],
#  ['보안', '문제'],
#  ['엣지',
#   '브라우저',
#   '거의',
#   '프로젝트',
#   '정도',
#   '유튜브',
#   '엣지',
#   '마소',
#   '회사',
#   '브라우저',
#   '개발',
#   '필요',
#   '오버'],
#  ['기존', '엣지', '사용'],
#  ['크롬', '확장', '프로그램', '기존', '넷플릭스', '고화질', '감상', '그대로'],
#  ['엣지',
#   '크롬',
#   '느낌',
#   '크로미움',
#   '기반',
#   '브라우저',
#   '유튜브',
#   '튕기',
#   '고질',
#   '문제',
#   '발생',
#   '파이어폭스',
#   '병행',
#   '유튜브',
#   '주로',
#   '파이어폭스',
#   '구글드라이브',
#   '부분',
#   '파폭',
#   '번역',
#   '확장',
#   '프로그램'],
#  ['기능', '선택', '탑재', '엣지'],
#  ['엣지', '모바일', '채터', '베이', '영상', '다시', '크롬'],
#  ['상단'],
#  ['맥북프로',
#   '넷플릭스',
#   '때문',
#   '크롬',
#   '엣지',
#   '넷플릭스',
#   '로그인',
#   '엣지',
#   '구글링',
#   '클리어',
#   '브라우징',
#   '데이터',
#   '레지스트리',
#   '설정',
#   '변경',
#   '상황',
#   '혹시',
#   '문제',
#   '해결'],
#  ['크롬', '프로그램', '흰색', '화면', '메뉴', '기능', '어플'],
#  ['기기',
#   '전송',
#   '구글',
#   '계정',
#   '통해',
#   '무선',
#   '전송',
#   '살짝',
#   '핀트',
#   '구글',
#   '기기',
#   '전송',
#   '미디어',
#   '캐스트',
#   '방식',
#   '아닐껍니'],
#  ['페이지', '메모리', '오히려', '엣지'],
#  ['기능',
#   '사용',
#   '시력',
#   '크롬',
#   '엣지',
#   '번갈아',
#   '사용',
#   '엣지',
#   '주기',
#   '다른',
#   '작업',
#   '놋북',
#   '이륙',
#   '소리',
#   '엣지',
#   '정도'],
#  ['기존',
#   '엣지',
#   '브라우저',
#   '경우',
#   '버벅일때',
#   '사용',
#   '엣지',
#   '브라우저',
#   '하니',
#   '기대',
#   '바로',
#   '사용'],
#  ['마나', '관건', '파이어폭스', '지금', '다량', '속도', '개빨', '엣지', '초창', '진짜', '상태'],
#  ['엣지',
#   '사용',
#   '크롬',
#   '다시',
#   '아보',
#   '신세계',
#   '엣지',
#   '크롬',
#   '수준',
#   '동기화',
#   '시간',
#   '윈도우',
#   '최적화',
#   '튕기기',
#   '느낌',
#   '결론',
#   '메리트',
#   '별로'],
#  ['브라우져',
#   '유튜브',
#   '영상',
#   '비교',
#   '경우',
#   '크롬',
#   '유튜브',
#   '영상',
#   '색영역',
#   '때문',
#   '크롬',
#   '플래그',
#   '설정',
#   '유튜브',
#   '인식',
#   '설정',
#   '영상',
#   '브라우져',
#   '기본',
#   '별도',
#   '설정',
#   '유튜브',
#   '영상',
#   '다른',
#   '브라우져',
#   '영상',
#   '항상',
#   '보고'],
#  ['애드가드',
#   '광고',
#   '제거',
#   '확장',
#   '프로그램',
#   '동작',
#   '크롬',
#   '다시',
#   '검색',
#   '네이버',
#   '혹시',
#   '설정',
#   '방법'],
#  ['씨디',
#   '바로',
#   '브라우저',
#   '북마크',
#   '동기화',
#   '기능',
#   '은행',
#   '업무',
#   '디자인',
#   '심플',
#   '최고',
#   '브라우저',
#   '생각'],
#  ['정보',
#   '엣지',
#   '브라우저',
#   '설치',
#   '문제점',
#   '유투브',
#   '코멘트',
#   '전혀',
#   '무한대',
#   '로딩',
#   '네이버',
#   '아예',
#   '브라우저',
#   '셋팅',
#   '문제',
#   '군데',
#   '다만',
#   '말씀',
#   '유투브',
#   '동영상',
#   '자체',
#   '아주'],
#  ['크롬'],
#  ['속도',
#   '거의',
#   '단지',
#   '플라시보',
#   '어차피',
#   '크로미움',
#   '기반',
#   '브라우져',
#   '브라우저',
#   '가장',
#   '핵심',
#   '엔진',
#   '자바스크립트',
#   '가지',
#   '단지',
#   '그냥',
#   '편의',
#   '위주',
#   '기존',
#   '엣지',
#   '어차피',
#   '차크라',
#   '기반',
#   '때문',
#   '크롬',
#   '속도',
#   '차이',
#   '이구',
#   '크롬',
#   '바로',
#   '사이트',
#   '비밀번호',
#   '자동',
#   '기억',
#   '때문',
#   '컬렉션',
#   '기능',
#   '사이트',
#   '대해',
#   '일일이',
#   '모든',
#   '비번',
#   '기억',
#   '크롬',
#   '비번',
#   '기능',
#   '사람',
#   '다른',
#   '브라우저',
#   '이용',
#   '확장',
#   '프로그램',
#   '오페',
#   '크롬',
#   '확장',
#   '플러그인',
#   '엣지',
#   '그게',
#   '확장',
#   '프로그램',
#   '갯수',
#   '차이',
#   '넘사벽'],
#  ['크롬', '웨일', '브라우저', '왜캐', '메모리', '개정', '부분', '관리'],
#  ['엣지',
#   '크롬',
#   '네이버',
#   '웨일',
#   '크로미움',
#   '엔진',
#   '기반',
#   '확장',
#   '프로그램',
#   '기능',
#   '비교',
#   '퍼포먼스',
#   '차이',
#   '별로',
#   '기존',
#   '내부',
#   '기록',
#   '데이터',
#   '거지',
#   '브라우저',
#   '마다',
#   '다른',
#   '엔진',
#   '그게',
#   '엔진',
#   '비교',
#   '포멧',
#   '컴퓨터',
#   '한번',
#   '사용',
#   '브라우저',
#   '개별',
#   '객관',
#   '테스트',
#   '크게',
#   '메리트',
#   '각자'],
#  ['그냥', '웨일즈', '최고'],
#  ['엣지',
#   '찬양',
#   '미디어',
#   '글쎄요',
#   '과연',
#   '무슨',
#   '기준',
#   '엣지',
#   '무진장',
#   '리소스',
#   '활동',
#   '무엇',
#   '다운로드',
#   '속도',
#   '엣지',
#   '장점',
#   '보안',
#   '빵점',
#   '마이너스'],
#  ['엣지', '유튜브', '광제', '제거', '광거', '제거', '그냥', '크롭'],
#  ['외국어',
#   '번역',
#   '경우',
#   '크롬',
#   '번역',
#   '원문',
#   '다시',
#   '번역',
#   '문제',
#   '엣지',
#   '번역',
#   '해당',
#   '화면',
#   '번역',
#   '아래',
#   '크롤',
#   '경우',
#   '종종',
#   '원문',
#   '다시',
#   '번역',
#   '거의',
#   '확률',
#   '해당',
#   '화면',
#   '분량',
#   '번역',
#   '거나',
#   '번역',
#   '자체',
#   '번역',
#   '증상',
#   '로드',
#   '다시',
#   '한번',
#   '한해',
#   '정상',
#   '작동',
#   '엣지',
#   '크롬',
#   '부분',
#   '버그',
#   '안정',
#   '크롬',
#   '예전',
#   '이야기',
#   '요즘',
#   '확장',
#   '프로그램',
#   '설치',
#   '점점',
#   '무거워',
#   '요즘',
#   '번역',
#   '파이어폭스',
#   '위주'],
#  ['환기', '능이', '그냥', '혹시', '다시', '크롬', '갈렵니', '속도', '그다지'],
#  ['크로미움',
#   '엣지',
#   '처음',
#   '베타',
#   '금지',
#   '회사',
#   '피씨',
#   '설치',
#   '크롬',
#   '제거',
#   '사용',
#   '크롬',
#   '확장',
#   '프로그램',
#   '그대로',
#   '사용',
#   '장점',
#   '단점',
#   '새탭',
#   '경우',
#   '페이지',
#   '구글'],
#  ['기능', '다른', '브라우저', '기본', '기능', '거의', '사랑', '대한민국', '사람'],
#  ['서버', '관리'],
#  ['사이즈'],
#  ['가격', '검색', '훌쩍', '케이스', '선호', '공간활용', '사양', '데스크탑'],
#  ['미니', '컴퓨터', '미니', '제온'],
#  ['쿼드로', '벽돌', '인코딩', '필요', '조텍'],
#  ['씨디', '제도', '수도', '오늘', '하루'],
#  ['예전', '한창', '미니', '요즘', '생각', '괴물'],
#  ['미니', '완전', '끝판', '쿼드로', '처음', '가격'],
#  ['제온', '프로세서', '쿼드로', '그래픽카드', '전문', '분야', '사용', '제품', '사이즈', '케이스'],
#  ['미니', '어디', '구입', '아마존'],
#  ['나이스'],
#  ['씨디', '다음', '미니', '배그'],
#  ['쩐다', '거가', '지고', '게임', '영상편집', '대박'],
#  ['여기', '왼쪽', '멀티탭', '무슨', '제품'],
#  ['미니', '리기', '소음'],
#  ['여사', '랩톱', '시장'],
#  ['씨디', '플루', '니블', '플루', '선팬', '소통', '자주', '플루', '응원'],
#  ['어댑터', '내장'],
#  ['타입',
#   '포트',
#   '입력',
#   '제한',
#   '때문',
#   '더블',
#   '태양',
#   '패널',
#   '경우',
#   '별도',
#   '포트',
#   '노트북',
#   '야외',
#   '사용',
#   '지금',
#   '소개',
#   '모델',
#   '사용',
#   '태양',
#   '패널',
#   '타입',
#   '리도',
#   '태양광',
#   '구름',
#   '마찬가지',
#   '배터리',
#   '야외',
#   '사용'],
#  ['마음', '드네'],
#  ['산티', '순례', '장시간', '이동해', '상황', '이면'],
#  ['실제',
#   '출력',
#   '포트',
#   '정도',
#   '효율',
#   '야외',
#   '캠핑',
#   '팩킹시',
#   '보조',
#   '배터리',
#   '충전',
#   '요긴',
#   '사용'],
#  ['출력', '정도'],
#  ['리뷰', '보고', '링크', '구매', '다른', '제품', '취소', '체크카드', '환불', '한참'],
#  ['배낭여행', '태양열', '충전'],
#  ['동차', '캠핑'],
#  ['노트북', '보조', '배터리', '정도', '제품', '추천', '중국', '직구', '제품', '보고', '고장', '소문'],
#  ['얼마나', '보조', '배터리', '기준', '시간', '충전', '이야기'],
#  ['제품', '구매', '링크'],
#  ['가성', '제품', '리뷰'],
#  ['다시', '진짜', '마음', '드네'],
#  ['리뷰', '정말', '필요'],
#  ['샤오미', '미지', '센서'],
#  ['개꿀템'],
#  ['부담', '가격', '제방', '하나'],
#  ['트렁크'],
#  ['제품', '링크', '어디', '영상', '매번', '씨디'],
#  ['현관문', '출입', '센서', '사용', '센싱', '문제', '천정', '센서', '대체', '생각', '천정', '센싱'],
#  ['타입', '이면', '구매'],
#  ['충전', '자석', '부착', '점도', '사용', '모드', '설정', '활용'],
#  ['댓글', '씨디'],
#  ['실용', '정보'],
#  ['가격', '생각'],
#  ['제품', '소개', '용도', '가격', '개인', '기준', '조금', '혹시', '접지', '케이블', '하나', '추천'],
#  ['제품', '케이블', '전원', '디스플레이', '문제'],
#  ['모니터', '연결', '사람', '이면', '가격', '싸넴'],
#  ['맥북', '인치', '외부', '모니터', '유튜브', '계속', '원래'],
#  ['모니터', '접지', '연결', '기기', '접지', '처음', '접지', '정말', '접지', '제품'],
#  ['마이크', '탈착', '사용', '주변', '소리', '듣기', '기능', '무선', '사용', '정말'],
#  ['마이크', '분리'],
#  ['기가바이트', '워터', '포스', '그래픽카드', '구매', '소음', '성능', '익스트림', '비교', '게임위', '주로'],
#  ['씨디',
#   '그동안',
#   '울트라',
#   '와이드',
#   '모니터',
#   '리뷰',
#   '자주',
#   '화면',
#   '인치',
#   '인치',
#   '그냥',
#   '일반',
#   '모니터',
#   '울트라',
#   '와이드',
#   '이유',
#   '게임',
#   '영상편집',
#   '따로따로',
#   '가요',
#   '영상',
#   '모니터',
#   '인치',
#   '해상도',
#   '지금',
#   '울트라',
#   '와이드',
#   '인치',
#   '인치',
#   '판단'],
#  ['성능',
#   '정말',
#   '가격',
#   '대비',
#   '거리',
#   '신호',
#   '강력',
#   '한편',
#   '역시',
#   '중국',
#   '수용',
#   '설정',
#   '국내',
#   '정식',
#   '출시'],
#  ['어우', '안테나', '안테나'],
#  ['안테나'],
#  ['가격'],
#  ['샤오미', '중국', '정부', '중국', '제품'],
#  ['동안', '문제', '우리동네', '기가랜'],
#  ['안테나', '방법'],
#  ['사용', '방법', '해당', '제품', '사용'],
#  ['가로',
#   '사이즈',
#   '다소',
#   '슬림',
#   '부분',
#   '커버',
#   '지원',
#   '무선',
#   '범위',
#   '커버',
#   '점수',
#   '제품',
#   '다만',
#   '요즘',
#   '기기',
#   '다국어',
#   '지원이',
#   '기본',
#   '샤오미',
#   '직구',
#   '부분',
#   '이군'],
#  ['정보', '정보', '팔고', '문제'],
#  ['개인정보', '공유'],
#  ['카페', '가게', '공유', '와이파이', '정도', '성능', '어디'],
#  ['광랜', '사용', '중이', '공유기', '사도', '체감'],
#  ['화웨이', '나왓', '던데', '화웨이', '공유기', '국내', '사용'],
#  ['와이파이',
#   '지원',
#   '공유기',
#   '제일',
#   '티피',
#   '링크',
#   '공유기',
#   '사용',
#   '시간',
#   '간격',
#   '와이파이',
#   '서재',
#   '접속',
#   '스트레스'],
#  ['사용', '링크', '스마트', '스위치', '태깅', '수행', '사용', '스위치'],
#  ['중국', '전자제품', '사기', '통신', '장비'],
#  ['카페', '사용', '샤오미', '공유기', '가정'],
#  ['중국', '수용', '제품', '수용', '제품', '벡도어', '생각', '비정상'],
#  ['기기', '인터넷', '지원', '환경'],
#  ['규격', '대부분', '미원', '기기', '후기', '지원', '안해', '사용', '사람'],
#  ['중국', '통신', '제품', '전부', '중국', '해킹', '백도'],
#  ['백도어',
#   '치구',
#   '전파',
#   '사용',
#   '하나',
#   '보급',
#   '한참',
#   '계통',
#   '내부',
#   '통신',
#   '규격',
#   '정보',
#   '약간',
#   '정도',
#   '삼성',
#   '로미',
#   '규격',
#   '약간',
#   '수준',
#   '기능',
#   '최신',
#   '기술',
#   '가성',
#   '차라리',
#   '요즘',
#   '파워',
#   '라즈베리파이',
#   '사서',
#   '모드',
#   '자작',
#   '멩그는',
#   '라즈베리파이',
#   '기본',
#   '스타터킷',
#   '베이직',
#   '겨우',
#   '한번',
#   '라즈베리파이',
#   '자작나스',
#   '멩그는법즘',
#   '리뷰'],
#  ['가성', '진짜', '중국', '제라', '네트워크', '라우터', '보안', '때문'],
#  ['영상',
#   '논외',
#   '공유기',
#   '로지',
#   '베이',
#   '아마존',
#   '직구',
#   '출하',
#   '영상',
#   '요즘',
#   '스트리밍',
#   '사이트',
#   '영상',
#   '넷플릭스',
#   '왓챠',
#   '유튜브',
#   '프리미엄',
#   '웨이브',
#   '티빙',
#   '고정',
#   '정액',
#   '비만',
#   '해도',
#   '무시',
#   '지경'],
#  ['이제', '중국', '선전'],
#  ['공유기',
#   '필요',
#   '보통',
#   '통신사',
#   '기본',
#   '모뎀',
#   '연결',
#   '포트',
#   '바로',
#   '셋톱',
#   '포트',
#   '공유기',
#   '공유기',
#   '선입견',
#   '공유기',
#   '속도',
#   '체크',
#   '기본',
#   '공유기',
#   '보안',
#   '설정',
#   '비번',
#   '속도',
#   '의미',
#   '각종',
#   '해킹',
#   '보안',
#   '설정',
#   '약간',
#   '속도',
#   '저하',
#   '보통',
#   '이기',
#   '때문',
#   '가전제품',
#   '전기',
#   '속도',
#   '무의미',
#   '보안',
#   '설정',
#   '풀로',
#   '제품'],
#  ['가량',
#   '사용',
#   '무선',
#   '최근',
#   '유선랜',
#   '문제',
#   '교체',
#   '생각',
#   '씨디',
#   '보급',
#   '부터',
#   '하이',
#   '앤드',
#   '제품',
#   '두루',
#   '사용',
#   '지도',
#   '사용',
#   '질문',
#   '기존',
#   '로지',
#   '외부',
#   '접속',
#   '미지',
#   '포트',
#   '포워딩',
#   '아이피',
#   '고정',
#   '기능',
#   '작동',
#   '트래픽',
#   '파일',
#   '다운로드',
#   '고화질',
#   '영상',
#   '시청',
#   '로지',
#   '외부',
#   '접속',
#   '사용',
#   '부하',
#   '공유기',
#   '핸들링',
#   '궁금',
#   '스트레스'],
#  ['백도어', '이제', '중국산', '통신', '기기', '라면'],
#  ['샤오미', '사지'],
#  ['디자인', '일반', '윈도우', '마음', '버전', '윈도우', '때문'],
#  ['서피스'],
#  ['리뷰', '감사'],
#  ['리뷰', '금방'],
#  ['저런', '테블릿'],
#  ['혹시', '리그', '오브', '레전드', '롤토', '체스'],
#  ['프로세서', '사용', '비트', '프로그램', '실행', '부분', '구매', '필히', '구매'],
#  ['일반', '샌디스크', '소니', '에스', '사용', '건가'],
#  ['뭔가', '갤럭시', '느낌', '부당', '윈도우', '아이콘', '아이', '패두', '달리', '느낌'],
#  ['마소',
#   '출시',
#   '태블릿',
#   '출시일',
#   '구입',
#   '이력',
#   '바로',
#   '서피스',
#   '아마',
#   '윈도우',
#   '성능',
#   '때문',
#   '계열',
#   '이후',
#   '태블릿',
#   '안드로이드',
#   '기억'],
#  ['프로', '타입', '커버', '구매', '수납', '공간'],
#  ['장점', '무엇'],
#  ['씨디',
#   '제모',
#   '휴대',
#   '얌려',
#   '모델',
#   '서피스',
#   '프로',
#   '서피스',
#   '랩탑',
#   '보고',
#   '서피스',
#   '프로',
#   '프로그램',
#   '설치',
#   '비트',
#   '비트',
#   '지원',
#   '가능',
#   '윈도우',
#   '설치',
#   '비트',
#   '게임',
#   '랩탑',
#   '나은지'],
#  ['건축', '작업'],
#  ['외관', '혼자', '캠핑', '디자인'],
#  ['휴대', '듣기'],
#  ['기술', '아날로그', '감성', '정말', '발굴'],
#  ['디자인'],
#  ['디자인',
#   '레트로',
#   '감성',
#   '라디오',
#   '알람',
#   '기능',
#   '활용',
#   '슬립',
#   '모드',
#   '사용',
#   '리뷰',
#   '리모컨',
#   '대한',
#   '이야기'],
#  ['댓글', '씨디'],
#  ['패드', '고장', '경우'],
#  ['영상', '전압', '측정기', '하나', '구매'],
#  ['전압', '기능', '퓨즈', '기능', '불량', '제품', '무리', '가면'],
#  ['박하', '시디', '덕분', '사람'],
#  ['어댑터', '지금', '고장', '전부', '과전압', '기억'],
#  ['어댑터', '기기', '기도', '처음'],
#  ['유튜버들', '유튜버', '시디', '유튜브', '항상', '이번', '정말', '도움'],
#  ['정보', '어댑터', '생각', '사용', '이참', '한번', '점검', '손해', '방지'],
#  ['고장',
#   '어댑터',
#   '보통',
#   '전압',
#   '아예',
#   '경우',
#   '전압',
#   '경우',
#   '다음',
#   '전압',
#   '어댑터',
#   '일반',
#   '어댑터',
#   '차이'],
#  ['가요', '류량', '때문', '회로'],
#  ['오늘',
#   '이영',
#   '상이',
#   '삼성',
#   '모니터',
#   '답터',
#   '스펙',
#   '삼성',
#   '답터',
#   '다행',
#   '크기',
#   '전원',
#   '사용',
#   '가능',
#   '가요'],
#  ['댓글', '씨디'],
#  ['진짜', '보고'],
#  ['처음', '적응', '계속'],
#  ['리뷰', '세심'],
#  ['샘숭', '컵드', '인치', '좀더', '모니터'],
#  ['영상', '볼때', '작업', '글쎄'],
#  ['실제', '커브', '화면', '가보', '영상', '볼땐', '왜곡', '실제'],
#  ['삼성', '사람', '곡면'],
#  ['인치'],
#  ['곡면',
#   '모니터',
#   '사용',
#   '느낌',
#   '가운데',
#   '하단',
#   '부분',
#   '조이스틱',
#   '하나',
#   '설정',
#   '정말',
#   '위치',
#   '조작'],
#  ['수록', '구성은', '지못미', '커브드', '최대', '단점', '개인', '제일', '무난'],
#  ['생각',
#   '제품',
#   '컨셉',
#   '벨벳',
#   '터치',
#   '디자인',
#   '엣지',
#   '크게',
#   '잡기',
#   '장점',
#   '듀얼',
#   '스크린',
#   '일단',
#   '기기',
#   '자체',
#   '엣지',
#   '두께',
#   '역시',
#   '기능',
#   '자체',
#   '문제',
#   '엣지',
#   '부분',
#   '활용',
#   '때문',
#   '디스플레이',
#   '면적',
#   '실제',
#   '공간',
#   '악세사리',
#   '가격',
#   '메리트',
#   '듀얼',
#   '스크린',
#   '기능',
#   '플랫',
#   '제품',
#   '플래그',
#   '탑재',
#   '벨벳',
#   '이미지',
#   '가격',
#   '영상',
#   '듀얼',
#   '스크린',
#   '디스플레이',
#   '엣지',
#   '물방울',
#   '노치',
#   '모양',
#   '약간',
#   '본체',
#   '노치',
#   '시작',
#   '부분',
#   '약간',
#   '라운딩',
#   '처리',
#   '반면',
#   '듀얼',
#   '스크린',
#   '도로',
#   '시작',
#   '통해',
#   '공장',
#   '원가',
#   '절감',
#   '목적',
#   '생산',
#   '다른',
#   '공정',
#   '원래',
#   '노치',
#   '직사각형',
#   '디스플레이',
#   '일부러',
#   '검은색',
#   '노치',
#   '뻘짓',
#   '예상'],
#  ['모바일', '사업', '부가', '적자', '정신', '이해'],
#  ['절대', '버벅거리', '가격', '회사', '사양', '예정', '쓰레기'],
#  ['성능', '듀얼', '스크린', '무료', '듀얼', '스크린', '사면', '가격', '벨벳살빠', '추천'],
#  ['스크린', '하나로', '보이', '획기', '기술', '듯함'],
#  ['공짜', '래야'],
#  ['듀얼', '스크린', '제작', '효과', '생각'],
#  ['밸벳', '사전예약', '구매', '엘지빠', '후회'],
#  ['밸벳', '가격'],
#  ['정도'],
#  ['듀얼', '스크린', '마지막', '희망'],
#  ['디자인', '듀얼', '스크린', '구매', '하야', '가격', '성능', '배젤', '아쉬움'],
#  ['타입',
#   '와콤',
#   '뱀부',
#   '잉크',
#   '잉크',
#   '프로',
#   '모델',
#   '전용',
#   '기능',
#   '뱀부',
#   '잉크',
#   '프로',
#   '부담',
#   '이면',
#   '스타일러스',
#   '사서',
#   '가격',
#   '이상',
#   '블투',
#   '충전',
#   '여부',
#   '차이'],
#  ['속도', '테스트', '해주시'],
#  ['듀얼', '스크린', '스냅', '가요', '차이'],
#  ['더블'],
#  ['성능', '듀얼', '스크린', '동일', '가격', '듀얼', '스크린', '공짜', '가격', '정책', '문제'],
#  ['영상',
#   '별개',
#   '내용',
#   '시디',
#   '예전',
#   '애플',
#   '제품',
#   '리뷰',
#   '조금',
#   '요즘',
#   '안드로이드',
#   '제품',
#   '조금'],
#  ['듀얼', '스크린', '마감', '디자인', '개선', '모습'],
#  ['배터리', '사용', '시간'],
#  ['듀얼', '스크린', '얼마'],
#  ['흰색', '생각', '건전지', '충전', '식이'],
#  ['듀얼',
#   '스크린',
#   '별도',
#   '구매',
#   '세대',
#   '거듭',
#   '듀얼',
#   '스크린',
#   '업글',
#   '스크린',
#   '노치',
#   '디자인',
#   '굳이'],
#  ['댓글', '씨디'],
#  ['씨디', '이형', '진짜', '유튜버', '이제', '인텔', '손절'],
#  ['성능', '진짜'],
#  ['이제', '시작'],
#  ['역시', '씨디', '공수'],
#  ['재활용', '발열'],
#  ['장난'],
#  ['라이', '비교'],
#  ['씨디', '웨이즈', '세대', '배터리', '세대', '배터리', '호환', '전문가', '질문'],
#  ['번말'],
#  ['인텔'],
#  ['쵸코파이', '쿨러', '인텔', '레이스', '쿨러', '노릇'],
#  ['싱글코어', '최강'],
#  ['전력', '소비', '발열', '진짜', '이전', '대비', '성비'],
#  ['코어', '쓰레드', '이제', '인텔', '코어', '수가', '점점', '거기', '부스터', '가격', '대도'],
#  ['로스', '소음', '여기'],
#  ['한전', '컴퓨터', '저걸'],
#  ['인텔', '암드', '의식', '외계인'],
#  ['문물',
#   '구경',
#   '케이스',
#   '무슨',
#   '제품',
#   '기사',
#   '부팅',
#   '확인',
#   '수리',
#   '보름',
#   '생각',
#   '반품',
#   '다시',
#   '수냉',
#   '쿨러',
#   '시디',
#   '지옥',
#   '매사'],
#  ['발열'],
#  ['혹시', '모니터', '실수', '액정', '줄선', '수리', '가격', '얼마', '정도', '아시', '최대한'],
#  ['무선', '청소기'],
#  ['샤오미'],
#  ['초반', '인사', '가전', '주부'],
#  ['제품', '관심', '리뷰', '제품', '소개', '설명', '사용', '단점'],
#  ['중국', '가전제품', '다이슨', '작년', '구매', '생각', '배터리', '얼마', '반품'],
#  ['대박', '완죤사', '리뷰'],
#  ['성능', '제품', '구성', '침구', '청소', '제공', '아이나비', '통해', '걱정', '사용', '에드'],
#  ['고딩', '씨디', '상보', '컴터', '조립', '여기', '벌써', '중반'],
#  ['저기', '옆집', '와이파이'],
#  ['성능'],
#  ['성능', '장난', '신호', '정말', '무료', '잠시', '동안', '사용', '갑자기'],
#  ['예전', '공유기', '베란다', '설치', '인터넷', '생각', '이건', '공유기'],
#  ['정도', '이웃', '공동', '구매'],
#  ['대형', '집회', '장소'],
#  ['가정', '과분', '가격'],
#  ['사무실', '사용'],
#  ['진짜', '성능', '괴물'],
#  ['스윽', '접속', '어우', '성능', '가격'],
#  ['만원', '이면', '거의', '만원', '이면', '가정', '쓰기'],
#  ['시청'],
#  ['축하'],
#  ['씨디', '뜬금', '설치', '정도'],
#  ['라이터', '방식', '안테나', '안나', '건가', '놀이터', '엄마'],
#  ['넷기어',
#   '한국',
#   '시장',
#   '가격',
#   '문제',
#   '요즘',
#   '직구',
#   '시대',
#   '아마존',
#   '가격',
#   '비교',
#   '디자인',
#   '외형',
#   '가성',
#   '생각'],
#  ['미국', '저택', '제품', '한국', '오버', '스펙'],
#  ['아파트', '하나', '혼자', '커버'],
#  ['비번', '누군가', '초인종'],
#  ['장난'],
#  ['영상',
#   '댓글',
#   '필터',
#   '바이러스',
#   '내용',
#   '나노',
#   '기술',
#   '내용',
#   '나노',
#   '기술',
#   '파나소닉',
#   '특허',
#   '상용',
#   '제품',
#   '사용',
#   '기술',
#   '공기청정기',
#   '이번',
#   '처음',
#   '사용',
#   '제품',
#   '대해',
#   '리뷰',
#   '바이러스',
#   '억제',
#   '기능',
#   '나노',
#   '기술',
#   '적용',
#   '기사도',
#   '참고'],
#  ['간만'],
#  ['씨디',
#   '오늘',
#   '가성',
#   '아보',
#   '구매',
#   '미세먼지',
#   '고양이',
#   '냄새',
#   '공기',
#   '청청',
#   '이두',
#   '보고',
#   '제품군'],
#  ['코로나',
#   '시기',
#   '회사',
#   '홍보',
#   '내용',
#   '프로',
#   '구매',
#   '위험',
#   '코로나',
#   '효과',
#   '정부',
#   '우선',
#   '구매',
#   '사용',
#   '코로나',
#   '시기',
#   '불안감',
#   '조성',
#   '마케팅',
#   '생각'],
#  ['역시', '싼값', '요즘', '시기', '아주', '공기청정기'],
#  ['씨디',
#   '전혀',
#   '설명',
#   '유튜브',
#   '영상',
#   '링크',
#   '리뷰',
#   '제품',
#   '소개',
#   '제품',
#   '최소한',
#   '지식',
#   '가지',
#   '설명',
#   '도리',
#   '생각',
#   '바이러스',
#   '세균',
#   '절대',
#   '협찬',
#   '직접',
#   '연락',
#   '시험',
#   '결과',
#   '제품',
#   '설명',
#   '달라',
#   '첨언드리',
#   '대부분',
#   '바이러스',
#   '습기',
#   '온도',
#   '취약',
#   '사실',
#   '현재',
#   '코로나',
#   '바이러스',
#   '경우',
#   '온도',
#   '지역',
#   '유행',
#   '때문',
#   '제품',
#   '구매',
#   '코로나',
#   '바이러스',
#   '억제',
#   '보기',
#   '생각'],
#  ['바이러스',
#   '과망',
#   '광고',
#   '오히려',
#   '실내',
#   '오염',
#   '원인',
#   '사용',
#   '권고',
#   '햇습니',
#   '헤파',
#   '오염',
#   '필터',
#   '바이러스',
#   '진원',
#   '바이러스',
#   '환기',
#   '필터',
#   '해결',
#   '주지'],
#  ['나노',
#   '기술',
#   '바이러스',
#   '걱정',
#   '터보',
#   '모드',
#   '수준',
#   '전력',
#   '소모',
#   '소비전력',
#   '편이',
#   '제품',
#   '필터',
#   '가격',
#   '교체',
#   '부담',
#   '부분'],
#  ['서로',
#   '생각',
#   '평행선',
#   '마지막',
#   '지금',
#   '코로나',
#   '유행',
#   '시점',
#   '공기청정기',
#   '바이러스',
#   '퍼뜨릴',
#   '도구',
#   '수도',
#   '때문',
#   '이면',
#   '환기',
#   '시점',
#   '개인',
#   '이득',
#   '위해',
#   '공기청정기',
#   '홍보',
#   '보기',
#   '기업',
#   '입장',
#   '코로나',
#   '바이러스',
#   '유행',
#   '시점',
#   '저런',
#   '신제품',
#   '등장',
#   '바이러스',
#   '제한',
#   '코로나',
#   '바이러스',
#   '제한',
#   '소비자',
#   '오해',
#   '코로나',
#   '바이러스',
#   '시점',
#   '본의',
#   '권고',
#   '사항',
#   '환기',
#   '공기청정기',
#   '낫다',
#   '참고',
#   '요즘',
#   '미세먼지',
#   '이상',
#   '답변'],
#  ['다시'],
#  ['아내'],
#  ['포트', '계속', '불안'],
#  ['네이비', '블루'],
#  ['미니', '뒤판', '유리', '가요'],
#  ['네이비',
#   '블루',
#   '듣기',
#   '네이비',
#   '블루',
#   '약간',
#   '보라',
#   '색상',
#   '네이비',
#   '블루',
#   '약간',
#   '보라',
#   '존예',
#   '어쨋',
#   '무조건',
#   '네이비',
#   '블루'],
#  ['노말', '모델', '삼성', '모델', '모델', '삼성'],
#  ['제발'],
#  ['아이폰', '탑재', '애플', '검수', '통과', '탑재', '걱정'],
#  ['이렁', '차이', '건가'],
#  ['한국', '디스', '애플', '인정'],
#  ['애플', '워치', '에어팟', '얼굴', '달라', '애플', '글래스', '앱등이', '영역', '얼굴'],
#  ['애플', '글래스', '구글', '글래스', '일반', '소비자', '어필', '소비자', '진짜', '스마트', '안경', '정의'],
#  ['처음'],
#  ['타이밍', '깜짝'],
#  ['배터리', '로고', '사과', '모양', '차이'],
#  ['오늘', '에어', '사서', '영상', '금보'],
#  ['미니'],
#  ['미니'],
#  ['미니'],
#  ['모바일'],
#  ['사진',
#   '보고',
#   '아이폰',
#   '아이폰',
#   '거의',
#   '다만',
#   '아이폰',
#   '아이폰',
#   '프로세서',
#   '아이폰',
#   '프로세서',
#   '프로세서',
#   '하나',
#   '소프트',
#   '웨어',
#   '측면',
#   '카메라',
#   '보정',
#   '기능'],
#  ['아이폰', '컬러', '진짜'],
#  ['기준', '작고', '배젤'],
#  ['케이티', '개통'],
#  ['니지'],
#  ['아이폰', '중고', '판매', '언제'],
#  ['동준', '영상', '도움', '폴드', '고려', '보고'],
#  ['삼성', '플립', '휴대'],
#  ['이유'],
#  ['외부', '액정', '플립', '수준', '거나', '태블릿', '더블'],
#  ['플립',
#   '외부',
#   '화면',
#   '조금',
#   '레이저',
#   '외부',
#   '화면',
#   '전화',
#   '정도',
#   '외부',
#   '화면',
#   '단독',
#   '사용'],
#  ['지금', '중고나라', '갤럭시', '폴드', '구매', '참고'],
#  ['삼성', '더블', '가격', '역대', '애플', '가격', '역대', '여기', '부터', '점점', '차이'],
#  ['개인', '의견', '페이스', '아디', '모델', '지문', '인식', '도입'],
#  ['프로', '모델', '프로세서', '라서', '전력', '소모', '하니'],
#  ['강제', '프로'],
#  ['하미', '쳣다'],
#  ['컨텐츠', '의미', '가격', '칩셋', '업글', '기본', '노치', '제발'],
#  ['확정'],
#  ['아이폰',
#   '정말',
#   '아이폰',
#   '답지',
#   '부터',
#   '시작',
#   '약정',
#   '그때',
#   '사면',
#   '엄마',
#   '줄라',
#   '그때',
#   '대면',
#   '아이폰',
#   '달라',
#   '엄마',
#   '사랑'],
#  ['프로', '모델', '일반', '모델', '삼성', '디스플레이', '패널', '패널', '심사', '탈락'],
#  ['인치', '모델', '배터리', '용량'],
#  ['베젤', '정말', '정말', '매우', '노치'],
#  ['디자인', '취향'],
#  ['아이폰', '인치', '오타'],
#  ['애초', '이름'],
#  ['아이폰', '인생', '레전드'],
#  ['프로', '맥스', '생각', '인치', '별로', '사고', '마음', '사이즈', '가격'],
#  ['인치', '기준'],
#  ['갑자기', '야구', '정보'],
#  ['망원', '카메라', '광각', '카메라', '소수', '핑거', '스냅'],
#  ['방금', '벨뱃', '광고', '뭔가'],
#  ['쿠팡', '최대', '할인', '품절', '가격'],
#  ['엘지', '가전'],
#  ['카메라', '평범'],
#  ['카메라',
#   '다른',
#   '회사',
#   '외형',
#   '항상',
#   '인덕션',
#   '별로',
#   '노치',
#   '생각',
#   '가능성',
#   '생각',
#   '이상',
#   '개인',
#   '의견'],
#  ['성능', '전작'],
#  ['중립', '기어', '박아', '애플', '이겻', '삼성', '무슨'],
#  ['뭔가', '동준', '영상'],
#  ['카메라', '카메라', '접힌다', '장점', '활용', '방안'],
#  ['외부', '액정', '레이저'],
#  ['보임'],
#  ['카메라', '어캐하'],
#  ['플립', '무조건', '무광', '액정', '필름', '유광', '자국', '신경'],
#  ['세로'],
#  ['그냥', '레이저'],
#  ['민서',
#   '아이폰',
#   '수리',
#   '산지',
#   '얼마',
#   '개월',
#   '인간',
#   '수학여행',
#   '아이폰',
#   '수리',
#   '말좀',
#   '너희',
#   '어머니',
#   '말씀',
#   '사과',
#   '구리',
#   '얼마나',
#   '중고',
#   '물어',
#   '제발',
#   '근성',
#   '아가',
#   '제발',
#   '책상',
#   '비듬',
#   '빗질',
#   '학교',
#   '책상',
#   '여름',
#   '최소한',
#   '매너',
#   '비듬',
#   '물티슈',
#   '간다',
#   '현빈',
#   '망상',
#   '선생님',
#   '구라',
#   '제발',
#   '잠수',
#   '타고'],
#  ['엘지'],
#  ['전자기기', '덕후'],
#  ['기업', '정책', '건가'],
#  ['눈팅'],
#  ['매스', '프리미엄', '전작', '가격', '차이', '안나', '성능', '오히려', '그냥', '자초', '결과', '결과'],
#  ['엘지', '엘지', '더욱'],
#  ['삼성', '판이'],
#  ['차라리', '스냅', '가격', '엑시노스', '가격'],
#  ['스냅', '독점'],
#  ['그냥'],
#  ['스냅', '그냥'],
#  ['라나', '문제'],
#  ['나노', '공정', '개발'],
#  ['갑자기', '채널', '적응'],
#  ['내년', '기대', '엑시노스'],
#  ['그련데',
#   '갤럭시',
#   '울트라',
#   '갤럭시',
#   '갤럭시',
#   '차이점',
#   '무엇',
#   '카메라',
#   '디자인',
#   '성능',
#   '모든',
#   '부분',
#   '제일',
#   '갤럭시',
#   '갤럭시',
#   '울트라',
#   '갤럭시',
#   '요재',
#   '주위',
#   '갤럭시',
#   '기본',
#   '사람',
#   '쓰기'],
#  ['암드', '합작', '엑시노스', '다시', '엑시노스', '전성기'],
#  ['합작'],
#  ['아아', '동준', '아시', '마이크', '픂퓨', '소리', '내면', '솜털', '선물'],
#  ['예전',
#   '엑시노스',
#   '클럭',
#   '처음',
#   '기염',
#   '스냅',
#   '노스',
#   '는걸',
#   '강조',
#   '엑시노스',
#   '쓰레기',
#   '다시',
#   '영광'],
#  ['동준', '일부러', '배속', '건가', '배속'],
#  ['중공',
#   '짝퉁',
#   '핸폰',
#   '겨울',
#   '사용',
#   '액정',
#   '고장',
#   '가격',
#   '삼성',
#   '최고',
#   '미국',
#   '삼성',
#   '미국',
#   '삼성',
#   '당첨',
#   '성능',
#   '기능',
#   '삼성',
#   '우한',
#   '때문',
#   '시기',
#   '카메라',
#   '성능',
#   '티비',
#   '화면',
#   '삼성',
#   '삼성',
#   '응원'],
#  ['엑시노스', '전작'],
#  ['노트', '플러스', '원금', '그때', '구매', '노트', '플러스', '모델', '구매', '조언', '의견', '고민'],
#  ['편집', '사람'],
#  ['삼성', '장점', '애플'],
#  ['통화', '녹음', '애플', '페이', '정말', '아이폰', '이유', '만년', '앱등이', '생각'],
#  ['통화', '녹음', '애플', '애플', '페이', '존버'],
#  ['만약', '설정', '허용', '거부', '허용', '설정', '사람', '끼리'],
#  ['영상'],
#  ['애플', '페이', '절대', '안나', '오니', '갤럭쉬'],
#  ['오우', '아주'],
#  ['개방'],
#  ['동굴', '목소리', '듣기'],
#  ['이번', '항상', '기대', '더욱더', '기대', '항상', '정보'],
#  ['진작', '녹음', '만약', '발생', '불법', '책임'],
#  ['유튜브', '컨셉', '가요'],
#  ['아이폰',
#   '프로',
#   '맥스',
#   '울트라',
#   '카메라',
#   '기타',
#   '아이폰',
#   '프로',
#   '맥스',
#   '기타',
#   '스팩',
#   '갤력시',
#   '울트라',
#   '상하',
#   '아이폰',
#   '프로',
#   '맥스'],
#  ['애플', '스토어', '호점', '명동', '루머'],
#  ['방수'],
#  ['역시', '기술', '발전'],
#  ['수량', '한정'],
#  ['진짜', '방수'],
#  ['외부',
#   '디스플레이',
#   '분명',
#   '출고',
#   '그냥',
#   '그대로',
#   '아이패드',
#   '프로',
#   '플립',
#   '더블',
#   '메리트',
#   '느낌'],
#  ['갤럭시', '폴드', '라이트', '외부', '디스플레이', '플립'],
#  ['아웃폴딩'],
#  ['제발', '타입'],
#  ['생각', '아이패드', '커넥터', '자석', '충천', '충전', '자석', '살이', '힐것'],
#  ['예전', '맥북', '세이프', '그거'],
#  ['아이폰', '성품', '이어폰', '이어폰', '커넥터', '아이폰', '무선', '충전기'],
#  ['지금',
#   '아이폰',
#   '에어팟',
#   '아이패드',
#   '프로',
#   '아이패드',
#   '때문',
#   '충전기',
#   '하나',
#   '아이패드',
#   '타입',
#   '은근',
#   '만약',
#   '팩트',
#   '아이폰',
#   '타입',
#   '하나',
#   '에어팟',
#   '라이트닝'],
#  ['아이폰', '오열'],
#  ['제발'],
#  ['아이폰', '갤럭시', '버즈', '만약'],
#  ['인치', '삼성', '디스플레이', '감지덕지', '포트', '신경안'],
#  ['라이트닝', '케이블'],
#  ['타입', '삼성', '고속', '충전기', '어댑터', '고속', '충전', '이안'],
#  ['이어폰', '포트', '이해', '충전', '포트', '충전', '사용', '어케함'],
#  ['라이트', '결론'],
#  ['라이트닝'],
#  ['아이폰', '프로', '스마트폰', '최초', '비트', '비트', '삼성', '다른', '스마트폰', '제조', '영역'],
#  ['아이폰', '이야기', '삼성', '삼성', '이후', '비트', '아이폰', '비트'],
#  ['라이트닝', '어그'],
#  ['삼성', '응원'],
#  ['아이폰'],
#  ['라면', '카메라'],
#  ['지문', '인식', '기능'],
#  ['흰색'],
#  ['카툭', '진짜', '정도', '아이폰', '고민', '갤럭시', '갤럭시', '자꾸'],
#  ['세상', '디자인'],
#  ['항상', '소식', '감사', '삼성', '그냥', '노트', '다음', '아이폰', '심정'],
#  ['진짜', '최악', '플래그', '사도', '보급', '느낌', '인식', '패턴', '해제', '하라', '건가'],
#  ['노트', '아이폰', '시리즈', '타피오카', '발칸포', '선녀', '시작', '진짜'],
#  ['우역', '해도', '홀수', '구나', '그냥', '내년', '기대'],
#  ['카툭'],
#  ['디자인',
#   '느낌',
#   '카메라',
#   '고객',
#   '계속',
#   '카메라',
#   '강조',
#   '차라리',
#   '그냥',
#   '노트',
#   '카툭',
#   '튀랑',
#   '카메라'],
#  ['신호등',
#   '디자인',
#   '다우',
#   '색깔',
#   '빨간색',
#   '노란색',
#   '초록색',
#   '노스',
#   '부활',
#   '노트',
#   '마음',
#   '다카',
#   '툭섬',
#   '티어',
#   '무기',
#   '일단',
#   '실물'],
#  ['지문', '화면', '지문', '인식', '탑제', '살라', '노트'],
#  ['기술'],
#  ['잡스', '에디', '진짜'],
#  ['안경', '패스'],
#  ['아침', '미쿠', '건가', '소아온', '극장판', '실사판'],
#  ['애플',
#   '글래스',
#   '도수',
#   '지원',
#   '디자인',
#   '일반',
#   '안경',
#   '차이',
#   '지금',
#   '안경',
#   '대용',
#   '무조건',
#   '과연',
#   '글래스',
#   '디자인'],
#  ['스타', '버스', '스트림'],
#  ['라이',
#   '센서',
#   '기술',
#   '아이패드',
#   '적용',
#   '판매',
#   '아이폰',
#   '적용',
#   '출시',
#   '애플',
#   '글라스',
#   '출시',
#   '맛보기'],
#  ['사람', '사용'],
#  ['노트'],
#  ['현실', '구분', '인기', '인기'],
#  ['양인'],
#  ['디자인'],
#  ['애플', '안경', '삼성', '렌즈', '가능'],
#  ['그래그래', '울트라', '모든', '뇌절'],
#  ['기본',
#   '노트',
#   '가격',
#   '아이폰',
#   '가장',
#   '아이폰',
#   '프로',
#   '맥스',
#   '가격',
#   '갤럭시',
#   '유저',
#   '아이폰',
#   '프로',
#   '간다',
#   '무조건'],
#  ['일반', '모델', '인치', '인치', '인치', '발전'],
#  ['아이폰'],
#  ['노트', '리콜'],
#  ['노트', '시리즈'],
#  ['노트', '노트', '건너', '글구'],
#  ['현직',
#   '노트',
#   '사용자',
#   '아주',
#   '만족',
#   '개월',
#   '사용',
#   '번인',
#   '고장',
#   '안나',
#   '이제',
#   '폴드',
#   '마음',
#   '노트',
#   '시리즈',
#   '항상'],
#  ['가격', '생각'],
#  ['까비'],
#  ['아이폰', '센서', '원래'],
#  ['중국', '카메라'],
#  ['아이폰', '던데', '가요'],
#  ['마리'],
#  ['옛날', '자막', '편집', '카메라', '지금'],
#  ['엘지'],
#  ['상상', '가성', '비듀', '마레', '방구'],
#  ['성비'],
#  ['충전기', '기기'],
#  ['소개', '영상'],
#  ['가성', '리뷰'],
#  ['동네', '엘지', '보고'],
#  ['브로', '가용', '가성', '괜찬', '무선', '충전', '굳이', '핸폰가지', '대부분', '브로'],
#  ['소비자', '선택'],
#  ['벨벳', '소리'],
#  ['등장'],
#  ['오프닝'],
#  ['듀마레', '말방규', '샤오미', '여윽시', '가성', '비쥬', '구경', '총총'],
#  ['오타'],
#  ['확실', '이번', '완판', '된거', '보고', '샤오미', '구매'],
#  ['방구', '형님', '샤오미', '요새', '리뷰', '예정', '가요'],
#  ['화웨이', '빽업', '데이터', '샤오미', '자신'],
#  ['이번', '터치', '영상'],
#  ['성능', '점수', '비교', '보기'],
#  ['무선', '충전', '기능', '기능', '기능'],
#  ['지금', '요금', '할인', '할인', '직구', '이득'],
#  ['플래그', '한번', '거의', '대부분', '계속', '플래그', '가지'],
#  ['역시', '고민', '해결', '말방규'],
#  ['구매', '기계', '구매'],
#  ['배경'],
#  ['모델', '안드', '기반', '듀얼', '쇼크', '연결', '통신사', '사용', '가능', '여부'],
#  ['가성',
#   '가성',
#   '문제',
#   '수명',
#   '포코',
#   '사망',
#   '미노트',
#   '담폰',
#   '샤오미',
#   '장점',
#   '하나',
#   '배터리',
#   '무자',
#   '간다'],
#  ['레드'],
#  ['진짜', '영상', '현실', '디자인', '정뚝', '디자인'],
#  ['샤오미', '보안', '메인'],
#  ['실화'],
#  ['서브', '정말', '사양', '가격'],
#  ['샤요미'],
#  ['말띠'],
#  ['지금', '노트', '팔고', '미노트', '역시', '백도어', '문제', '샤오미', '다른', '국가', '회사', '고민'],
#  ['엘쥐', '사운드', '추가', '바로'],
#  ['장모님', '샤오미', '성비', '쿠사리', '어르신', '갤럭시', '최고'],
#  ['통신사', '사용'],
#  ['벤치', '성능', '비교', '아이폰', '벨벳'],
#  ['듀말', '방구', '보고'],
#  ['샤오미', '성비', '출시', '모델', '마넌', '초반', '최고', '중반', '모델', '마넌', '빛번짐', '장난'],
#  ['스냅드래곤', '일반', '차이', '가요'],
#  ['벨벳'],
#  ['역시', '샤오미', '가성'],
#  ['찬사', '진짜'],
#  ['정발', '매진', '지금'],
#  ['전자', '리뷰', '방구'],
#  ['벨벳'],
#  ['샤오미', '구글'],
#  ['개인', '배터리', '무게'],
#  ['샤오미', '가성', '절약', '디자인', '갤럭시'],
#  ['듀말', '말방규'],
#  ['미리', '해외', '직구', '프로', '모델'],
#  ['무선', '충전', '방수', '방진', '벨벳', '소비자', '선택'],
#  ['샤태식'],
#  ['알리', '직구'],
#  ['게임', '기용'],
#  ['지금', '심정', '궁굼함'],
#  ['이잉'],
#  ['배용'],
#  ['무선', '충전'],
#  ['노트',
#   '구매',
#   '사용',
#   '가격',
#   '대비',
#   '성능',
#   '높이',
#   '테이블',
#   '전면',
#   '유리',
#   '파손',
#   '전면',
#   '보호',
#   '유리',
#   '교환',
#   '다시',
#   '파손',
#   '전면',
#   '유리',
#   '교환',
#   '금액',
#   '지금',
#   '차량',
#   '블루투스',
#   '음악'],
#  ['듀말', '보기'],
#  ['중국'],
#  ['센서', '추억'],
#  ['몇장', '아이폰', '세대', '중고'],
#  ['엘지', '국뽕', '커버', '불가능'],
#  ['디자인', '별로', '서브'],
#  ['그린', '컬러', '왜빼'],
#  ['중국'],
#  ['정발', '가격', '다나', '최저', '링크', '후반', '파네', '쿠팡', '로켓', '배송', '최저'],
#  ['국제', '보안', '어찌'],
#  ['계속', '고민', '행시', '방구', '실험실', '화이팅', '방구', '실험실', '수로', '알림', '설정'],
#  ['서브', '영상', '덕분', '리스트', '하나'],
#  ['백도어',
#   '삼성',
#   '애플',
#   '마당',
#   '의미',
#   '중국',
#   '백도어',
#   '문제',
#   '구글',
#   '수집',
#   '개인정보',
#   '차이',
#   '개인정보',
#   '의미'],
#  ['진짜', '성비'],
#  ['정발', '제품', '구글', '플레이', '포함', '직구', '제품'],
#  ['하드웨어', '도오', '샤오미', '아이폰'],
#  ['중국', '제품', '이제', '보안', '이슈'],
#  ['해외', '직구', '나은', '가격', '정도', '차이'],
#  ['샤오미폰',
#   '백도',
#   '사람',
#   '실상',
#   '주변',
#   '금융',
#   '친구',
#   '지장',
#   '잘만',
#   '중국',
#   '우리나라',
#   '백도어',
#   '소리'],
#  ['당첨',
#   '발표',
#   '금일',
#   '오후',
#   '유튜브',
#   '커뮤니티',
#   '통해',
#   '공개',
#   '당첨',
#   '과정',
#   '영상',
#   '공유',
#   '벨벳',
#   '던킨',
#   '커피'],
#  ['엘쥐', '벨벳', '매혹', '적임', '딴트공', '화이팅'],
#  ['역시',
#   '방구',
#   '오늘',
#   '감상',
#   '생각',
#   '벨벳',
#   '물방울',
#   '강의',
#   '카메라',
#   '네이버',
#   '평일',
#   '말방규',
#   '듀말',
#   '말방규'],
#  ['타임', '랩스', '기능', '정말', '기능', '인터넷', '방송', '디자인', '성능', '벨벳', '화이팅', '지메일'],
#  ['출시', '스마트폰', '보고', '듀얼', '스크린', '포함', '더욱', '성능', '가격', '지메일'],
#  ['다시', '딴트공', '벨벳', '패션', '생각', '어디', '딴트공', '보고', '화이팅'],
#  ['오늘', '시청', '방구', '홧팅', '네이버컴'],
#  ['아이폰', '느낌', '벨벳', '화이팅', '지메일'],
#  ['엘지', '벨벳', '시리즈', '삼성', '노트', '시리즈', '대체', '수도', '생각', '네이버'],
#  ['등짝',
#   '컬러',
#   '아주',
#   '일루',
#   '선셋',
#   '컬러',
#   '미미',
#   '완전',
#   '물방울',
#   '디자인',
#   '아크',
#   '디자인',
#   '대한',
#   '디자인',
#   '신경',
#   '모습',
#   '벨벳',
#   '시작',
#   '엘지',
#   '활약',
#   '기대',
#   '네이버'],
#  ['벨벳', '색상', '스마트폰', '엘지', '유저', '로써', '카메라', '기능', '반칙', '꿀잠', '예상', '벨벳'],
#  ['애플', '아이폰', '사용자', '로써', '한번', '엘지', '휴대폰', '보고', '혹시', '한번', '참여'],
#  ['벨벳', '이번', '휴대폰', '이름', '옛날', '디자인', '벨벳', '한번', '보고', '휴대폰'],
#  ['벨벳', '화이팅', '지메일'],
#  ['물방울', '디자인', '판매량', '세대'],
#  ['오옷', '아침', '이벤트', '온라인', '수업', '바로', '벨벳', '진짜', '가지', '디자인', '지메일'],
#  ['디자인', '진짜', '벨벳', '카카오'],
#  ['라이브', '인트', '항상', '벨벳', '디자인', '기능', '기대', '네이버'],
#  ['지메일',
#   '벨벳',
#   '다시',
#   '한번',
#   '점프',
#   '자리',
#   '스프링',
#   '존재',
#   '생각',
#   '정말',
#   '스팩',
#   '요즘',
#   '시기',
#   '부담',
#   '가격',
#   '생각',
#   '정말'],
#  ['벨벳', '정말', '당첨'],
#  ['이번', '정말', '화이팅'],
#  ['벨벳', '생각', '이번', '기회', '지메일'],
#  ['이번', '디자인', '스타일', '골뱅이', '지메일', '점컴'],
#  ['디자인'],
#  ['앨지폰', '선입견', '이후', '관심', '이번', '벨벳', '한번', '보고', '듀말', '말방규', '평일', '말방규'],
#  ['진짜', '선셋', '색상'],
#  ['벨벳', '듀얼', '스크린', '전체', '말겁', '네이버'],
#  ['색상', '디자인', '지메일'],
#  ['진짜', '네이버'],
#  ['벨벳', '정말', '지메일'],
#  ['엘지', '개인', '가장', '지메일'],
#  ['이번', '벨벳', '기대', '지메일'],
#  ['정말', '당첨', '방구', '응원', '벨벳', '디자인', '아주', '그냥', '데쓰', '골뱅이', '지메일', '점컴'],
#  ['색상', '정말', '완전', '네이버'],
#  ['아쉬움', '거짓', '부디', '부활', '신호탄', '고대', '벨벳', '브로', '지메일'],
#  ['초콜릿', '요흥', '행해', '벨벳', '지메일'],
#  ['사진', '별로', '동영상', '생각', '화면비율', '디자인', '다만', '애플'],
#  ['엘지', '엘지', '사용'],
#  ['디자인', '중심', '나사', '스마트폰', '지메일'],
#  ['네이버'],
#  ['벨벳', '런가'],
#  ['디자인', '가격', '노코멘트', '파이팅', '네이버'],
#  ['한메일', '벨벳', '색깔', '아우라', '완전', '브랜드', '기대'],
#  ['색깔', '심플', '혹시', '응모'],
#  ['디자인'],
#  ['역시', '디자인', '상보', '카메라'],
#  ['스마트폰', '기대', '지메일'],
#  ['벨벳', '뭔가', '디자인', '체고', '지메일'],
#  ['진짜'],
#  ['벨벳', '흑우'],
#  ['지메일', '물방울', '카메라', '보고'],
#  ['디자인', '벨벳', '기대', '네이버'],
#  ['진짜', '이번'],
#  ['디자인', '지메일'],
#  ['엘지', '벨벳', '디자인', '진짜', '브르', '카메라', '네이버'],
#  ['벨벳', '정말', '기대', '카메라', '실제', '보고', '골뱅이'],
#  ['생방',
#   '라인강',
#   '라이브',
#   '영상',
#   '다행',
#   '트공',
#   '엑스페리아',
#   '스마트폰',
#   '리뷰',
#   '트공',
#   '영상',
#   '최신',
#   '부모님'],
#  ['벨벳', '영상', '디자인', '계속', '강조', '디자인', '다만', '가격', '대비', '스펙', '지메일'],
#  ['봣던', '독자', '스마트폰', '급햇', '당첨'],
#  ['이번', '엘지', '엘지', '면도', '면도', '계속', '지메일'],
#  ['진짜', '선셋', '당첨', '가즈'],
#  ['방구', '실험실', '예전', '보고', '응원'],
#  ['반구', '지메일'],
#  ['벨벳', '도전', '지메일'],
#  ['영국', '남자', '지메일'],
#  ['제발', '벨벳', '당첨', '가즈', '선셋', '목업', '달라'],
#  ['벨벳', '렌더링', '부터', '실물', '진짜', '실제', '제품', '기대'],
#  ['디자인', '부서', '느낌', '지메일', '점컴'],
#  ['엘지', '엘지', '사용', '사람', '응원', '네이버', '쩜컴'],
#  ['자체', '카메라', '디자인', '선택', '출시', '인기', '구글'],
#  ['진짜', '마이크', '다른', '완전', '영상'],
#  ['사용자', '로써', '벨벳', '가지', '화이팅', '도넛', '지메일'],
#  ['벨벳', '화이팅', '아이폰', '네이버'],
#  ['벨벳'],
#  ['항상', '방구', '실험실', '보고', '댓글', '벨벳', '유혹', '수가', '보이', '항상'],
#  ['이번', '벨벳', '색깔', '기대', '네이버컴'],
#  ['아이폰', '고생', '벨벳', '항상', '영상', '보고'],
#  ['디자인', '진짜', '골뱅이', '네이버'],
#  ['휴대폰', '장비', '취미', '유튜브', '시작'],
#  ['디자인', '색상', '정말'],
#  ['이메일', '주소', '벨벳', '대한', '대감', '가격', '사양', '한번', '보고', '보조금', '정도', '바로'],
#  ['이름', '추억', '엘지', '벨벳', '흥해', '네이버'],
#  ['벨벳', '딴트공', '트래비스', '면상'],
#  ['디자인', '역대'],
#  ['엘지', '저번', '한번', '엘지', '화이팅'],
#  ['디자인', '컬러', '성능', '조금', '네이버'],
#  ['벨벳', '디자인', '칼라', '미춌네'],
#  ['화이팅', '이번', '성공', '네이버'],
#  ['벨벳', '누가', '구글'],
#  ['색상', '정말', '카메라', '성능', '기대', '네이버'],
#  ['벨벳', '카메라', '에드', '최고', '네이버'],
#  ['기대', '디자인', '카메라', '기대'],
#  ['벨벳', '디자인', '진짜', '성능', '진짜', '지메일'],
#  ['디자인',
#   '정말',
#   '색감',
#   '진짜',
#   '국내',
#   '스마트폰',
#   '호불호',
#   '갈릴',
#   '수도',
#   '감히',
#   '시리즈',
#   '출시',
#   '전략',
#   '스마트폰',
#   '이메일',
#   '주소',
#   '골뱅이',
#   '지메일'],
#  ['벨벳',
#   '정말',
#   '플래그',
#   '모델',
#   '벨벳',
#   '사면',
#   '듀얼',
#   '스크린',
#   '듀얼',
#   '스크린',
#   '사면',
#   '전용',
#   '사고',
#   '마음',
#   '때문',
#   '지출',
#   '제발'],
#  ['혹시', '일단', '항상'],
#  ['벨벳', '한번', '보고'],
#  ['가격'],
#  ['디자인', '개선', '가격', '엘지', '응원'],
#  ['진짜', '아이폰', '가격', '전부', '산다', '화이팅', '메일'],
#  ['가격'],
#  ['벨벳', '화이팅', '선전'],
#  ['디자인', '진짜', '기회', '보고'],
#  ['핸드폰', '디자인', '벨벳', '소개', '네이버'],
#  ['물방울', '디자인', '인상'],
#  ['벨벳', '도약', '빌어', '골뱅이', '지메일'],
#  ['최초', '성능', '기대'],
#  ['벨벳', '디자인', '가격', '네이버'],
#  ['일루', '선셋', '벨벳', '당첨', '아아', '네이버'],
#  ['벨벳', '카메라', '디자인', '이번', '개인', '핸드폰'],
#  ['벨벳', '이름', '마음', '드네', '띵큐', '정말', '마음', '듭니', '색깔', '화이트', '제일'],
#  ['벨벳', '네이버컴'],
#  ['디자인', '녹색', '뭔가'],
#  ['벨벳', '당첨', '네이버'],
#  ['하얀색', '딴트콩', '트레비스', '벨벳'],
#  ['벨벳', '탈출'],
#  ['지메일'],
#  ['벨벳', '카메라', '렌즈', '디자인'],
#  ['이번'],
#  ['디자인', '가격'],
#  ['손가락', '엘쥐', '네이버'],
#  ['벨벳', '한번', '보고', '응원', '엘지'],
#  ['벨벳', '디자인'],
#  ['벨벳', '디자인', '가격', '사람', '엘지', '화이팅', '네이버컴'],
#  ['벨벳', '네이버'],
#  ['디자인', '듀얼', '한층', '하니', '기대', '네이버'],
#  ['영상', '다음'],
#  ['벨벳', '이제', '사업'],
#  ['가격', '이해', '네이버'],
#  ['엘지', '벨벳'],
#  ['역시', '디자인', '깡패'],
#  ['벨벳', '정말', '디자인', '색상', '생각', '기능', '정말', '트공'],
#  ['플래그', '기능', '네이버'],
#  ['벨벳', '디자인', '칭찬', '가격'],
#  ['컬러', '다한', '지메일'],
#  ['세로', '확대', '항상', '용서', '사모님', '가요'],
#  ['엘지',
#   '밸벳',
#   '가격',
#   '엘지',
#   '생각',
#   '가격',
#   '선택',
#   '생각',
#   '듭니',
#   '스펙',
#   '디자인',
#   '등등',
#   '문제',
#   '가격',
#   '가격',
#   '제일',
#   '문제',
#   '이메일',
#   '삭제',
#   '영상'],
#  ['아이폰', '에어팟', '프로', '황금', '올리브', '벨벳'],
#  ['성능', '쿼드덱', '무선', '충전', '베젤', '가격'],
#  ['자기', '얼굴', '면서', '인스타', '틱톡', '사람', '아이폰', '사지'],
#  ['사용', '영상편집', '원래', '타임랩스', '속도', '조절', '기능', '홍보', '진짜', '실망'],
#  ['와우', '이번', '제품', '플래그', '가격', '바로', '사고', '정도', '리뷰', '영상'],
#  ['이후', '한번', '보고'],
#  ['여러분', '생각', '벨벳'],
#  ['평일', '말방규', '오늘', '아침', '엘지', '카메라', '삼성', '궁금궁금'],
#  ['영상', '제작', '최적화', '서브'],
#  ['삼성', '시도', '던데', '동영상', '편집', '기능'],
#  ['오오오오', '벨벳', '패션', '생각', '트공', '화이팅'],
#  ['세로', '형식', '게다가', '벨벳'],
#  ['벨벳', '디자인', '이아주'],
#  ['가격', '한번'],
#  ['엘지', '또르', '삼성', '애플'],
#  ['벨벳', '진짜'],
#  ['벨벳', '엘지', '대작', '이번', '예전', '명성', '찾기', '희망', '네이버'],
#  ['평일', '말방규'],
#  ['저기', '저가', '예전', '대애'],
#  ['벨벳', '디자인', '진짜', '생태계', '교란', '등장', '가격', '대비', '포지션', '네이버'],
#  ['이번', '벨벳', '느오긴', '혹시', '미노트', '개봉', '리뷰'],
#  ['먹방', '시작', '벨벳', '시작'],
#  ['하이브로'],
#  ['디자인', '편집', '같아욯'],
#  ['실제', '모습', '기대'],
#  ['전성기', '다시', '찾기', '이번', '네이버'],
#  ['세로', '영상'],
#  ['엘지', '손절', '이건'],
#  ['사모님', '에이', '망구', '절대', '설마'],
#  ['핸드폰',
#   '게임',
#   '그레',
#   '벨벳',
#   '가지',
#   '벨벳',
#   '디자인',
#   '가지',
#   '유트브',
#   '영상',
#   '데폰',
#   '여서',
#   '카메라',
#   '버벅거리',
#   '심지어',
#   '고장',
#   '가지',
#   '카메라',
#   '사용',
#   '카메라',
#   '우리',
#   '카메라',
#   '살수',
#   '형편',
#   '출시',
#   '벨벳',
#   '매일',
#   '매일'],
#  ['보조금', '느낌', '가격'],
#  ['이건', '퀄컴', '이상', '거나', '아예', '가격', '불만', '구멍'],
#  ['이벤트', '참여', '계정', '메일'],
#  ['엘지', '스타일', '애플', '삼성'],
#  ['감상', '디자인', '하나', '카메라', '배치', '카메라', '생각', '벨벳', '생각', '디자인', '깡패', '네이버'],
#  ['가지'],
#  ['카메라', '지메일'],
#  ['세로', '화면'],
#  ['편집', '최고', '마이크'],
#  ['이번', '엘지', '그린', '모델', '스카웃', '가지', '깜짝', '방구', '와이프', '오늘', '영상', '보고'],
#  ['벨벳', '디자인', '생각', '평소', '엘지', '디자인', '별로', '생각', '이번', '디자인', '색감'],
#  ['세로', '라이브', '세로', '녹화', '본인', '가요'],
#  ['네이버'],
#  ['벨벳', '디자인', '만하', '가격', '네이버'],
#  ['촬영', '세로', '영상', '가로', '영상', '편집', '벨벳', '한몫'],
#  ['영상', '재생', '최대', '다른', '가요'],
#  ['찍기'],
#  ['나나', '컴터', '꿀잼'],
#  ['댓글'],
#  ['항상', '영상'],
#  ['구글',
#   '벨벳',
#   '마치',
#   '스마트폰',
#   '디자인',
#   '하나',
#   '줄기',
#   '존재',
#   '물방울',
#   '카메라',
#   '엣지',
#   '벨벳',
#   '터치',
#   '디자인',
#   '취향',
#   '게다가',
#   '색갈',
#   '베젤',
#   '리스',
#   '한번',
#   '보고',
#   '하드웨어',
#   '스펙',
#   '느낌',
#   '도나',
#   '풍경화',
#   '진짜',
#   '기능',
#   '고성능',
#   '준수',
#   '성능',
#   '이외',
#   '장점',
#   '벨벳',
#   '진짜'],
#  ['라이브', '내내', '색깔', '색깔'],
#  ['벨벳', '타임', '랩스', '기능', '마음', '저희', '오빠', '엘지빠', '이번', '색상', '화이트', '가장'],
#  ['어째서', '벨벳', '누님'],
#  ['벨벳', '디자인', '정말', '한번', '보고'],
#  ['쩌기', '영상', '여자', '갤럭시', '워치', '액티부', '엘지'],
#  ['벨벳', '예약', '왜케', '엘지', '번가', '예약', '짐벌', '아이폰', '차이'],
#  ['벨벳',
#   '줄평',
#   '물방울',
#   '카메라',
#   '인정',
#   '이유',
#   '물방울',
#   '카메라',
#   '인정',
#   '디자인',
#   '이기',
#   '때문',
#   '방구',
#   '보고'],
#  ['화면', '비율'],
#  ['디자인', '위해', '악마', '모든', '재물', '벨벳', '응원'],
#  ['네이버', '벨벳', '간지'],
#  ['벨벳', '디자인', '가격', '별로', '성능', '아이폰', '예감'],
#  ['가격', '다소', '보이', '카메라', '성능', '실제', '사용', '얼마나', '보정', '조금', '리뷰'],
#  ['화면', '세로'],
#  ['가격'],
#  ['약간', '아티스트'],
#  ['카메라', '홍보'],
#  ['가격', '착햇으'],
#  ['정도', '마이크', '영상', '자랑거리', '유튜브', '상용'],
#  ['그냥'],
#  ['노트'],
#  ['쿼드', '어디', '증발', '입지', '가요'],
#  ['사리', '벨벳', '관심'],
#  ['이번', '엘지', '뭔가', '엘지', '색깔', '진짜', '화이트', '제일', '저희', '애가', '틱톡', '틱톡'],
#  ['벨벳', '조건', '디자인', '카메라', '디자인', '이메일'],
#  ['벨벳',
#   '디자인',
#   '만듬새',
#   '보이',
#   '일단',
#   '카메라',
#   '소리',
#   '녹음',
#   '위주',
#   '리뷰',
#   '인지',
#   '성능',
#   '소프트웨어',
#   '최적화',
#   '보지',
#   '로써',
#   '카메라',
#   '편집',
#   '기능',
#   '보이',
#   '디자인',
#   '후지',
#   '소프트웨어',
#   '최적화',
#   '합리',
#   '가격',
#   '보완'],
#  ['디자인', '뭔가', '아이폰'],
#  ['번인'],
#  ['구별'],
#  ['처음', '기능', '기존', '기술', '성공', '기원'],
#  ['벨벳', '디자인', '카메라', '촬영', '신경', '타임', '랩스', '기능'],
#  ['진짜', '가격'],
#  ['가격'],
#  ['벨벳', '인덕션', '물방울', '모양', '카메라', '인상', '다른', '기업', '디자인', '시도'],
#  ['성능'],
#  ['팔지'],
#  ['명암', '처리', '기분'],
#  ['정말', '기능', '사기'],
#  ['세로', '전체', '화면'],
#  ['영상', '진짜', '아이폰'],
#  ['시네마', '모드'],
#  ['블로거',
#   '유튜버',
#   '소셜',
#   '리뷰',
#   '사람',
#   '제격',
#   '요약',
#   '생산',
#   '정도',
#   '가격',
#   '스펙',
#   '구입',
#   '과연',
#   '이번',
#   '벨벳',
#   '얼마나'],
#  ['동영상', '찍기'],
#  ['엘지', '화웨이'],
#  ['세로'],
#  ['벨벳', '리뷰', '가장', '제대로', '제품', '장점', '리뷰', '유투브', '영상', '세로'],
#  ['전체', '화면'],
#  ['최대', '화질', '아이폰'],
#  ['여성', '누구', '가이거', '후회'],
#  ['서브', '하나', '집사람', '등짝뺨따쿠', '오타쿠'],
#  ['세로', '재생'],
#  ['벨벳', '카메라', '물방울', '노치', '사람', '관심', '이메일', '이벤트', '참여'],
#  ['벨벳'],
#  ['세로',
#   '영상',
#   '벨벳',
#   '노력',
#   '아이폰',
#   '가격',
#   '후덜',
#   '비교',
#   '똥망폰',
#   '벨벳',
#   '아빠',
#   '채널',
#   '이중인격',
#   '채널'],
#  ['벨벳', '설마', '기능', '설마'],
#  ['광고인', '영상', '동안', '매력'],
#  ['벨벳', '별로', '모델', '레드', '벨벳'],
#  ['모델',
#   '화면',
#   '실물',
#   '카메라',
#   '더욱',
#   '분발',
#   '스마트폰',
#   '카메라',
#   '카메라',
#   '화질',
#   '뽀샤시',
#   '건데',
#   '사의',
#   '기술'],
#  ['아이폰', '아이폰', '매력', '삼성', '노트', '시리즈', '매력', '처럼'],
#  ['쿼드덱빼', '시체', '회사', '쿼드덱'],
#  ['대충', '관짝', '형님', '관짝'],
#  ['문자메시지', '팝업', '크기'],
#  ['테디', '원안', '지원'],
#  ['벨벳', '디자인', '사랑', '역시', '킹쥐'],
#  ['다가'],
#  ['이번', '과감', '로고', '엘지'],
#  ['가격', '핼지'],
#  ['가격'],
#  ['품질'],
#  ['여자', '모델', '누구세요', '아내', '설마', '사람', '실제', '가격', '정책', '기대'],
#  ['빠음'],
#  ['삼성',
#   '아이폰',
#   '인기',
#   '시장조사',
#   '성능',
#   '크기',
#   '가격',
#   '합리',
#   '엘지',
#   '지금',
#   '상태',
#   '작고',
#   '가형',
#   '틈새',
#   '공략',
#   '해도'],
#  ['네이버', '디자인', '벨벳'],
#  ['개인',
#   '디자인',
#   '정도',
#   '틱톡',
#   '인스타',
#   '사이즈',
#   '가격',
#   '세상',
#   '장점',
#   '쿼드덱',
#   '발할라',
#   '디자인',
#   '메리트'],
#  ['따따', '다단', '따따', '다다', '다단', '관짝'],
#  ['감상',
#   '광고',
#   '벨벳',
#   '디자인',
#   '강조',
#   '디자인',
#   '강조',
#   '느낌',
#   '보급',
#   '생각',
#   '성능',
#   '정도',
#   '정도',
#   '신뢰',
#   '부분',
#   '감점',
#   '스마트폰',
#   '정도',
#   '벚어날',
#   '생각',
#   '디자인',
#   '요소',
#   '전과',
#   '다른',
#   '영상',
#   '이드',
#   '카메라',
#   '성능',
#   '칭찬',
#   '점수',
#   '만점',
#   '제품'],
#  ['삼성', '배끼', '인물', '모드', '애플'],
#  ['디자인', '이번', '정말', '생각', '음원', '사람', '사용', '쿼드', '이번', '구매', '일반인', '생각'],
#  ['그냥',
#   '플레그',
#   '나왓으',
#   '고민',
#   '디자인',
#   '다운',
#   '그레이드',
#   '선택',
#   '이유',
#   '삼성',
#   '디자인',
#   '별로',
#   '아이폰',
#   '전면',
#   '디자인',
#   '별로',
#   '지금',
#   '가격',
#   '십만원',
#   '플레그',
#   '나름',
#   '선방',
#   '덴데'],
#  ['이벤트', '참여', '벨벳', '트랜디'],
#  ['이번',
#   '광고',
#   '아보',
#   '려고',
#   '방구',
#   '몇몇',
#   '유튜',
#   '버들',
#   '통해',
#   '카메라',
#   '정말',
#   '가격',
#   '거의',
#   '판매',
#   '도둑',
#   '스마트폰',
#   '유저',
#   '로써',
#   '이번',
#   '정말',
#   '실망',
#   '지금',
#   '그냥',
#   '보급',
#   '제품',
#   '출시',
#   '가격',
#   '이번',
#   '창렬스러움',
#   '제대로'],
#  ['아이폰', '다른', '틀링'],
#  ['벨벳', '디자인', '성능', '격변', '잠재력', '녀석'],
#  ['여러분', '아이폰', '참고', '밤샘', '실수'],
#  ['생각', '비교', '아이폰', '기본', '루머', '일단', '하반기', '존버합니'],
#  ['버벅거리'],
#  ['유튜브'],
#  ['다음', '비교'],
#  ['비교', '비교', '자급', '제로'],
#  ['오타'],
#  ['비교'],
#  ['가성', '사망', '방구', '성비', '보고'],
#  ['전면', '느낌', '배터리', '느낌'],
#  ['가성', '사망', '방구'],
#  ['이건'],
#  ['그래픽', '상보', '사용', '나머지', '가성', '차지', '성능'],
#  ['존버', '탈껄', '일부러', '카메라', '배터리', '이나', '차이', '흐규규규'],
#  ['저건', '아이폰', '미디어텍', '발전', '크게', '문제'],
#  ['프로세서', '원가', '절감', '기능', '등등', '플레그', '프로세서', '해상도', '배터리', '원가', '절감'],
#  ['영상', '정리'],
#  ['배터리', '매우', '영상', '사람'],
#  ['휴대폰', '배그'],
#  ['성능', '후지', '생각', '여서'],
#  ['프로세서', '게임', '아이폰', '미디어', '컨텐츠', '안드로이드'],
#  ['제품', '고민'],
#  ['듀말', '말방규', '항상'],
#  ['걀제', '오타', '하나', '오늘', '리뷰', '말방규'],
#  ['고생', '딴트공', '교차', '건강', '월요일', '말방규'],
#  ['갤럭시',
#   '전작',
#   '사용',
#   '아몰레드',
#   '액정',
#   '장점',
#   '개월',
#   '정도',
#   '사용',
#   '너무버벅',
#   '삼성',
#   '페이도',
#   '카드',
#   '타이밍',
#   '로딩',
#   '시작',
#   '상황',
#   '발생',
#   '마찬가지',
#   '생각',
#   '정말',
#   '라이트'],
#  ['비교', '가격', '비교', '생각', '듭니', '보고'],
#  ['초등학생'],
#  ['영상', '화면', '비율'],
#  ['오늘', '말방규'],
#  ['비교', '하겟', '화면', '요구', '관계', '사전예약'],
#  ['미노트', '성능', '비슷가격', '따블', '갤럭시', '미노트', '가격', '바가지'],
#  ['조리', '걀제', '타용'],
#  ['카메라', '개수', '능사', '프로세서', '사진', '처리', '능력', '초점', '애플', '인덕션'],
#  ['정보', '오늘', '자막', '오타', '띄어쓰기', '엉망'],
#  ['순간', '인트로보', '만화', '채널'],
#  ['역시', '방구', '생각', '여기', '제일', '제품'],
#  ['애플', '이제', '옛날', '우려', '발전', '하자', '삼성', '성능', '업그레이드'],
#  ['브로',
#   '가용',
#   '장단점',
#   '브로',
#   '고민',
#   '금액',
#   '화면',
#   '크기',
#   '등등',
#   '갤럭시',
#   '성능',
#   '아이폰',
#   '괜찬을듯해',
#   '생각'],
#  ['오늘', '갤럭시', '사서'],
#  ['영상', '사람'],
#  ['방구', '인트'],
#  ['하얀색', '서브', '가로', '기대', '안해', '제일'],
#  ['처음', '배경음악', '무엇'],
#  ['메인', '서브'],
#  ['영상', '이제'],
#  ['사고', '미디어텍', '거르'],
#  ['페이', '오타'],
#  ['성능', '아이폰', '압살'],
#  ['나중', '리뷰'],
#  ['차이', '가격', '과도', '비교'],
#  ['아이폰', '롤토', '판하', '배터리', '와우'],
#  ['이형도', '인트', '가미'],
#  ['비교', '압살'],
#  ['아이폰'],
#  ['걀제'],
#  ['항상', '브금', '아시'],
#  ['과극', '비교'],
#  ['최대', '미디어텍', '차라리', '엑시노스'],
#  ['라인'],
#  ['비교'],
#  ['가성', '사망'],
#  ['비교'],
#  ['미디어텍', '때문'],
#  ['세컨', '아이폰'],
#  ['무슨', '비교'],
#  ['비교', '까비'],
#  ['비대', '아이폰', '저가', '게임', '게임'],
#  ['화면', '버튼', '갤럭시'],
#  ['빠뒤'],
#  ['항상',
#   '트래비스',
#   '유튜브',
#   '보고',
#   '이번',
#   '비교',
#   '대상',
#   '생각',
#   '듭니',
#   '가격',
#   '가라',
#   '체감',
#   '차이'],
#  ['부모님', '갤럭시', '어른', '사용', '적당'],
#  ['개월전', '해외', '중고', '최상급', '듀얼', '배그', '원활', '극한', '옵션', '화면'],
#  ['다음', '비교'],
#  ['아이폰',
#   '국대도',
#   '생각',
#   '화면',
#   '글케',
#   '아이폰',
#   '세대',
#   '아이폰',
#   '화면',
#   '크기',
#   '오히려',
#   '게임',
#   '화면비',
#   '도해',
#   '애초',
#   '진짜',
#   '화면'],
#  ['가폰', '엄마', '사라', '아이폰', '한번', '사용', '사람'],
#  ['유툽', '출고', '만이천원'],
#  ['벨벳', '출시', '사망', '기적', '이군'],
#  ['배터리', '갤럭시', '프로세서', '아이폰'],
#  ['성비'],
#  ['항상', '리뷰', '비교', '리뷰'],
#  ['갤럭시', '아이폰', '비교'],
#  ['아이폰', '용량'],
#  ['출시'],
#  ['삼숭', '시리즈', '살바', '샤오미', '포코', '폰등', '스팩'],
#  ['갤럭시'],
#  ['사용자', '십중팔구', '지갑', '케이스', '포인트', '될런'],
#  ['얼굴', '사진', '갑툭튀', '다행', '훈남', '리뷰', '테크', '리뷰', '방구', '실험실', '인정'],
#  ['이번', '아이폰', '타입', '산다'],
#  ['결제', '대신', '걀제', '오타'],
#  ['비교', '가격', '비교'],
#  ['아이폰'],
#  ['결론'],
#  ['리뷰'],
#  ['성능', '버벅이거', '사이트', '사람'],
#  ['비교', '불가'],
#  ['아이폰', '구리'],
#  ['세대'],
#  ['비교'],
#  ['보급', '삼성', '애플'],
#  ['갤럭시', '충전', '속도'],
#  ['아이폰', '세대', '가면', '구매', '예정', '아이폰'],
#  ['과거', '선불', '느낌'],
#  ['다음', '정도', '출고', '비교'],
#  ['비교'],
#  ['아이폰', '가로'],
#  ['살껄'],
#  ['프로세서', '무과', '느낌'],
#  ['카메라'],
#  ['비교', '비교', '게다가', '쿠팡', '정도', '가격', '부담', '통신사', '비교', '수준'],
#  ['가격', '준수', '가격', '보급', '비교', '요즘', '삼성', '보급', '토헤'],
#  ['취향', '차이', '갤럭시', '갤럭시', '아이폰', '아이폰'],
#  ['비교', '등급', '비교', '얼추'],
#  ['아이폰', '배터리', '실화'],
#  ['해도'],
#  ['어자피', '페이'],
#  ['아이폰', '잘못', '정보', '수정'],
#  ['애플', '입문', '평생', '루팡'],
#  ['유튜브', '촬영'],
#  ['이즈', '디스플레이'],
#  ['비교', '가격', '대가'],
#  ['삼성', '아이폰', '사면'],
#  ['아이폰',
#   '갤럭시',
#   '스펙',
#   '성능',
#   '부분',
#   '최고',
#   '프로세서',
#   '탑재',
#   '아이폰',
#   '도적',
#   '승리',
#   '결과',
#   '갤럭시',
#   '배터리',
#   '페이',
#   '사람'],
#  ['아이폰'],
#  ['아이폰', '가라'],
#  ['화면', '배터리', '단점', '프로세서', '단점', '배터리'],
#  ['부모님', '세대', '사용', '기능'],
#  ['결론', '스마트폰', '삼성', '갤럭시', '통해', '가격', '산다', '이득'],
#  ['아이폰', '가야', '브로'],
#  ...]

# %% [markdown]
# ## word2vec
# - 중심단어와 주변단어 벡터의 내적이 코사인 유사도가 되도록 단어를 벡터
#     공간에 임베딩(배치) 한다.
#
# - min_count  = 몇 이하로 등장하는 단어 제외
# - workers = 몇코어 쓸건지
# - iter = 몇번 학습하라는건지
# - window =  주변의 단어를 몇개로 볼것인지
# - size = 몇차원으로 할것인지
# - 학습 차원의 크기
# 일반적으로 100-300을 사용한다. 최소한의 정확도를 얻기 위해서는 50차원 이상은 사용해야한다고 생각한다. 만약 적은 차원을 선택하면 많은 차원에서 얻을 수 있는 특성들을 잃게될 수 있다. 훈련시간이 크게 중요하지 않다면 200차원을 권한다. 최상의 정확도는 300차원에서 얻어진다. 300차원 이상이면 학습시간이 늘어나는 것에 비해서 얻어지는 향상은 미미하다.

# %%
model = Word2Vec(vec, min_count=10,window=6,iter=50, size=200, sg=1) #skip-gram

model.wv.syn0.shape #w2v size  -> 45개의 단어가 200차원을 가지고 있음
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# (1693, 200)

# %%
#45개의 단어가 200차원으로 벡터화된 수치를 넣어줌
word_vectors = model.wv.syn0 # model.wv.vectors와 같은 값을 가짐
word_vectors
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
# array([[-0.00074854,  0.26282978,  0.45566377, ..., -0.05394634,
#          0.10587042,  0.09536416],
#        [ 0.54615635, -0.11760239,  0.32902753, ...,  0.00773853,
#         -0.14281456,  0.11257779],
#        [-0.09776734,  0.07172029, -0.03951255, ...,  0.07122423,
#         -0.23710962, -0.04703211],
#        ...,
#        [-0.12960827, -0.04355733,  0.01447977, ...,  0.39886054,
#         -0.03749514,  0.01608958],
#        [ 0.1618641 ,  0.34329778, -0.35288525, ..., -0.02241052,
#         -0.04746927, -0.06961648],
#        [-0.00592769,  0.02876071,  0.1810827 , ...,  0.09892049,
#         -0.01209091, -0.15708315]], dtype=float32)

# %%
num_clusters = 6 #cluster의 갯수 산정
kmeans_clustering = KMeans( n_clusters = num_clusters )#default
idx = kmeans_clustering.fit_predict( word_vectors ) #각 단어가 어떤 군집에 속하는지 확인
idx
# Out:
# array([0, 0, 0, ..., 3, 3, 4])

# %%
# 각 어휘 단어를 클러스터 번호에 매핑되게 word/Index 사전을 만든다.
idx = list(idx)
names = model.wv.index2word #학습된 단어들 unique
word_centroid_map = {names[i]: idx[i] for i in range(len(names))}#각 단어 별로 클러스터 번호에 매칭
print(names)
# Out:
# ['영상', '진짜', '리뷰', '아이폰', '가격', '사용', '보고', '생각', '제품', '오늘', '인트', '보드', '성능', '정말', '애플', '벨벳', '그냥', '삼성', '항상', '역시', '정도', '디자인', '사람', '프로', '세대', '때문', '구매', '이번', '하나', '노트북', '정보', '카메라', '기능', '지금', '게임', '비교', '배터리', '인텔', '엘지', '갤럭시', '리안', '이제', '요즘', '인치', '추천', '아이패드', '고민', '혹시', '가성', '가요', '산다', '케이스', '화면', '차이', '느낌', '한번', '모델', '처음', '공기청정기', '다른', '맥북', '다이슨', '문제', '바로', '댓글', '오버', '오케이', '출시', '노트', '소리', '설명', '컴퓨터', '다시', '다음', '구독', '성조', '계속', '스피커', '업데이트', '부분', '유튜브', '이유', '지원', '인트로', '최고', '에어', '건가', '라이', '뭔가', '조금', '누나', '가지', '이상', '방구', '민성', '스마트폰', '광고', '존버', '코어', '매력', '두목', '충전', '인식', '기본', '구석', '대박', '이건', '시간', '마스크', '완전', '독자', '기대', '이어폰', '거의', '편집', '작업', '테스트', '경우', '가장', '무선', '모니터', '예전', '방법', '제일', '마음', '구입', '형님', '사랑', '얼마나', '언제', '우리', '감사', '레드', '얼마', '축하', '사고', '핸드폰', '나비', '별로', '짝퉁', '개인', '제발', '목소리', '친구', '시리즈', '프레임', '추가', '설정', '채널', '마우스', '버전', '유저', '시작', '기기', '여기', '렌즈', '네이버', '촬영', '점점', '게이', '도움', '참고', '와이파이', '사양', '보기', '에어팟', '어디', '모드', '쿨러', '사진', '티비', '화이팅', '회사', '중고', '화이트', '매직', '아주', '동영상', '이벤트', '온도', '얼굴', '기술', '안드로이드', '고생', '디스플레이', '사서', '꿀팁', '장점', '덕분', '선택', '색상', '용량', '사실', '마리', '엣지', '단점', '스펙', '해도', '사면', '정리', '속도', '응원', '워치', '썸네일', '잇츠', '윈도우', '이해', '버튼', '소음', '발열', '크롬', '프로그램', '관심', '이면', '보급', '유튜버', '사운드', '자주', '일단', '흑우', '언니', '태블릿', '위해', '라이트', '소식', '이름', '크기', '컨텐츠', '말씀', '원래', '서울', '실제', '유선', '상태', '나중', '혁키', '스크린', '조명', '제대로', '사용자', '자체', '무엇', '차라리', '무조건', '내용', '기분', '무슨', '마이크', '듀얼', '휴대폰', '중국', '클럭', '옛날', '그거', '수준', '일반', '조립', '코로나', '화질', '견적', '그래픽카드', '베젤', '녹음', '라이브', '중간', '설치', '활용', '누가', '갑자기', '마지막', '쓰기', '맥프로', '플래그', '필요', '연결', '터치', '학교', '당첨', '만능', '미니', '소개', '확인', '한국', '카드', '기준', '거기', '충전기', '볼때', '용도', '암드', '적용', '와우', '불칸', '페이', '매번', '질문', '모습', '안경', '페이스', '무게', '코드', '엠알님', '플러스', '맥북프로', '결론', '샤오미', '패드', '공기', '혁키님', '세상', '할인', '공부', '어플', '부터', '소비자', '메인보드', '최적화', '이용', '크게', '그래픽', '맛집', '주문', '구글', '대비', '스마트', '업글', '라면', '감상', '해결', '약간', '오프닝', '스킨', '케이블', '매우', '처럼', '자동', '모두', '감성', '지문', '추억', '자료', '관련', '기존', '다행', '여러분', '순간', '맥북에어', '인터넷', '메모리', '하루', '최대', '절대', '걱정', '벌써', '보이', '모든', '울트라', '효과', '엄마', '발전', '브랜드', '웃기', '현재', '대한', '시청', '말방규', '방송', '남자', '부탁', '강화유리', '액정', '블루투스', '업그레이드', '직접', '커버', '교체', '신경', '자꾸', '지메일', '가끔', '어제', '연기', '사전예약', '환경', '필름', '해외', '음악', '수업', '옵션', '블랙', '라인업', '이나', '진심', '필터', '통화', '자막', '관짝', '폴더', '사려', '포기', '공유', '기억', '패널', '공유기', '성비', '글카', '프린터', '테슬라', '소프트웨어', '데스크탑', '그대로', '링크', '아이', '노래', '학생', '대체', '굳이', '검색', '국내', '의미', '가능', '가면', '수가', '기계', '레노버', '하나요', '제목', '물건', '슈퍼', '머리', '썬더볼트', '다만', '필기', '저런', '이형', '장난', '전력', '초반', '블루', '만족', '온라인', '누구', '테크', '고급', '티셔츠', '아래', '판매', '색깔', '베가', '신성', '방식', '포함', '시장', '초기', '이야기', '대부분', '고려', '맥스', '는걸', '기회', '건강', '대신', '뽐뿌', '개선', '전면', '아이디', '대해', '그게', '사이즈', '포트', '센서', '이군', '사과', '그때', '선생님', '벤치', '라인', '영어', '현상', '좀더', '만약', '최근', '실험', '내장', '예정', '로고', '역대', '아아', '등등', '보안', '노치', '인정', '살짝', '거리', '프리미엄', '저걸', '작년', '시대', '그램', '갤탭', '쏙쏙', '보스', '모바일', '호환', '전부', '탑재', '메리트', '보조', '기도', '구성', '현실', '서브', '미리', '잘못', '박스', '얘기', '키노트', '그것', '어차피', '다운', '통해', '관리', '전원', '사지', '알림', '실망', '이하', '센스', '하트', '준비', '영화', '메인', '일체', '무료', '몇번', '영상편집', '드네', '직구', '파워', '보통', '해주시', '컴터', '취향', '가즈', '저번', '조절', '보시', '부품', '퀄리티', '방수', '배그', '사기', '장비', '후기', '쓰레기', '청소', '기업', '개월', '스타', '부모님', '색감', '이분', '재미', '단자', '공감', '솜사탕', '최신', '데이터', '금제', '예상', '입장', '전자기기', '선물', '배송', '강의', '나름', '펀치', '수고', '그림', '조루', '노션', '음질', '체감', '고정', '브로', '오히려', '거지', '이후', '최강', '이전', '저기', '홍보', '에디', '가용', '실화', '개봉', '다가', '케이', '소켓', '수도', '달라', '컨셉', '전혀', '상황', '고장', '통신사', '레전드', '지역', '오타', '더욱', '입문', '오른쪽', '당장', '안보', '아이언', '업로드', '주로', '매일', '동안', '상이', '책상', '루머', '플레이', '메일', '찾기', '저희', '비율', '아수스', '최소', '아웃', '얼른', '갈수록', '농협', '녹투', '재생', '프로세서', '듣기', '안해', '제작', '시기', '의견',  ...

# %%
for cluster in range(0,6):
    # 클러스터 번호를 출력
    print("\nCluster {}".format(cluster))
    
    # 클러스터번호와 클러스터에 있는 단어를 찍는다.
    words = []
    for i in range(0,len(list(word_centroid_map.values()))): #list(dict)키 값만 리스트로 반환
        #list(dict.values)는 value값이 리스트로 반환
        if( list(word_centroid_map.values())[i] == cluster ):
            words.append(list(word_centroid_map.keys())[i])
    print(words)
# Out:
# Cluster 0
# ['영상', '진짜', '리뷰', '보고', '오늘', '인트', '정말', '항상', '역시', '정보', '리안', '이제', '요즘', '한번', '처음', '댓글', '오케이', '설명', '다시', '구독', '계속', '인트로', '최고', '뭔가', '누나', '방구', '민성', '광고', '매력', '두목', '대박', '시간', '완전', '독자', '기대', '이어폰', '편집', '예전', '사랑', '우리', '감사', '레드', '축하', '나비', '목소리', '채널', '시작', '렌즈', '점점', '도움', '보기', '화이팅', '이벤트', '얼굴', '고생', '꿀팁', '덕분', '응원', '썸네일', '잇츠', '관심', '유튜버', '언니', '소식', '컨텐츠', '서울', '유선', '나중', '혁키', '조명', '무엇', '기분', '옛날', '코로나', '라이브', '중간', '누가', '갑자기', '마지막', '당첨', '만능', '소개', '볼때', '와우', '모습', '안경', '코드', '엠알님', '혁키님', '맛집', '감상', '오프닝', '감성', '추억', '다행', '하루', '벌써', '엄마', '발전', '웃기', '말방규', '방송', '남자', '자꾸', '지메일', '연기', '진심', '자막', '노래', '수가', '제목', '머리', '이형', '테크', '티셔츠', '신성', '기회', '건강', '이군', '역대', '아아', '인정', '살짝', '쏙쏙', '미리', '센스', '하트', '준비', '몇번', '영상편집', '해주시', '가즈', '보시', '퀄리티', '장비', '이분', '재미', '전자기기', '선물', '브로', '저기', '홍보', '가용', '케이', '컨셉', '레전드', '매일', '상이', '메일', '저희', '갈수록', '듣기', '제작', '아이디어', '전자', '여자', '당신', '와중', '장인', '언박싱', '드론', '세계', '왤케', '오우', '이메일', '중독', '골드', '앞머리', '상보', '어머니', '참여', '로그', '창고', '상상', '텐션', '아시', '주시', '끝판', '인생', '노력', '아이템', '삼양', '조만간', '발음', '기네', '하이', '어그', '듀말', '드립', '자랑', '교수', '가방', '엠알', '씨디', '꿀잼', '브금', '숙제', '레트로', '적응', '만이', '주말', '오지', '아닠', '요청', '실버', '썸넬', '아침', '오오오오', '누님', '분위기', '전설', '우왕', '진행', '회수', '집중', '런가', '팩트', '실험실', '평소', '버들', '일찍', '유투', '치킨', '안뇽', '가게', '알람', '간만', '트공', '아빠', '포인트', '완료', '새벽', '졸라', '도대체', '말투', '열쓰님', '태형', '박하', '그린', '인상', '기원', '하하', '생활', '표정', '형도', '리얼', '방금', '지도', '협찬', '여윽시', '왜케', '브이', '홈쇼핑', '핵심', '유튜버들', '연락', '주소', '웃음', '외국', '튜버', '당황', '여행', '개그', '미모', '만우절', '나비야', '체험', '전문가', '인사', '딴트공', '평일', '스타일', '성공', '이외', '콜라보', '아들', '답글', '드라마', '정성', '안녕', '셔츠', '스카이', '유니콘', '두부', '감동', '프로젝트', '활동', '가전', '잠시', '자리', '아저씨', '아버지', '유의', '인트롴', '프라다', '한참', '뭐얔', '핑크', '니콘', '크리에이터', '딕션', '졸귀', '펀쿨섹좌', '클라스', '운동', '콘텐츠', '착용', '엠알형', '동전', '선셋', '플루', '깜짝', '살이', '공개', '골뱅이', '유튜', '이자', '병맛', '실력', '군대', '거짓말', '성장', '꾸욱', '전달', '엡손', '천재', '보벳', '가발', '공원', '사골', '일루', '주신', '배속', '오빠', '평생', '땡큐', '투표', '엉엉', '생일', '어머', '외모', '진리', '대리', '사투리', '모자', '존경', '헤헤', '모음', '바지', '프라이드', '시청료', '지고', '유플러스', '클릭', '능이', '소통', '전자제품', '타고', '이안', '듀마레', '파이팅', '생방', '확대', '와이프', '드뎌', '동물', '배우', '보구', '비밀', '결혼', '튜바', '추카', '앱손', '뿜뿜', '거꾸로', '덕트', '가슴', '대세', '민우', '벤츠', '설리']
#
# Cluster 1
# ['사용', '유튜브', '구석', '마스크', '작업', '경우', '가장', '방법', '추가', '설정', '네이버', '와이파이', '아주', '동영상', '엣지', '해도', '속도', '윈도우', '크롬', '프로그램', '자주', '내용', '설치', '활용', '학교', '용도', '매번', '질문', '공부', '어플', '이용', '해결', '자동', '자료', '인터넷', '시청', '가끔', '음악', '수업', '공유', '공유기', '데스크탑', '그대로', '링크', '아이', '학생', '검색', '온라인', '이야기', '아이디', '대해', '선생님', '영어', '현상', '모바일', '현실', '키노트', '다운', '통해', '알림', '영화', '무료', '데이터', '강의', '그림', '노션', '고정', '전혀', '상황', '지역', '더욱', '입문', '업로드', '주로', '플레이', '재생', '여러', '교육', '경험', '비번', '브라우저', '넷플릭스', '파일', '제공', '사이트', '해당', '로만', '음영', '신분', '출력', '부팅', '아이콘', '신청', '기반', '확장', '무한', '숫자', '오류', '정상', '인강', '포토샵', '동시', '메시', '요새', '문서', '여러가지', '버그', '해제', '카톡', '실행', '마침', '웹서핑', '변경', '번역', '업무', '하나로', '유튭', '유투브', '아마', '프린트', '단축', '암호', '페이지', '미디어', '라디오', '생산', '시도', '인지', '문자', '유료', '저장', '메모', '개꿀', '웨일', '우선', '한가지', '또한', '대학생', '엑셀', '학습', '하니', '도전', '한글', '각도', '다리', '과학', '편의', '계정', '체크', '서로', '잠깐', '다운로드', '연동', '신세계', '종종', '로지', '생기', '교사', '마소', '발생', '위주', '시험', '개학', '과제', '각각', '원격', '달리', '메뉴', '안테나', '대상', '기간', '도착', '번호', '어어', '작성', '링크시스', '파워포인트', '삭제', '비밀번호', '혜택', '라운드', '스텀', '폰트', '복사', '간섭', '발견', '로딩', '일일이', '사무실', '내내', '스팀', '타이핑', '답장', '실시간', '개념', '우마', '특정', '증상', '문제점', '몇몇', '코딩', '반복', '버젼', '방향키', '상승', '주식', '화장실', '루마', '퓨전']
#
# Cluster 2
# ['가격', '생각', '제품', '보드', '성능', '그냥', '정도', '사람', '세대', '게임', '비교', '인텔', '가성', '차이', '문제', '오버', '컴퓨터', '성조', '이유', '라이', '가지', '이상', '코어', '이건', '거의', '테스트', '얼마나', '별로', '개인', '프레임', '유저', '게이', '참고', '사양', '쿨러', '회사', '온도', '선택', '마리', '스펙', '정리', '이해', '소음', '발열', '이면', '실제', '상태', '클럭', '수준', '조립', '견적', '그래픽카드', '필요', '기준', '암드', '불칸', '결론', '부터', '소비자', '메인보드', '그래픽', '대비', '업글', '라면', '매우', '메모리', '모든', '브랜드', '커버', '교체', '신경', '환경', '라인업', '관짝', '포기', '성비', '글카', '굳이', '의미', '가면', '레노버', '슈퍼', '다만', '전력', '초반', '시장', '고려', '그게', '그때', '벤치', '라인', '좀더', '프리미엄', '저걸', '시대', '메리트', '기도', '구성', '잘못', '얘기', '그것', '어차피', '이하', '일체', '드네', '파워', '보통', '컴터', '취향', '부품', '배그', '스타', '공감', '예상', '나름', '수고', '체감', '오히려', '거지', '최강', '이전', '다가', '소켓', '아이언', '찾기', '최소', '농협', '녹투', '프로세서', '시기', '간다', '베이스', '아무', '개발', '거나', '로스', '자기', '멀티', '사업', '향상', '아예', '결과', '게다가', '대충', '비용', '지식', '인기', '사수', '목적', '정신', '파이', '시스템', '만원', '분명', '잘만', '베터리', '애즈락', '전용', '존재', '전체', '대가', '이득', '저가', '상위', '평가', '시점', '부담', '불량', '무용', '존나', '하드', '경쟁', '엘리트', '도마', '유지', '대장', '스냅', '마크', '던데', '본인', '요약', '당시', '라데온', '조합', '마초', '로써', '안나', '효율', '어우', '편이', '어찌', '욕심', '무시', '듭니', '전문', '가형', '이드', '저건', '투자', '조사', '구조', '조건', '안정', '점수', '공간', '쓰레드', '수냉', '원부', '구형', '셋팅', '신제품', '나머지', '로서', '하이엔드', '개발자', '쿼드코어', '언급', '변화', '사장', '방어', '공랭', '유니', '스트레스', '나은', '깡패', '드라이버', '지뢰', '메이플', '가나', '오버클럭', '일부', '구리', '판단', '불가', '용이', '게이밍', '측정', '본적', '가치', '증가', '뽑기', '실사', '사망', '로드', '기가바이트', '본체', '슬슬', '호환성', '쿨링', '아쉬움', '대중', '의문', '서버', '라서', '엔비디아', '데탑', '가도', '만해', '제외', '대기업', '안정화', '한계', '스레드', '컬러풀', '갯수', '마찬가지', '부하', '재활용', '구분', '고성능', '프리미어', '바이오', '상관', '테라', '단순', '바이오스', '경쟁력', '다크', '장사', '저리', '금붕어', '팀킬', '저하', '전기', '소모', '가능성', '최악', '우려', '등급', '표기', '슬롯', '장착', '헤르츠', '국민', '몬헌', '부스트', '와트', '영향', '시퓨', '어쌔신', '프라임', '강제', '점유', '기록', '확률', '절감', '적자', '타이밍', '기어', '포지션', '여서', '불만', '녀석', '순위', '사시', '두번째', '웨이', '따라서', '순정', '완성', '마스터', '부자', '물리', '피드백', '긱바', '저렴', '지인', '번영', '공냉', '링스', '불가능', '진작', '리기', '전압', '부가', '에드', '박아', '높이', '일반인', '그레이드', '요구', '노답', '오토', '하위', '바보', '시피', '리가', '카본', '워낙', '행복', '함정', '카트', '양심', '수치', '신동', '격차', '게이머']
#
# Cluster 3
# ['때문', '산다', '공기청정기', '다이슨', '기술', '위해', '말씀', '제대로', '공기', '세상', '스킨', '걱정', '효과', '필름', '필터', '프린터', '테슬라', '저런', '누구', '센서', '실험', '거리', '관리', '청소', '솜사탕', '수도', '안보', '먼지', '에어컨', '유리', '바퀴', '필수', '제거', '가습기', '세차', '가정', '혼자', '바람', '선풍기', '나노', '가족', '수명', '품질', '수염', '청소기', '유행', '자신', '집안', '외계인', '여름', '모토로라', '표현', '청정기', '보호', '합리', '방지', '위치', '바이러스', '냄새', '레이저', '인테리어', '제모', '부산', '작품', '면서', '표시', '가전제품', '능력', '주의', '장면', '만큼', '프린터기', '검은색', '미세먼지', '인간', '지갑', '등록', '피부', '압도', '보지', '이기', '손가락', '기적', '시절', '시국', '어머님', '주행', '창문', '노래방', '대한민국', '동네', '가까이', '흡입', '오토파일럿', '심플', '최대한', '신뢰', '요소', '멀리', '강아지', '레이', '방광', '인물', '방향', '단계', '코팅', '오라', '차선', '유막', '마다', '구현', '효도', '비염', '고양이', '차량', '음식', '거실', '알뜰', '운전', '미로', '도구', '주지', '자국', '만하', '일주일', '대화', '논란', '검정색', '조도', '믿음', '휴게소', '왁스', '행위', '세차장']
#
# Cluster 4
# ['프로', '구매', '이번', '노트북', '지금', '인치', '추천', '아이패드', '고민', '혹시', '가요', '케이스', '모델', '맥북', '바로', '출시', '다음', '에어', '건가', '존버', '기본', '모니터', '구입', '형님', '언제', '얼마', '사고', '제발', '친구', '마우스', '여기', '에어팟', '어디', '중고', '화이트', '매직', '사서', '사실', '사면', '일단', '흑우', '맥프로', '미니', '확인', '한국', '플러스', '맥북프로', '할인', '주문', '케이블', '관련', '여러분', '순간', '맥북에어', '절대', '부탁', '강화유리', '업그레이드', '직접', '어제', '사전예약', '해외', '옵션', '이나', '사려', '기억', '국내', '하나요', '물건', '썬더볼트', '필기', '장난', '만족', '고급', '판매', '포함', '대부분', '맥스', '는걸', '뽐뿌', '사이즈', '예정', '등등', '작년', '그램', '갤탭', '호환', '보조', '서브', '사지', '직구', '저번', '사기', '후기', '개월', '부모님', '배송', '개봉', '통신사', '오타', '당장', '동안', '아수스', '얼른', '안해', '약정', '상품', '나스', '가로', '후회', '답변', '키보', '과연', '해상도', '미국', '애초', '인스타', '가야', '플렉스', '로직', '실수', '에이', '동생', '사이', '요금', '팔고', '청량', '최저', '마케팅', '쿠팡', '설마', '트랙패드', '버즈', '다나', '스튜디오', '중이', '수리', '출고', '발표', '살수', '제로', '먼저', '호구', '삼각대', '올해', '예약', '밴드', '자급', '산지', '정발', '결정', '공식', '카페', '사도', '알리', '쿠폰', '읍니', '화웨이', '금액', '탈출', '갤럭시탭', '아이맥', '흐흐', '서피스', '계열', '취소', '품절', '로지텍', '매장', '이온', '손해', '공짜', '취미', '직원', '브라더', '아보', '무리', '구경', '내년', '이슈', '사라', '오픈', '분해', '텐키', '계획', '투명', '실용', '정품', '체티', '살때', '유심', '지름신', '가가', '웁니', '내일', '며칠', '호갱', '가입', '환불', '뜬금', '결제', '승리', '종이', '업체', '다해', '팀쿡', '대기', '폴리오', '매빅', '아마존', '개통', '보임', '조언', '커뮤니티', '렌더링', '려고', '장단점', '덜덜', '정가', '키감', '자동차', '욕구', '닉스', '박격포', '퀀텀', '후반', '생태계', '한성', '파이널컷', '유출', '문의', '세트', '자마자', '살돈', '신형', '코스트코', '의자', '차이점', '원금', '스팩', '지난', '공홈', '기변', '한지', '고등학생', '반값', '리퍼', '짐벌', '익스', '겨우', '출시일', '상용', '남아', '기만', '어이', '프레', '어서', '파컷', '푸른', '용기', '젠장', '박살', '메이트']
#
# Cluster 5
# ['아이폰', '애플', '벨벳', '삼성', '디자인', '하나', '카메라', '기능', '배터리', '엘지', '갤럭시', '화면', '느낌', '다른', '노트', '소리', '스피커', '업데이트', '부분', '지원', '조금', '스마트폰', '충전', '인식', '무선', '제일', '마음', '핸드폰', '짝퉁', '시리즈', '버전', '기기', '촬영', '모드', '사진', '티비', '안드로이드', '디스플레이', '장점', '색상', '용량', '단점', '워치', '버튼', '보급', '사운드', '태블릿', '라이트', '이름', '크기', '원래', '스크린', '사용자', '자체', '차라리', '무조건', '무슨', '마이크', '듀얼', '휴대폰', '중국', '그거', '일반', '화질', '베젤', '녹음', '쓰기', '플래그', '연결', '터치', '카드', '거기', '충전기', '적용', '페이', '페이스', '무게', '샤오미', '패드', '최적화', '크게', '구글', '스마트', '약간', '처럼', '모두', '지문', '기존', '최대', '보이', '울트라', '현재', '대한', '액정', '블루투스', '블랙', '통화', '폴더', '패널', '소프트웨어', '대체', '가능', '기계', '블루', '아래', '색깔', '베가', '방식', '초기', '대신', '개선', '전면', '포트', '사과', '만약', '최근', '내장', '로고', '보안', '노치', '보스', '전부', '탑재', '박스', '전원', '실망', '메인', '조절', '방수', '쓰레기', '기업', '색감', '단자', '최신', '금제', '입장', '펀치', '조루', '음질', '이후', '에디', '실화', '달라', '고장', '오른쪽', '책상', '루머', '비율', '아웃', '의견', '미디어텍', '충격', '펜슬', '물방울', '주변', '플립', '쓰시', '배경화면', '우리나라', '모양', '엑시노스', '배경', '빅스', '노크', '이미지', '작동', '왼쪽', '전화', '업뎃', '팬택', '중소기업', '위로', '은근', '안드', '녹화', '밝기', '하드웨어', '제한', '외부', '휴대', '된거', '인증', '일이', '칩셋', '더블', '소니', '앱등이', '심지어', '붙이', '실물', '폴드', '엘쥐', '방진', '컬러', '세로', '리스', '수정', '버벅', '입력', '리모컨', '하단', '잉크', '번인', '미노트', '리모콘', '금방', '처리', '강조', '서비스', '야간', '몇개', '음성', '불편', '타입', '칭찬', '눈물', '마이크로', '무거워', '인덕션', '타임', '쿼드', '반응', '미래', '픽셀', '패치', '패스', '실패', '그동안', '도로', '마감', '구멍', '센터', '덱스', '재부팅', '일본', '혁신', '통신', '흰색', '별도', '내부', '야외', '중국산', '카카오', '하자', '오디오', '시계', '무지개', '어댑터', '일부러', '스냅드래곤', '장만', '안전', '알뜰폰', '쿼드덱', '때매', '배젤', '글라스', '마치', '커서', '이정', '점도', '선호', '매스', '판매량', '초점', '인피니티', '전환', '반대', '단말', '보이지', '프라다폰', '스위치', '규격', '테블릿', '정책', '네이비', '작고', '간지', '컨트롤', '거치', '스토리', '지지', '스티커', '차별', '나이키', '블랙스크린', '외관', '정식', '비트', '악세사리', '측면', '패턴', '하라', '빨간색', '용서', '후지', '과거', '먹통', '백라이트', '그닥', '셀카', '고문', '포커', '모듈', '시리', '치명', '뮤직', '종류', '전기차', '상단', '미지', '백도어', '글래스', '소프트', '보정', '고속', '선녀', '레벨', '볼륨', '플라스틱', '제어', '보아', '대략', '대여', '캘리포니아', '불구', '나라', '대안', '해킹', '궁금', '두께', '공장', '식이', '대형', '장소', '카툭', '살바', '손목', '롤러', '퍼센트', '지능', '모서리', '요전', '일상', '마트', '어케', '번역기', '초음파', '보관']

# %%
words
# Out:
# ['아이폰',
#  '애플',
#  '벨벳',
#  '삼성',
#  '디자인',
#  '하나',
#  '카메라',
#  '기능',
#  '배터리',
#  '엘지',
#  '갤럭시',
#  '화면',
#  '느낌',
#  '다른',
#  '노트',
#  '소리',
#  '스피커',
#  '업데이트',
#  '부분',
#  '지원',
#  '조금',
#  '스마트폰',
#  '충전',
#  '인식',
#  '무선',
#  '제일',
#  '마음',
#  '핸드폰',
#  '짝퉁',
#  '시리즈',
#  '버전',
#  '기기',
#  '촬영',
#  '모드',
#  '사진',
#  '티비',
#  '안드로이드',
#  '디스플레이',
#  '장점',
#  '색상',
#  '용량',
#  '단점',
#  '워치',
#  '버튼',
#  '보급',
#  '사운드',
#  '태블릿',
#  '라이트',
#  '이름',
#  '크기',
#  '원래',
#  '스크린',
#  '사용자',
#  '자체',
#  '차라리',
#  '무조건',
#  '무슨',
#  '마이크',
#  '듀얼',
#  '휴대폰',
#  '중국',
#  '그거',
#  '일반',
#  '화질',
#  '베젤',
#  '녹음',
#  '쓰기',
#  '플래그',
#  '연결',
#  '터치',
#  '카드',
#  '거기',
#  '충전기',
#  '적용',
#  '페이',
#  '페이스',
#  '무게',
#  '샤오미',
#  '패드',
#  '최적화',
#  '크게',
#  '구글',
#  '스마트',
#  '약간',
#  '처럼',
#  '모두',
#  '지문',
#  '기존',
#  '최대',
#  '보이',
#  '울트라',
#  '현재',
#  '대한',
#  '액정',
#  '블루투스',
#  '블랙',
#  '통화',
#  '폴더',
#  '패널',
#  '소프트웨어',
#  '대체',
#  '가능',
#  '기계',
#  '블루',
#  '아래',
#  '색깔',
#  '베가',
#  '방식',
#  '초기',
#  '대신',
#  '개선',
#  '전면',
#  '포트',
#  '사과',
#  '만약',
#  '최근',
#  '내장',
#  '로고',
#  '보안',
#  '노치',
#  '보스',
#  '전부',
#  '탑재',
#  '박스',
#  '전원',
#  '실망',
#  '메인',
#  '조절',
#  '방수',
#  '쓰레기',
#  '기업',
#  '색감',
#  '단자',
#  '최신',
#  '금제',
#  '입장',
#  '펀치',
#  '조루',
#  '음질',
#  '이후',
#  '에디',
#  '실화',
#  '달라',
#  '고장',
#  '오른쪽',
#  '책상',
#  '루머',
#  '비율',
#  '아웃',
#  '의견',
#  '미디어텍',
#  '충격',
#  '펜슬',
#  '물방울',
#  '주변',
#  '플립',
#  '쓰시',
#  '배경화면',
#  '우리나라',
#  '모양',
#  '엑시노스',
#  '배경',
#  '빅스',
#  '노크',
#  '이미지',
#  '작동',
#  '왼쪽',
#  '전화',
#  '업뎃',
#  '팬택',
#  '중소기업',
#  '위로',
#  '은근',
#  '안드',
#  '녹화',
#  '밝기',
#  '하드웨어',
#  '제한',
#  '외부',
#  '휴대',
#  '된거',
#  '인증',
#  '일이',
#  '칩셋',
#  '더블',
#  '소니',
#  '앱등이',
#  '심지어',
#  '붙이',
#  '실물',
#  '폴드',
#  '엘쥐',
#  '방진',
#  '컬러',
#  '세로',
#  '리스',
#  '수정',
#  '버벅',
#  '입력',
#  '리모컨',
#  '하단',
#  '잉크',
#  '번인',
#  '미노트',
#  '리모콘',
#  '금방',
#  '처리',
#  '강조',
#  '서비스',
#  '야간',
#  '몇개',
#  '음성',
#  '불편',
#  '타입',
#  '칭찬',
#  '눈물',
#  '마이크로',
#  '무거워',
#  '인덕션',
#  '타임',
#  '쿼드',
#  '반응',
#  '미래',
#  '픽셀',
#  '패치',
#  '패스',
#  '실패',
#  '그동안',
#  '도로',
#  '마감',
#  '구멍',
#  '센터',
#  '덱스',
#  '재부팅',
#  '일본',
#  '혁신',
#  '통신',
#  '흰색',
#  '별도',
#  '내부',
#  '야외',
#  '중국산',
#  '카카오',
#  '하자',
#  '오디오',
#  '시계',
#  '무지개',
#  '어댑터',
#  '일부러',
#  '스냅드래곤',
#  '장만',
#  '안전',
#  '알뜰폰',
#  '쿼드덱',
#  '때매',
#  '배젤',
#  '글라스',
#  '마치',
#  '커서',
#  '이정',
#  '점도',
#  '선호',
#  '매스',
#  '판매량',
#  '초점',
#  '인피니티',
#  '전환',
#  '반대',
#  '단말',
#  '보이지',
#  '프라다폰',
#  '스위치',
#  '규격',
#  '테블릿',
#  '정책',
#  '네이비',
#  '작고',
#  '간지',
#  '컨트롤',
#  '거치',
#  '스토리',
#  '지지',
#  '스티커',
#  '차별',
#  '나이키',
#  '블랙스크린',
#  '외관',
#  '정식',
#  '비트',
#  '악세사리',
#  '측면',
#  '패턴',
#  '하라',
#  '빨간색',
#  '용서',
#  '후지',
#  '과거',
#  '먹통',
#  '백라이트',
#  '그닥',
#  '셀카',
#  '고문',
#  '포커',
#  '모듈',
#  '시리',
#  '치명',
#  '뮤직',
#  '종류',
#  '전기차',
#  '상단',
#  '미지',
#  '백도어',
#  '글래스',
#  '소프트',
#  '보정',
#  '고속',
#  '선녀',
#  '레벨',
#  '볼륨',
#  '플라스틱',
#  '제어',
#  '보아',
#  '대략',
#  '대여',
#  '캘리포니아',
#  '불구',
#  '나라',
#  '대안',
#  '해킹',
#  '궁금',
#  '두께',
#  '공장',
#  '식이',
#  '대형',
#  '장소',
#  '카툭',
#  '살바',
#  '손목',
#  '롤러',
#  '퍼센트',
#  '지능',
#  '모서리',
#  '요전',
#  '일상',
#  '마트',
#  '어케',
#  '번역기',
#  '초음파',
#  '보관']

# %%
# 현재 작업하는 클러스터의 모델명 지정 및 저장
model_name = 'Beaut_M_10W_6'
model.save(model_name)

mpl.rcParams['axes.unicode_minus'] = False
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
X = model[vocab]
print(len(X))
print(X[0][:10])
tsne = TSNE(n_components=2)
# Out:
# 1693
# [ 0.04671257 -0.29330188  0.36007586  0.5000033   0.1728026  -0.01895967
#   0.5518517  -0.38951236 -0.60131407 -0.11637925]
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
# 100개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:100,:])
# X_tsne = tsne.fit_transform(X)

df = pd.DataFrame(X_tsne, index=vocab[:100], columns=['x', 'y'])
df.shape
# Out:
# (100, 2)

# %%
df
# Out:
#                x           y
# 윈도우    44.470680   91.476097
# 지금    -26.906500   36.745564
# 업데이트 -126.462227  -69.482651
# 도구     29.112673   36.711998
# 다운로드   38.398403   55.253239
# ...          ...         ...
# 보고    -19.141907   -5.427667
# 컨셉    -79.581413   45.337685
# 일체    -19.579990  112.641479
# 관심     56.755657 -115.356567
# 때문    -47.878017   13.306992
#
# [100 rows x 2 columns]

# %%
fig = plt.figure()
fig.set_size_inches(20, 20)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
plt.show()

# %%
# 150개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:150,:])
# X_tsne = tsne.fit_transform(X)

df = pd.DataFrame(X_tsne, index=vocab[:150], columns=['x', 'y'])
df.shape
# Out:
# (150, 2)

# %%
df.head(10)
# Out:
#                 x           y
# 윈도우    -18.016823  -86.482239
# 지금     -21.932318  -41.118500
# 업데이트  -137.721375    5.629502
# 도구       2.895757  -32.277939
# 다운로드     7.238663  -45.787769
# 업그레이드  -73.593056   45.554241
# 차이점     41.936172  -36.012459
# 설치     -31.371130 -100.435387
# 버전      85.219521  -67.808823
# 최신      48.626431  -73.989243

# %%
fig = plt.figure()
fig.set_size_inches(20, 20)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=15)
plt.show()

# %%
model.most_similar('벨벳')
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('물방울', 0.41694754362106323),
#  ('일루', 0.4143184423446655),
#  ('선셋', 0.3953391909599304),
#  ('엘지', 0.3942118287086487),
#  ('용기', 0.37726759910583496),
#  ('지메일', 0.36972713470458984),
#  ('노치', 0.36822476983070374),
#  ('유출', 0.3607909083366394),
#  ('듀마레', 0.3533651530742645),
#  ('네이비', 0.34872138500213623)]

# %%
model.most_similar('코로나')
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('바이러스', 0.4936356544494629),
#  ('평일', 0.3668171763420105),
#  ('시기', 0.34689241647720337),
#  ('엠알', 0.34481358528137207),
#  ('비염', 0.3342677354812622),
#  ('노래방', 0.32560884952545166),
#  ('군대', 0.32496190071105957),
#  ('당첨', 0.32439908385276794),
#  ('덕트', 0.3239538371562958),
#  ('시점', 0.32300078868865967)]

# %%
model.most_similar('벨벳')
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('물방울', 0.41694754362106323),
#  ('일루', 0.4143184423446655),
#  ('선셋', 0.3953391909599304),
#  ('엘지', 0.3942118287086487),
#  ('용기', 0.37726759910583496),
#  ('지메일', 0.36972713470458984),
#  ('노치', 0.36822476983070374),
#  ('유출', 0.3607909083366394),
#  ('듀마레', 0.3533651530742645),
#  ('네이비', 0.34872138500213623)]

# %%
print(model.most_similar(positive = ["제품","엘지"])[5])
print(model.most_similar(positive = ["벨벳","엘지"])[7])
# Out:
# ('중국산', 0.34781497716903687)
# ('고문', 0.3698788583278656)
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).

# %%
model.most_similar(positive = ["벨벳","성능"])
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('일루', 0.3943178653717041),
#  ('바이오', 0.3916250467300415),
#  ('쓰레드', 0.39081525802612305),
#  ('경쟁력', 0.3837761878967285),
#  ('팀킬', 0.37669479846954346),
#  ('스냅드래곤', 0.37402504682540894),
#  ('매스', 0.37243273854255676),
#  ('선셋', 0.3647623360157013),
#  ('지메일', 0.36431169509887695),
#  ('실물', 0.3625694811344147)]

# %%
model.similarity('코로나', '제품')
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similarity` (Method will be removed in 4.0.0, use self.wv.similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.18997702

# %%
# 현재 작업하는 클러스터의 모델명 지정 및 저장
model_name = 'Beaut_M_10W_6'
model.save(model_name)

mpl.rcParams['axes.unicode_minus'] = False
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
X = model[vocab]
print(len(X))
print(X[0][:10])
tsne = TSNE(n_components=3)

# %%
# 100개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:1693,:])
# X_tsne = tsne.fit_transform(X)

df = pd.DataFrame(X_tsne, index=vocab[:1693], columns=['x', 'y','z'])
df.shape
df

# %%
from sklearn.datasets import make_swiss_roll
from plotly.offline import plot
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# %%
# X, t = make_swiss_roll(n_samples=1000, noise=0)
# color = (t - t.min()) / (t.max() - t.min())

# %%
df_list = list(df.index)
df_list

# %%
X, t = make_swiss_roll(n_samples=1000, noise=0)
color = (t - t.min()) / (t.max() - t.min())

# %%
data = go.Scatter3d(
    x=df['x'],
    y=df['y'],
    z=df['z'],
    text = df_list,
    mode='markers',
   
    marker=dict(
        size=3,
        color=color,
        colorscale='Jet',
        line=dict(
            #color='rgba(217, 217, 217, 0.14)',
            #color='rgb(217, 217, 217)',
            width=0.0
        ),
        opacity=0.8
    )
)

layout = go.Layout(
    autosize=False,
    width=1000,
    height=1000,
    margin=go.Margin(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
    #paper_bgcolor='#7f7f7f',
    #plot_bgcolor='#c7c7c7'
)

# %%
fig = go.Figure(data=[data], layout=layout)
# iplot(fig)

# %%
from plotly.offline import plot
plot(fig, filename='plotly-3d-scatter-small_4.html', auto_open=True)

# %%
fig = go.Figure(data=[data1, data2, data3], layout=layout)
fig = plt.figure()
fig.set_size_inches(20, 20)
ax = fig.add_subplot(1, 1, 1)

# ax.scatter(df['x'], df['y'],df['z'])
plotly
for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
import csv
from os import listdir
from os.path import isfile, join

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

handles = []
colors = ['blue', 'red']

X1 = cluster 0
Y1 = list(range(10))
Z1 = list(range(10))

random.shuffle(X1)
random.shuffle(Y1)
random.shuffle(Z1)

scatter1 = ax.scatter(X1, Y1, Z1, c = colors[0], marker = 'o')

random.shuffle(X1)
random.shuffle(Y1)
random.shuffle(Z1)

scatter2 = ax.scatter(X1, Y1, Z1, c = colors[1], marker = 'v')

ax.set_xlabel('X', fontsize = 10)
ax.set_ylabel('Y', fontsize = 10)
ax.set_zlabel('Z', fontsize = 10)

ax.legend([scatter1, scatter2], ['label1', 'label2'])

plt.show()

# %%
scatter1_proxy = mpl.lines.Line2D([0],[0], linestyle="none", c=colors[0], marker = 'o')
scatter2_proxy = mpl.lines.Line2D([0],[0], linestyle="none", c=colors[1], marker = 'v')
ax.legend([scatter1_proxy, scatter2_proxy], ['label1', 'label2'], numpoints = 1)

# %%
scatter1_proxy

# %%
scatter2_proxy

# %%
ax
