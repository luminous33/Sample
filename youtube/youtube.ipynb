# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import folium
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from konlpy.tag import Twitter # 바뀌기 전의 이름
from konlpy.tag import Okt  # 바뀐 이름
from konlpy.corpus import kolaw
import nltk

font_name = fm.FontProperties(fname='C:/windows/Fonts/malgun.ttf').get_name()
plt.rc('font',family =font_name)
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

# %%
youtube = pd.read_csv('./Hyojin/Hyojin_info.csv',encoding='euc-kr',index_col= 'name')
youtube
youtube.columns
#youtube = youtube.loc[youtube['view'].str.contains('만회',na=False)]

views = []
for i in youtube['view']:
    if '만회' in i :
        views.append(float(i.split('만회')[0])*10000)
    elif '천회' in i:
        views.append(float(i.split('천회')[0])*1000)
    elif '회' in i :
        views.append(float(i.split('회')[0]))
        
youtube['조회수']= views

youtube['조회수'].astype('int')
youtube['조회수']= youtube['조회수'].astype('int')

comment1=[]
for i in youtube['comment']:
    i = (i.split(' ')[1].split('개')[0])
    if ',' in i:
        i = i.split(',')[0]+i.split(',')[1]
    
    comment1.append(int(i))    
    
comment1
youtube['댓글수']= comment1

like =[]
for i in youtube['likes_num']:
    if '만개' in i :
        like.append(float(i.split('만개')[0])*10000)
    elif '천개' in i:
        like.append(float(i.split('천개')[0])*1000)
    elif '개' in i :
        like.append(float(i.split('개')[0]))
    
like
youtube['좋아요수'] = like
youtube['좋아요수'] = youtube['좋아요수'].astype('int')

unlike =[]
for i in youtube['unlikes_num']:
    if '만개' in i :
        unlike.append(float(i.split('만개')[0])*10000)
    elif '천개' in i:
        unlike.append(float(i.split('천개')[0])*1000)
    elif '개' in i :
        unlike.append(float(i.split('개')[0]))
    
unlike
youtube['싫어요수']=unlike
youtube['싫어요수']=youtube['싫어요수']

time = []
for i in youtube['time_duration']:
    a=int(i.split('\n')[1].split(':')[0])
    b= int(i.split('\n')[1].split(':')[1])
    time.append((60*a)+b)
youtube['영상길이']= time

del youtube['time_duration']
del youtube['video_url']
del youtube['thumbnail']
del youtube['Unnamed: 0']
del youtube['view']
del youtube['previous_time']
del youtube['start_date']
del youtube['comment']
del youtube['likes_num']
del youtube['unlikes_num']
youtube
# Out:
#                                                         조회수   댓글수   좋아요수  \
# name
# 이게 바로 사회적 거리두기 효진쓰 생일파티...?? (feat.미역국 만들기)          110000   164   2500
# ?? 피부가 투명해지는 청순 메이크업 ??: MLBB MAKEUP                 160000   255   3300
# 막걸리 마시면서 Q&A :: 조효진은 어떤사람인가? 그리고 고민상담                240000   349   5200
# (ENG) 홍대언니 메이크업 + 흥??이 올라도, 무너지지 않는 본격 영혼 갈아넣은 ...   290000  1258   6100
# ??효진쓰 2020년 목표 챌린지 브이로그?? :: 첫 영어회화 수업?? + 화실에서...   100000   167   1900
# 오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH ...   240000   443   5300
# Asian Baby Girl (ABG) Transformation Makeup?:: ...   290000   504   8800
# 조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라...   140000   218   2700
# (ENG) 인생샷? 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) ::...   410000   561   8400
# 남의 집에서 살아남기...... (Feat.짧게 룸투어, 캔들 만들기, 홈카페, 머릿...   160000   180   2400
# (eng) 같은사람 맞음?! 분위기 난리나는 핑크 메이크업 (feat.피지&유분 잡는...  1310000  1338  29000
# ??봄을 위한 우아한 청초 메이크업?? (feat.중도포기&노렌즈) :: Natura...   300000   531   5700
# 조파파...다시 재취업하다....(feat.임용 1년만에 붙은 썰)                250000   306   4300
# ??봄맞이 누드립 메이크업?? :: MLBB MAKEUP                      400000   699   9100
# 1일 1깡 (1일차)                                          290000  1123   6900
# 집에서 할 수 있는 모든것을 해보는 브이로그.... (feat.진지하게 춤연습, 달고...   230000   579   3900
# 이게 바로 날것 그대로의 조효진 브이로그.                              210000   464   3800
# ??봄나들이 못가서 미치기 일보 직전 메이크업??  :: Spring Red Makeup    370000   537   6500
# 아무것도 위로 되지 못할 때 위로가 되어주는 팝송모음??                      110000   254   3600
# 이불 속 나에게 들려주는 음악 :: 효진쓰 인생 플레이리스트??                   99000   154   3200
#
#                                                      싫어요수  영상길이
# name
# 이게 바로 사회적 거리두기 효진쓰 생일파티...?? (feat.미역국 만들기)          43.0  1162
# ?? 피부가 투명해지는 청순 메이크업 ??: MLBB MAKEUP                 38.0   383
# 막걸리 마시면서 Q&A :: 조효진은 어떤사람인가? 그리고 고민상담                48.0  1657
# (ENG) 홍대언니 메이크업 + 흥??이 올라도, 무너지지 않는 본격 영혼 갈아넣은 ...  114.0  1289
# ??효진쓰 2020년 목표 챌린지 브이로그?? :: 첫 영어회화 수업?? + 화실에서...   23.0  1215
# 오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH ...  112.0  1618
# Asian Baby Girl (ABG) Transformation Makeup?:: ...   73.0   321
# 조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라...   25.0  1203
# (ENG) 인생샷? 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) ::...  103.0  1325
# 남의 집에서 살아남기...... (Feat.짧게 룸투어, 캔들 만들기, 홈카페, 머릿...   39.0  1402
# (eng) 같은사람 맞음?! 분위기 난리나는 핑크 메이크업 (feat.피지&유분 잡는...  492.0  1443
# ??봄을 위한 우아한 청초 메이크업?? (feat.중도포기&노렌즈) :: Natura...  113.0  1476
# 조파파...다시 재취업하다....(feat.임용 1년만에 붙은 썰)                49.0  1441
# ??봄맞이 누드립 메이크업?? :: MLBB MAKEUP                     115.0   267
# 1일 1깡 (1일차)                                         112.0    77
# 집에서 할 수 있는 모든것을 해보는 브이로그.... (feat.진지하게 춤연습, 달고...   45.0  1853
# 이게 바로 날것 그대로의 조효진 브이로그.                              57.0  1558
# ??봄나들이 못가서 미치기 일보 직전 메이크업??  :: Spring Red Makeup    91.0  1433
# 아무것도 위로 되지 못할 때 위로가 되어주는 팝송모음??                      20.0  2101
# 이불 속 나에게 들려주는 음악 :: 효진쓰 인생 플레이리스트??                  24.0  2794

# %%
youtube.corr()
# Out:
#            조회수       댓글수      좋아요수      싫어요수      영상길이
# 조회수   1.000000  0.879379  0.797386  0.798756  0.260720
# 댓글수   0.879379  1.000000  0.651813  0.671184  0.231829
# 좋아요수  0.797386  0.651813  1.000000  0.633507  0.025862
# 싫어요수  0.798756  0.671184  0.633507  1.000000 -0.032103
# 영상길이  0.260720  0.231829  0.025862 -0.032103  1.000000

# %%
a=['1,342','1,123','2,123']
a
b='1,234'
c= b.split(',')[0]+b.split(',')[1]
d=[1,2,3,4,5]
int(c)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
plt.figure(figsize=(10,10))
sns.heatmap(youtube[['조회수','댓글수',
                                  '좋아요수','싫어요수','영상길이']],
            annot=True,fmt= 'f',cmap='RdPu',linewidths =.5)

# %%
you = np.polyfit(youtube['댓글수'],youtube['조회수'],1)
u1= np.poly1d(you)
print(u1)
# Out:
#
# 715.9 x - 8616

# %%
plt.figure(figsize=(6,6))
plt.plot(youtube['좋아요수'],u1(youtube['좋아요수']),lw=3,color='g',
                               ls='dashed')
plt.xlabel('좋아요수')
plt.ylabel('영상길이')
plt.scatter(youtube['좋아요수'],youtube['영상길이'])
plt.grid()

# %%
sns.pairplot(youtube,vars=['좋아요수','조회수','싫어요수','영상길이','댓글수'],size= 4,kind='reg')
# Out:
# C:\Users\zmfkv\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
