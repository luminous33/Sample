# %%
import requests
from bs4 import BeautifulSoup
import time 
import urllib.request #
from selenium.webdriver import chrome
import re 
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request #
from selenium.webdriver import Chrome
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
start_url = 'https://www.youtube.com/channel/UC9kmlDcqksaOnCkC_qzGacA/featured'
#start_url = 'https://www.youtube.com/channel/UC9kmlDcqksaOnCkC_qzGacA/videos'

# %%
delay=3
browser = Chrome()
browser.implicitly_wait(delay)

# %%
browser.get(start_url)  
browser.maximize_window()

# %%
#동영상 클릭
browser.find_element_by_xpath('//*[@id="tabsContent"]/paper-tab[2]').click()

# %%
body = browser.find_element_by_tag_name('body')

# %%
body = browser.find_element_by_tag_name('body')#스크롤하기 위해 소스 추출

num_of_pagedowns = 5
#10번 밑으로 내리는 것
while num_of_pagedowns:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)
    num_of_pagedowns -= 1

# %%
html0 = browser.page_source

# %%
html = BeautifulSoup(html0,'html.parser')

# %%
html = BeautifulSoup(html0,'html.parser')

# %%
video_list0 = html.find('div',{'id':'items', 'class':'style-scope ytd-grid-renderer'})

# %%
print(video_list0)
# Out:
# <div class="style-scope ytd-grid-renderer" id="items"><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=SORLO6WAKm8" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/SORLO6WAKm8/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLDDUOfVJBp9L-MN7B57U3TuI4cYfg" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="19분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       19:22
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="이게 바로 사회적 거리두기 효진쓰 생일파티...🎉 (feat.미역국 만들기) 게시자: 조효진 HYOJIN 2일 전 19분 조회수 117,968회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=SORLO6WAKm8" id="video-title" title="이게 바로 사회적 거리두기 효진쓰 생일파티...🎉 (feat.미역국 만들기)">이게 바로 사회적 거리두기 효진쓰 생일파티...🎉 (feat.미역국 만들기)</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 11만회</span>
# <span class="style-scope ytd-grid-video-renderer">2일 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=UneZzf702aQ" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/UneZzf702aQ/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLD-d06vhW6hePJchVwEBYA_ePxZ2g" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="6분 23초" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       6:23
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="💎 피부가 투명해지는 청순 메이크업 💎: MLBB MAKEUP 게시자: 조효진 HYOJIN 3일 전 6분 23초 조회수 160,955회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=UneZzf702aQ" id="video-title" title="💎 피부가 투명해지는 청순 메이크업 💎: MLBB MAKEUP">💎 피부가 투명해지는 청순 메이크업 💎: MLBB MAKEUP</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 16만회</span>
# <span class="style-scope ytd-grid-video-renderer">3일 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=R2gmUCDRdg0" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/R2gmUCDRdg0/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLDKte2AKmkS9kPv9ubagy0HfuTZig" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="27분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       27:37
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="막걸리 마시면서 Q&amp;A :: 조효진은 어떤사람인가? 그리고 고민상담 게시자: 조효진 HYOJIN 1주 전 27분 조회수 245,403회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=R2gmUCDRdg0" id="video-title" title="막걸리 마시면서 Q&amp;A :: 조효진은 어떤사람인가? 그리고 고민상담">막걸리 마시면서 Q&amp;A :: 조효진은 어떤사람인가? 그리고 고민상담</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 24만회</span>
# <span class="style-scope ytd-grid-video-renderer">1주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=zimCBRlhJ9U" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/zimCBRlhJ9U/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLCantnBKdRFryLcXZa4y2LST13-cQ" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="21분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       21:29
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="(ENG) 홍대언니 메이크업 + 흥🔥이 올라도, 무너지지 않는 본격 영혼 갈아넣은 여름☀️ 베이스 메이크업 (+지속력 테스트) :: K-BEAUTY MAKEUP GRWM 게시자: 조효진 HYOJIN 1주 전 21분 조회수 290,454회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=zimCBRlhJ9U" id="video-title" title="(ENG) 홍대언니 메이크업 + 흥🔥이 올라도, 무너지지 않는 본격 영혼 갈아넣은 여름☀️ 베이스 메이크업 (+지속력 테스트) :: K-BEAUTY MAKEUP GRWM">(ENG) 홍대언니 메이크업 + 흥🔥이 올라도, 무너지지 않는 본격 영혼 갈아넣은 여름☀️ 베이스 메이크업 (+지속력 테스트) :: K-BEAUTY MAKEUP GRWM</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 29만회</span>
# <span class="style-scope ytd-grid-video-renderer">1주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" id="video-badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">자막</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=RZJM1ngE_cI" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/RZJM1ngE_cI/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAxSa9Pt5dkIX-d7WJAqzWE3Q_cXQ" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="20분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       20:15
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="🔥효진쓰 2020년 목표 챌린지 브이로그🔥 :: 첫 영어회화 수업✏️ + 화실에서 아크릴 그림 그리기🎨 도전... (feat.도전은 잘함.. 포기도 잘함..) 게시자: 조효진 HYOJIN 2주 전 20분 조회수 99,974회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=RZJM1ngE_cI" id="video-title" title="🔥효진쓰 2020년 목표 챌린지 브이로그🔥 :: 첫 영어회화 수업✏️ + 화실에서 아크릴 그림 그리기🎨 도전... (feat.도전은 잘함.. 포기도 잘함..)">🔥효진쓰 2020년 목표 챌린지 브이로그🔥 :: 첫 영어회화 수업✏️ + 화실에서 아크릴 그림 그리기🎨 도전... (feat.도전은 잘함.. 포기도 잘함..)</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 9.9만회</span>
# <span class="style-scope ytd-grid-video-renderer">2주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=mz5HG-51wHw" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/mz5HG-51wHw/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAe3kHjW6bJ8VMucMbZRN06kXIVQg" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="26분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       26:58
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH MY GIRL YOOAst MAKEUP 게시자: 조효진 HYOJIN 3주 전 26분 조회수 245,611회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=mz5HG-51wHw" id="video-title" title="오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH MY GIRL YOOAst MAKEUP">오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH MY GIRL YOOAst MAKEUP</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 24만회</span>
# <span class="style-scope ytd-grid-video-renderer">3주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=RGx2Rb7QPv4" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/RGx2Rb7QPv4/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLAIXQ5PCQPhzGBlPV4-R4B0--pCdQ" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="5분 21초" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       5:21
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="Asian Baby Girl (ABG) Transformation Makeup✨:: 힙한 인스타그램 셀카 메이크업 게시자: 조효진 HYOJIN 3주 전 5분 21초 조회수 293,904회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=RGx2Rb7QPv4" id="video-title" title="Asian Baby Girl (ABG) Transformation Makeup✨:: 힙한 인스타그램 셀카 메이크업">Asian Baby Girl (ABG) Transformation Makeup✨:: 힙한 인스타그램 셀카 메이크업</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 29만회</span>
# <span class="style-scope ytd-grid-video-renderer">3주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=T0drPtRrwOg" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/T0drPtRrwOg/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLCa7tUED_LDnZLPbNDlWYzax-huNQ" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="20분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       20:03
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라디오 사은품 / 요즘 사용하는 입욕제 게시자: 조효진 HYOJIN 4주 전 20분 조회수 145,335회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=T0drPtRrwOg" id="video-title" title="조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라디오 사은품 / 요즘 사용하는 입욕제">조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라디오 사은품 / 요즘 사용하는 입욕제</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 14만회</span>
# <span class="style-scope ytd-grid-video-renderer">4주 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=946308a1lzI" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition" ftl-eligible="" loaded="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" src="https://i.ytimg.com/vi/946308a1lzI/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&amp;rs=AOn4CLCBxFFyqiHmv3dO_dpZIHmZop5n9w" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="22분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       22:05
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="(ENG) 인생샷✨ 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) :: HOLIDAY MAKEUP WITH SUBS 게시자: 조효진 HYOJIN 1개월 전 22분 조회수 410,996회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=946308a1lzI" id="video-title" title="(ENG) 인생샷✨ 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) :: HOLIDAY MAKEUP WITH SUBS">(ENG) 인생샷✨ 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) :: HOLIDAY MAKEUP WITH SUBS</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 41만회</span>
# <span class="style-scope ytd-grid-video-renderer">1개월 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" id="video-badges"><!--css-build:shady-->
# <div class="badge badge-style-type-simple style-scope ytd-badge-supported-renderer">
# <yt-icon class="style-scope ytd-badge-supported-renderer" disable-upgrade="" hidden="">
# </yt-icon>
# <span class="style-scope ytd-badge-supported-renderer">자막</span>
# </div>
# <dom-repeat as="badge" class="style-scope ytd-badge-supported-renderer" id="repeat"><template is="dom-repeat"></template></dom-repeat>
# </ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# ...
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=oul4XxcLTxY" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="23분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       23:21
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="조효진 결혼?! 👰🏻❤️ 웨딩촬영 메이크업 같이 준비해요...! :: SELF WEDDING MAKEUP GWRAM 게시자: 조효진 HYOJIN 1년 전 23분 조회수 347,976회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=oul4XxcLTxY" id="video-title" title="조효진 결혼?! 👰🏻❤️ 웨딩촬영 메이크업 같이 준비해요...! :: SELF WEDDING MAKEUP GWRAM">조효진 결혼?! 👰🏻❤️ 웨딩촬영 메이크업 같이 준비해요...! :: SELF WEDDING MAKEUP GWRAM</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 34만회</span>
# <span class="style-scope ytd-grid-video-renderer">1년 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=7wL36zcYvb0" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="16분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       16:30
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="(안보면 땅을치고 후회함) 아니 100원인데 왜안사?! 올리브영 역.대.급 할인템 다알랴줌!!!!!! 게시자: 조효진 HYOJIN 1년 전 16분 조회수 216,332회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=7wL36zcYvb0" id="video-title" title="(안보면 땅을치고 후회함) 아니 100원인데 왜안사?! 올리브영 역.대.급 할인템 다알랴줌!!!!!!">(안보면 땅을치고 후회함) 아니 100원인데 왜안사?! 올리브영 역.대.급 할인템 다알랴줌!!!!!!</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 21만회</span>
# <span class="style-scope ytd-grid-video-renderer">1년 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer><ytd-grid-video-renderer class="style-scope ytd-grid-renderer" lockup=""><!--css-build:shady--><div class="style-scope ytd-grid-video-renderer" id="dismissable"><ytd-thumbnail class="style-scope ytd-grid-video-renderer" use-hovered-property=""><!--css-build:shady-->
# <a aria-hidden="true" class="yt-simple-endpoint inline-block style-scope ytd-thumbnail" href="/watch?v=MRWnv0CTJKg" id="thumbnail" rel="null" tabindex="-1">
# <yt-img-shadow class="style-scope ytd-thumbnail no-transition empty" ftl-eligible="" style="background-color: transparent;"><!--css-build:shady--><img alt="" class="style-scope yt-img-shadow" id="img" width="210"/></yt-img-shadow>
# <div class="style-scope ytd-thumbnail" id="overlays"><ytd-thumbnail-overlay-time-status-renderer class="style-scope ytd-thumbnail" overlay-style="DEFAULT"><!--css-build:shady--><yt-icon class="style-scope ytd-thumbnail-overlay-time-status-renderer" disable-upgrade="" hidden=""></yt-icon><span aria-label="15분" class="style-scope ytd-thumbnail-overlay-time-status-renderer">
#       15:14
#     </span></ytd-thumbnail-overlay-time-status-renderer><ytd-thumbnail-overlay-now-playing-renderer class="style-scope ytd-thumbnail"><!--css-build:shady-->
# <span class="style-scope ytd-thumbnail-overlay-now-playing-renderer">지금 재생 중</span>
# </ytd-thumbnail-overlay-now-playing-renderer></div>
# <div class="style-scope ytd-thumbnail" id="mouseover-overlay"></div>
# <div class="style-scope ytd-thumbnail" id="hover-overlays"></div>
# </a>
# </ytd-thumbnail><div class="style-scope ytd-grid-video-renderer" id="details"><div class="style-scope ytd-grid-video-renderer" id="meta"><h3 class="style-scope ytd-grid-video-renderer"><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden=""></ytd-badge-supported-renderer><a aria-label="My Summer Nudy Makeup (with subs) 나만의 여름 누디 메이크업 👑 게시자: 조효진 HYOJIN 1년 전 15분 조회수 442,238회" class="yt-simple-endpoint style-scope ytd-grid-video-renderer" href="/watch?v=MRWnv0CTJKg" id="video-title" title="My Summer Nudy Makeup (with subs) 나만의 여름 누디 메이크업 👑">My Summer Nudy Makeup (with subs) 나만의 여름 누디 메이크업 👑</a></h3><div class="grid style-scope ytd-grid-video-renderer" id="metadata-container" meta-block=""><div class="style-scope ytd-grid-video-renderer" id="metadata"><div class="style-scope ytd-grid-video-renderer" hidden="" id="byline-container"><ytd-channel-name class="style-scope ytd-grid-video-renderer" id="channel-name"><!--css-build:shady-->
# <div class="style-scope ytd-channel-name" id="container">
# <div class="style-scope ytd-channel-name" id="text-container">
# <yt-formatted-string class="style-scope ytd-channel-name" ellipsis-truncate="" id="text" title=""></yt-formatted-string>
# </div>
# <paper-tooltip class="style-scope ytd-channel-name" fit-to-visible-bounds="" offset="10" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
# </div>
# </paper-tooltip>
# </div>
# <ytd-badge-supported-renderer class="style-scope ytd-channel-name" disable-upgrade="" hidden="">
# </ytd-badge-supported-renderer>
# </ytd-channel-name></div><div class="style-scope ytd-grid-video-renderer" id="metadata-line">
# <span class="style-scope ytd-grid-video-renderer">조회수 44만회</span>
# <span class="style-scope ytd-grid-video-renderer">1년 전</span>
# <dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div><div class="style-scope ytd-grid-video-renderer" id="additional-metadata-line"><dom-repeat class="style-scope ytd-grid-video-renderer" strip-whitespace=""><template is="dom-repeat"></template></dom-repeat></div></div></div><ytd-badge-supported-renderer class="style-scope ytd-grid-video-renderer" disable-upgrade="" hidden="" id="video-badges"></ytd-badge-supported-renderer><div class="style-scope ytd-grid-video-renderer" id="menu"><ytd-menu-renderer class="style-scope ytd-grid-video-renderer"><!--css-build:shady-->
# <div class="style-scope ytd-menu-renderer" id="top-level-buttons"></div>
# <yt-icon-button class="dropdown-trigger style-scope ytd-menu-renderer" id="button"><!--css-build:shady--><button aria-label="작업 메뉴" class="style-scope yt-icon-button" id="button">
# <yt-icon class="style-scope ytd-menu-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M12 8c1.1 0 2-.9 2-2s-.9-2-2-2-2 .9-2 2 .9 2 2 2zm0 2c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm0 6c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path>
# </g></svg><!--css-build:shady-->
# </yt-icon>
# </button></yt-icon-button>
# </ytd-menu-renderer></div></div><div class="style-scope ytd-grid-video-renderer" id="buttons"></div></div><div class="style-scope ytd-grid-video-renderer" id="dismissed"><div class="style-scope ytd-grid-video-renderer" id="dismissed-content"></div></div></ytd-grid-video-renderer></div>

# %%
base_url = 'http://www.youtube.com'

# %%
video_list2 = video_list0.find_all('ytd-grid-video-renderer',{'class':'style-scope ytd-grid-renderer'})

# %%
for div in video_list2:
       print(div.text)
# Out:
#       19:22
#
# 지금 재생 중
#
#
#
#
# 이게 바로 사회적 거리두기 효진쓰 생일파티...🎉 (feat.미역국 만들기)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 11만회
# 2일 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       6:23
#
# 지금 재생 중
#
#
#
#
# 💎 피부가 투명해지는 청순 메이크업 💎: MLBB MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 16만회
# 3일 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       27:37
#
# 지금 재생 중
#
#
#
#
# 막걸리 마시면서 Q&A :: 조효진은 어떤사람인가? 그리고 고민상담
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 24만회
# 1주 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:29
#
# 지금 재생 중
#
#
#
#
# (ENG) 홍대언니 메이크업 + 흥🔥이 올라도, 무너지지 않는 본격 영혼 갈아넣은 여름☀️ 베이스 메이크업 (+지속력 테스트) :: K-BEAUTY MAKEUP GRWM
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 29만회
# 1주 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       20:15
#
# 지금 재생 중
#
#
#
#
# 🔥효진쓰 2020년 목표 챌린지 브이로그🔥 :: 첫 영어회화 수업✏️ + 화실에서 아크릴 그림 그리기🎨 도전... (feat.도전은 잘함.. 포기도 잘함..)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 9.9만회
# 2주 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       26:58
#
# 지금 재생 중
#
#
#
#
# 오마이걸 유아st 아이돌 메이크업 (feat.비브라스 광채쿠션 신상리뷰) :: OH MY GIRL YOOAst MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 24만회
# 3주 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       5:21
#
# 지금 재생 중
#
#
#
#
# Asian Baby Girl (ABG) Transformation Makeup✨:: 힙한 인스타그램 셀카 메이크업
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 29만회
# 3주 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       20:03
#
# 지금 재생 중
#
#
#
#
# 조파파...화보촬영 하다... / 아크릴 미술 도전(?) 화방 구경가기 / 레트로 라디오 사은품 / 요즘 사용하는 입욕제
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 14만회
# 4주 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:05
#
# 지금 재생 중
#
#
#
#
# (ENG) 인생샷✨ 건지는 홈파티 메이크업 (feat.웨이크메이크 신상 리뷰!) :: HOLIDAY MAKEUP WITH SUBS
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 41만회
# 1개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:22
#
# 지금 재생 중
#
#
#
#
# 남의 집에서 살아남기...... (Feat.짧게 룸투어, 캔들 만들기, 홈카페, 머릿결 관리)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 16만회
# 1개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:03
#
# 지금 재생 중
#
#
#
#
# (eng) 같은사람 맞음?! 분위기 난리나는 핑크 메이크업 (feat.피지&유분 잡는 스킨케어 루틴) :: MOOD PINK MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 131만회
# 1개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:36
#
# 지금 재생 중
#
#
#
#
# 🌷봄을 위한 우아한 청초 메이크업🌷 (feat.중도포기&노렌즈) :: Natural Glow Makup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 30만회
# 1개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:01
#
# 지금 재생 중
#
#
#
#
# 조파파...다시 재취업하다....(feat.임용 1년만에 붙은 썰)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 25만회
# 1개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       4:27
#
# 지금 재생 중
#
#
#
#
# 🖤봄맞이 누드립 메이크업🖤 :: MLBB MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 40만회
# 1개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       1:17
#
# 지금 재생 중
#
#
#
#
# 1일 1깡 (1일차)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 29만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       30:53
#
# 지금 재생 중
#
#
#
#
# 집에서 할 수 있는 모든것을 해보는 브이로그.... (feat.진지하게 춤연습, 달고나커피, 줌바스, 수플레오믈렛, 아이패드, 브런치)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 23만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       25:58
#
# 지금 재생 중
#
#
#
#
# 이게 바로 날것 그대로의 조효진 브이로그.
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 21만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:53
#
# 지금 재생 중
#
#
#
#
# 🌸봄나들이 못가서 미치기 일보 직전 메이크업🌸  :: Spring Red Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 37만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       35:01
#
# 지금 재생 중
#
#
#
#
# 아무것도 위로 되지 못할 때 위로가 되어주는 팝송모음🌙
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 11만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       46:34
#
# 지금 재생 중
#
#
#
#
# 이불 속 나에게 들려주는 음악 :: 효진쓰 인생 플레이리스트🎧
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 9.9만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       29:37
#
# 지금 재생 중
#
#
#
#
# 자발적 집순이가 강제 집순이가 되면 일어나는일.....(feat.아이패드 어플 소개, 요즘 즐겨보는 유튜브 채널)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 27만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       9:39
#
# 지금 재생 중
#
#
#
#
# 인생 증명사진📷 메이크업하고 지하철역 증명사진 찍어봄. (feat.난리나는 꿀팁)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 21만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:35
#
# 지금 재생 중
#
#
#
#
# 본격 집안에서 살아남기...(feat.왜 쨔미쓰 인가요? & 시리지옥)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 28만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       34:29
#
# 지금 재생 중
#
#
#
#
# 집나간 흥도 돌아온다는 전설의 플레이리스트 (for.집구석관종)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 18만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:44
#
# 지금 재생 중
#
#
#
#
# 피부 열감!🔥 마스크! 요즘 같이 자극 많이 받는날을 위한 라벤더 퍼플 메이크업 💜:: Lavender Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 32만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:09
#
# 지금 재생 중
#
#
#
#
# 본격 집콕 들어가기 전 일상들...치과 임플란트, 오랜만에 네일샵, 그리고 가열(?)요리
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 19만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:26
#
# 지금 재생 중
#
#
#
#
# 🌷블링블링 청순 아이돌st 메이크업🌷 (feat.클리오 ⚡️신상⚡️ 원브랜드 메이크업) :: K-pop Star Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 53만회
# 2개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:47
#
# 지금 재생 중
#
#
#
#
# (eng) 그냥 문때고 비비면 ⭐️쉐딩 마스터⭐️ 가능?! (with.쉐딩여왕 홍현희슨생님)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 101만회
# 3개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       27:26
#
# 지금 재생 중
#
#
#
#
# (eng) 조효진 취향 10000% 들어간 인스타그램 메이크업 :: Instagram Model Makeup with subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 44만회
# 3개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       26:17
#
# 지금 재생 중
#
#
#
#
# 인생 흘러가는대로....조효진의 24시간 밀착 브이로그 (feat.갑분 책상 위 아이템 소개하기)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 24만회
# 3개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       10:44
#
# 지금 재생 중
#
#
#
#
# 아빠가 드디어 메이크업 더빙 해줬습니다. (feat.역시 뷰티유튜버의 조파파) :: makeup dubbed by daddy
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 43만회
# 3개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       26:23
#
# 지금 재생 중
#
#
#
#
# 조효진네 가족 👕관종 티셔츠👕 입고 여행하기... 가족여행은 발리가 최고네요.
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 22만회
# 4개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:06
#
# 지금 재생 중
#
#
#
#
# 동일인물 맞음?! 2020년 첫 단발로 자르고 촉촉레드립 메이크업 같이 준비해요💄
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 139만회
# 4개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:09
#
# 지금 재생 중
#
#
#
#
# ‼️조효진의 인생을 바꿔준 삶의 질 향상템 대공개‼️
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 40만회
# 4개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:17
#
# 지금 재생 중
#
#
#
#
# 2020년 계획 세우기(+쨔미쓰), 조파파와 시장 장보기, 효진쓰 새해기념 단발(?)... 2019년 마지막 브이로그!
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 22만회
# 5개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:18
#
# 지금 재생 중
#
#
#
#
# 🎄친구들과 소소하고 시끄러운 크리스마스&연말 파티 브이로그.🎄 (+몰래 쨔미쓰 선물🎁 준비하기)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 28만회
# 5개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:37
#
# 지금 재생 중
#
#
#
#
# 드디어 가족 완전체 첫여행!✈️ , 여행가서도 아이패드 드로잉, 역대급 조촐한 캐리어와 짐싸기(+여행에서도 그림자룩...^^)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 22만회
# 5개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:31
#
# 지금 재생 중
#
#
#
#
# 연말에 하기 딱 좋은 노렌즈 + 청순고급 메이크업. (feat.렌즈 없이 눈커지는 방법) :: Daily Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 40만회
# 5개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:00
#
# 지금 재생 중
#
#
#
#
# 자퇴한 대학생과 은퇴한 아빠의 브이로그.
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 31만회
# 5개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       27:04
#
# 지금 재생 중
#
#
#
#
# 이보다 화려할 수 없다...연말파티 ✨시.선.집.중✨펄잔치 메이크업 (+ 연말파티 룩북) :: GLITTER MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 36만회
# 5개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       32:43
#
# 지금 재생 중
#
#
#
#
# 7년차 복학생 조효진.. 결국 자퇴했습니다... (Feat.자퇴한 이유...)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 56만회
# 5개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:23
#
# 지금 재생 중
#
#
#
#
# ❗️S.O.S❗️ 생리 전, 피부 컨디션 최상으로 끌어올리는 메이크업 (with.생리) :: Blue Makeup GRWM with subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 44만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       20:24
#
# 지금 재생 중
#
#
#
#
# 조효진의 마지막 복학생 브이로그...그리고 조파파 결국 일 짤리다ㅠㅠㅠ
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 32만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:33
#
# 지금 재생 중
#
#
#
#
# 아싸 복학생 조효진의 그림자룩템 공유합니다. (Feat.오랜만에(?) 학교 도서관에서 독서^^...)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 27만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       28:12
#
# 지금 재생 중
#
#
#
#
# 노렌즈+흑발+레드립 그냥 끝남. :: Black Red Makeup GRWM
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 97만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:42
#
# 지금 재생 중
#
#
#
#
# 복학생 조효진의 중간고사 끝난 뒤 현타와 함께한 브이로그....(feat.번아웃 극복하는 영상)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 25만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       5:33
#
# 지금 재생 중
#
#
#
#
# 마! 이게 7년째 학교다니는 찐복학생 메이크업 아이가! (feat.유튜버 최초 그림자룩북)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 27만회
# 6개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:26
#
# 지금 재생 중
#
#
#
#
# 캐시야 무지개 다리 너머 잘 지내고있지? 12년동안 건강하게 지내줘서 고마워..
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 35만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       20:01
#
# 지금 재생 중
#
#
#
#
# 여러분들의 중간고사는 안녕하신가요....? (feat.복학생의 쓸쓸한 중간고사 준비)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 27만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       14:16
#
# 지금 재생 중
#
#
#
#
# 오랜만에 노.렌.즈 + 단발 메이크업 해봄. (feat.어퓨 신상쿠션 솔직리뷰! 가성비최고ㄷㄷ) :: Fall Brown Makeup with subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 52만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       12:50
#
# 지금 재생 중
#
#
#
#
# 유튜브 최신기능?! 유튜브에서 직접화장까지 해줌..;; 🖤레알 MAC언니 메이크업🖤 (with sub)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 26만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:51
#
# 지금 재생 중
#
#
#
#
# 아싸들의 특징:학교 빠지면 아무것도 모름.... (Feat.복학생 조효진에게 휴강공지 좀 해조라~!~!~!)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 49만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       17:45
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ|中文|わご） 꾸민듯 안꾸민듯 NO평범 안경 메이크업 (feat.투쿨포 신상쿠션 리뷰&나눔이벤트!) :: Not Ordinary Daily Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 29만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:02
#
# 지금 재생 중
#
#
#
#
# 중간고사,,다가온다,,, 복학생 조효진의 시험준비 워밍업 브이로그....(+취준생들의 뒷담화)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 42만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:27
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ) 이것이 진짜 깐달걀 촉촉💧 메이크업 같이 준비해요💙 （feat.요즘하는 수분케어 루틴) :: Glow Makeup GRWM
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 30만회
# 7개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       32:03
#
# 지금 재생 중
#
#
#
#
# 세상 열심히 사는척하는 복학생 브이로그. (feat.자퇴하고싶다. 종강아 어디야?)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 35만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       7:52
#
# 지금 재생 중
#
#
#
#
# 나의 간단한 가을룩북🍁🍂 (feat.캠퍼스룩&출근룩 그리고 나눔이벤트✨) :: MY FALL LOOKBOOK
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 13만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:06
#
# 지금 재생 중
#
#
#
#
# 이게 바로 복학생의 현실 대학 브이로그.....(feat.같은학교 구독자님과 밥먹은 썰, 다꾸에 빠진 효진쓰, 그림자룩)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 31만회
# 8개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       11:12
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ) ⚠️화장으로만 이게 가능하다고?!⚠️초간단 인스타갬성 가을 메이크업(Feat. 메이블린뉴욕 신상파데 솔직리뷰!) :  INSTAGRAM FALL MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 30만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:59
#
# 지금 재생 중
#
#
#
#
# 개강 전 경상도 화장쟁이의 하루✨ 요즘 듣는 플레이리스트, 커피 만들어 마시기, 오늘의 룩북❤️
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 14만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       16:56
#
# 지금 재생 중
#
#
#
#
# (ENG) 개.강.이.다!✨ 말린장미 메이크업 같이 준비해요!🥀 :: DRY ROSE GRWM WITH SUBS
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 40만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       34:03
#
# 지금 재생 중
#
#
#
#
# 복학했습니다. 7년째 졸업 못하고 있는 대학생 조효진의 일상. (feat.눈물의 크리미빵)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 47만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:29
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ) 🍁분위기갑 데일리 스모키 메이크업 (feat.살면서 가장 후회되는 것) 🍁:: DAILY MOOD MAKEUP
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 51만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:16
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ) 가을 복숭아 메이크업🍂🍁 같이 준비해요🍑 :: Dry Peach Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 44만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:04
#
# 지금 재생 중
#
#
#
#
# 8090년생들을 위한 싸이월드 bgm 추억팔이, 이모들! 오랜만에 복덩이 왔어요!, 쨔미쓰와 밥먹고 오락실, 유경씨와 뒹굴뒹굴...
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 17만회
# 8개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:01
#
# 지금 재생 중
#
#
#
#
# (Eng|Espñ) 2019년 첫가을은 나와 함께 준비해요🍁🍂(feat.조효진이 직접 드로잉한 파우치 선공개?!)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 68만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       20:36
#
# 지금 재생 중
#
#
#
#
# 어디에서도 절.대 들을 수 없는 꿀팁 대잔치 !! 이효리,공효진,이솜,손나은 담당 홍이모의 있는 그대로 큐앤에이🌵(모공/스킨케어/피부관리/인생템/베이스제품)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 15만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       30:50
#
# 지금 재생 중
#
#
#
#
# 안본사람 없게 해주세요..베이킹이 뭐죠?ㅋㅋㅋㅋㅋㅋ우리 왜한다고 그랬지?ㅋㅋㅋㅋ (feat.지옥에서 온 쿠키)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 26만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       26:15
#
# 지금 재생 중
#
#
#
#
# 역.대.급 펄잔치 메이크업 (feat.섀도우 팔레트 세.상.쉽.게 색조합 하는 방법!) :: Glitter Makeup
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 29만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:40
#
# 지금 재생 중
#
#
#
#
# ✈️한달에 한번 떠나는 여행쟁이들 같이 짐싸면서✨ 캐리어 & 파우치 털기 (feat.여행필수템, 최애선크림, 간단LA하울)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 16만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       33:22
#
# 지금 재생 중
#
#
#
#
# 유튜버 3명이 LA여행 가면 일어나는일❤️ (feat.효진&에바&희주 :: 트리플H 꿀잼주의!!💦)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 26만회
# 9개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       25:17
#
# 지금 재생 중
#
#
#
#
# 무더운 LA에서도 살아남는 데일리 워터프루프💦 메이크업 (feat.매트한 파데로 모공커버 잘 하는법) :: Waterproof Makeup GRWM with subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 31만회
# 9개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:29
#
# 지금 재생 중
#
#
#
#
# 엄마와 추억 쌓기❤️ 모녀여행 추천🌴 가족들이랑 추억 많이많이 가지기 브이로그 마지막!!!
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 14만회
# 10개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:06
#
# 지금 재생 중
#
#
#
#
# 조파파도 드디어 여행간다! 그.러.나 제주도 온지 3시간만에 바로 부산으로?!ㅠㅠ 부모님과 추억 쌓기 브이로그 1탄🌵
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 18만회
# 10개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       18:58
#
# 지금 재생 중
#
#
#
#
# 인스타갬성 인.생.샷 나오는 오렌지 메이크업 (feat.입생로랑 신상쿠션 솔직리뷰!!!!) :: Orange Makeup with Subs🍊
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 42만회
# 10개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       22:08
#
# 지금 재생 중
#
#
#
#
# 이모들 복덩이 드디어 집에 왔어요!(+깜짝파티) 그리고 경상도 똥쟁이 캐시와 산책 브이로그🌵
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 19만회
# 10개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       16:49
#
# 지금 재생 중
#
#
#
#
# (컨실러,톤업크림X) 조효진이 쌩.노.파.데 메이크업을 한다면?! with.모공쟁이+트러블자국+블랙헤드 ✨
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 90만회
# 10개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       34:49
#
# 지금 재생 중
#
#
#
#
# 이상한 이모들의 왕초보 육아 브이로그, 그림 어떻게 그려요? (+색쓰는법,영감은 어디서...,왕초보 그림교실) with.소현작가님 :: 조.있.그.브🌵
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 19만회
# 10개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       32:39
#
# 지금 재생 중
#
#
#
#
# 경상도 화장쟁이 드.디.어 이모 되다!👶🏻, 쨔미쓰와 조파파와 만남ㅋㅋㅋㅋㅋ어디에도 볼 수 없는 조합 브이로그
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 23만회
# 10개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       8:48
#
# 지금 재생 중
#
#
#
#
# 조효진이 노.렌.즈 메이크업을 한다면?! 여름철 뽀송 지속력 메이크업 ⚡️ :: Summer Makeu with subs🙌🏻
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 48만회
# 10개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       24:37
#
# 지금 재생 중
#
#
#
#
# 발리에서 생긴 일🔥/발리맛집+먹방 & 소소하게 쇼핑/묵었던 숙소🤟🏽
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 16만회
# 11개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       36:44
#
# 지금 재생 중
#
#
#
#
# (말JOLLA많음 주의) 얘들아..2년만이지..? 반말영상..준비했어...큐앤에이도있어... :: 여름 최소한으로만 메이크업!
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 30만회
# 11개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       19:28
#
# 지금 재생 중
#
#
#
#
# 오랜만에 모공,블랙헤드분들 안부인사🤟🏽 + 여름 바캉스 메이크업 같이 준비해요🖤🌴🖤 :: Summer Vacance Makeup with Subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 48만회
# 11개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       33:38
#
# 지금 재생 중
#
#
#
#
# 조.있.그.브🌴 :: 호캉스로 뒹굴뒹굴 보내는 하루, 그림도 그리고 한밤중에 파우치 털고 도쿄 행사로 마무리🤟🏽
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 21만회
# 11개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       31:56
#
# 지금 재생 중
#
#
#
#
# 3년만에 첫 팬미팅을..그리고 나에 대한 추측 Q&A.... (+여기서 쨔미쓰 생일선물 후기 풀어달라고요?! + 선물언박싱!!)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 18만회
# 11개월 전
#
#
#
#
# 자막
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       33:01
#
# 지금 재생 중
#
#
#
#
# 제주도에서 경상도 화장쟁이 이름 지어주신 어머님 만나고 옴 그리고 나만의 시간 갖기 (+요즘 읽는 책 추천)
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 18만회
# 11개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       21:19
#
# 지금 재생 중
#
#
#
#
# 여름에 딱! 어울리는 (+ 얼굴 비대칭 잡는 꿀팁) 메이크업 & 여름룩북 :: Summer Lookbook and Makeup with subs
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 19만회
# 11개월 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       23:21
#
# 지금 재생 중
#
#
#
#
# 조효진 결혼?! 👰🏻❤️ 웨딩촬영 메이크업 같이 준비해요...! :: SELF WEDDING MAKEUP GWRAM
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 34만회
# 1년 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       16:30
#
# 지금 재생 중
#
#
#
#
# (안보면 땅을치고 후회함) 아니 100원인데 왜안사?! 올리브영 역.대.급 할인템 다알랴줌!!!!!!
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 21만회
# 1년 전
#
#
#
#
#
#
#
#
#
#
#
#
#
#       15:14
#
# 지금 재생 중
#
#
#
#
# My Summer Nudy Makeup (with subs) 나만의 여름 누디 메이크업 👑
#
#
#
#
#
#
#
#
#
#
#
#
# 조회수 44만회
# 1년 전

# %%
isabe_url = []
for i in range(len(video_list2)):
    url = base_url+video_list2[i].find('a',{'id':'thumbnail'})['href']
    isabe_url.append(url)

# %%
print(isabe_url[0])
# Out:
# http://www.youtube.com/watch?v=SORLO6WAKm8

# %%
start_url = isabe_url[0] #리스트로 만들어져 있는 url중 한개의 url을 이용

browser.get('http://www.youtube.com/watch?v=QY0tZiya8aw/featured') 
body = browser.find_element_by_tag_name('body')
#웹드라이버로 url접속한 뒤 스크롤 내리기 위한 소스를 받아오는 것

# %%
num_page_down = 5
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1.5)
    num_page_down -= 1

# %%
#인기순/작성순 선택할 수 있는 영역 클릭
browser.find_element_by_xpath('//paper-button[@class="dropdown-trigger style-scope yt-dropdown-menu"]').click()
#인기순 카테고리 클릭
browser.find_element_by_xpath('//paper-listbox[@class="dropdown-content style-scope yt-dropdown-menu"]/a[1]').click()

# %%
num_page_down = 20
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1.5)
    num_page_down -= 1

# %%
comment_data = pd.DataFrame({'youtube_id':[],
                            'comment':[],
                            'like_num':[]})
browser = Chrome()#chrome_options=options
browser.implicitly_wait(delay)
browser.maximize_window()#전체화면이 아니라 최대화하는 방법

start_url = isabe_url[0]
browser.get(start_url) 
body = browser.find_element_by_tag_name('body')
#웹드라이버로 url접속한 뒤 스크롤 내리기 위한 소스를 받아오는 것

time.sleep(2)

num_page_down = 5
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1.5)
    num_page_down -= 1

#이 세개가 다 되는 코드임 - 자동제어 창을 띄어놔야 코드실행이 빨라짐
#browser.find_element_by_xpath('//*[@id="sort-menu"]').click()
browser.find_element_by_xpath('//paper-button[@class="dropdown-trigger style-scope yt-dropdown-menu"]').click()
#browser.find_element_by_xpath('//paper-menu-button[@class="style-scope yt-dropdown-menu"]').click()
#반드시 클릭은 해당 클릭할 화면이 보여야 클릭이 가능하다 당연히 제어하는 것이기 때문에

time.sleep(1.5)
browser.find_element_by_xpath('//paper-listbox[@class="dropdown-content style-scope yt-dropdown-menu"]/a[1]').click()
#driver.find_element_by_xpath('//*[@id="menu"]/a[2]/paper-item/paper-item-body/div[text()="최근 날짜순"]').click()
#이렇게 직접 텍스트를 지정해줌으로써 클릭하게 할 수 있음 -> 현재는 인기댓글순임

num_page_down = 20
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1.5)
    num_page_down -= 1
    
html_s0 = browser.page_source
html_s = BeautifulSoup(html_s0,'html.parser')

comment0 = html_s.find_all('ytd-comment-renderer',{'class':'style-scope ytd-comment-thread-renderer'})

for i in range(len(comment0)):
    #댓글
    comment = comment0[i].find('yt-formatted-string',{'id':'content-text','class':'style-scope ytd-comment-renderer'}).text
    
    try:
        aa = comment0[i].find('span',{'id':'vote-count-left'}).text
        #정규표현식으로 숫자만 추출하는 것은 정규표현식에 대한 공부를 더 한 뒤 해결
        #re.findall('[0-9]',aa)
        #"".join(re.findall('[0-9]',aa)) -> 리스트 내부의 문자열의 합
        like_num = "".join(re.findall('[0-9]',aa)) + "개"
    except:
        like_num = 0
        
    bb = comment0[i].find('a',{'id':'author-text'}).find('span').text
    youtube_id = "".join(re.findall('[가-힣0-9a-zA-Z]',bb))
    
    insert_data =  pd.DataFrame({'youtube_id':[youtube_id],
                                               'comment':[comment],
                                               'like_num':[like_num]})

    comment_data = comment_data.append(insert_data)
    
comment_data.index = range(len(comment_data))

# %%
comment_data.to_csv("text_mining.csv", mode='w',encoding='utf-8-sig')
