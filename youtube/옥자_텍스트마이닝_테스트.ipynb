# %%
from collections import Counter

# %%
# 1. 이전 포스트에서 크롤링한 댓글파일을 읽기전용으로 호출함
file = open('C:/Users/acorn/Desktop/Opensource/Python/Text Crawling/okja1.txt','r',encoding='utf-8')
lines = file.readlines()

# 2. 변수 okja에 전체댓글을 다시저장
okja = []
for line in lines:
    okja.append(line)
file.close()

# 3. 트윗터 패키지 안에 konlpy 모듈호출
from konlpy.tag import Twitter
twitter = Twitter()

# 4. 각 문장별로 형태소 구분하기
sentences_tag = []
for sentence in okja:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    print(morph)
    print('-'*30)

print(sentences_tag)
print(len(sentences_tag))
print('\n'*3)

# 5. 명사 혹은 형용사인 품사만 선별해 리스트에 담기
noun_adj_list = []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun','Adjective']:
            noun_adj_list.append(word)

# 6. 선별된 품사별 빈도수 계산 & 상위 빈도 10위 까지 출력
counts = Counter(noun_adj_list)
print(counts.most_common(10))
# Out:
# C:\Users\acorn\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('!', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('재미있고', 'Adjective'), ('뭉클하고', 'Adjective'), ('동물', 'Noun'), ('을', 'Josa'), ('먹는데', 'Verb'), ('대해', 'Noun'), ('죄책감', 'Noun'), ('이', 'Josa'), ('들게', 'Verb'), ('한다', 'Verb'), ('.', 'Punctuation'), ('인간', 'Noun'), ('은', 'Josa'), ('너무나', 'Adverb'), ('잔인하다', 'Adjective'), ('.', 'Punctuation'), ('특히', 'Adverb'), ('살아있는', 'Verb'), ('생명체', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('잔인하게', 'Adjective'), (',', 'Punctuation'), ('생선', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('산', 'Noun'), ('채', 'Noun'), ('로', 'Josa'), ('요리', 'Noun'), ('해서', 'Verb'), ('꿈틀', 'Noun'), ('대', 'Suffix'), ('는', 'Josa'), ('걸', 'Noun'), ('먹기', 'Noun'), ('까지', 'Josa'), ('하는', 'Verb'), ('인간', 'Noun'), ('들', 'Suffix'), ('\n', 'Foreign')]
# ------------------------------
# [('[', 'Punctuation'), ('옥자', 'Noun'), (']', 'Punctuation'), ('를', 'Noun'), ('보기', 'Noun'), ('전', 'Noun'), (':', 'Punctuation'), ('촌스러운', 'Adjective'), ('이름', 'Noun'), ('이네', 'Josa'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('옥자', 'Noun'), (']', 'Punctuation'), ('를', 'Noun'), ('본', 'Verb'), ('후', 'Noun'), (':', 'Punctuation'), ('옥자', 'Noun'), ('라는', 'Josa'), ('촌스러', 'Adjective'), ('움', 'Noun'), ('이', 'Josa'), ('귀엽다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('볼', 'Noun'), ('만', 'Josa'), ('하긴', 'Verb'), ('하지만', 'Conjunction'), ('확', 'Noun'), ('끌리진', 'Verb'), ('않음', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('미자', 'Noun'), ('또래', 'Noun'), ('의', 'Josa'), ('미성년', 'Noun'), ('자', 'Suffix'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('영화인', 'Noun'), ('듯', 'Noun'), ('한', 'Determiner'), ('데', 'Noun'), ('...', 'Punctuation'), ('시종일관', 'Noun'), ('유머러스하게', 'Adjective'), ('그릴려고', 'Verb'), ('한', 'Verb'), ('부분', 'Noun'), ('은', 'Josa'), ('다분히', 'Adjective'), ('계산', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('성인영화', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('무엇', 'Noun'), ('보다', 'Josa'), ('흥미로웠던건', 'Adjective'), ('옥자', 'Noun'), ('의', 'Josa'), ('그럴듯한', 'Adjective'), ('실물', 'Noun'), ('화', 'Suffix'), ('인데', 'Josa'), ('이', 'Noun'), ('부분', 'Noun'), ('이', 'Josa'), ('선입견', 'Noun'), ('을', 'Josa'), ('깨고', 'Verb'), ('영화', 'Noun'), ('를', 'Josa'), ('시시하게', 'Adjective'), ('하지는', 'Verb'), ('않았다', 'Verb'), ('.', 'Punctuation'), ('마지막', 'Noun'), ('꽤', 'Noun'), ('길게', 'Adjective'), ('비춰주던', 'Verb'), ('할아버지', 'Noun'), ('와', 'Josa'), ('손녀', 'Noun'), ('가', 'Josa'), ('밥', 'Noun'), ('먹을', 'Verb'), ('때', 'Noun'), ('백', 'Modifier'), ('그', 'Modifier'), ('라운드', 'Noun'), ('에', 'Josa'), ('보', 'Noun'), ('이던', 'Josa'), ('옥자', 'Noun'), ('의', 'Josa'), ('얼굴', 'Noun'), ('과', 'Josa'), ('새끼', 'Noun'), ('돼지', 'Noun'), ('엉덩이', 'Noun'), ('가', 'Josa'), ('특히', 'Adverb'), ('인상', 'Noun'), ('적', 'Suffix'), ('이다', 'Josa'), ('.', 'Punctuation'), ('이', 'Noun'), ('정도', 'Noun'), ('의', 'Josa'), ('평화', 'Noun'), ('라면', 'Noun'), ('누구', 'Noun'), ('나', 'Josa'), ('다', 'Adverb'), ('수긍', 'Noun'), ('할만', 'Verb'), ('한', 'Determiner'), ('장면', 'Noun'), ('일터', 'Noun'), ('...', 'Punctuation'), ('솔직히', 'Adjective'), ('영화', 'Noun'), ('는', 'Josa'), ('썩', 'Noun'), ('재밌지는', 'Adjective'), ('않았지만', 'Verb'), ('깔끔한', 'Adjective'), ('영상', 'Noun'), ('과', 'Josa'), ('은은한', 'Adjective'), ('엔딩', 'Noun'), ('이', 'Josa'), ('나쁘지', 'Adjective'), ('않았다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('재밌게', 'Adjective'), ('봄', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('동물', 'Noun'), ('들', 'Suffix'), ('도', 'Josa'), ('인간', 'Noun'), ('과', 'Josa'), ('같은', 'Adjective'), ('감정', 'Noun'), ('이', 'Josa'), ('있긴', 'Adjective'), ('하다', 'Verb'), ('...', 'Punctuation'), ('군대', 'Noun'), ('때', 'Noun'), ('대대', 'Noun'), ('회식', 'Noun'), ('하는데', 'Verb'), ('생', 'Noun'), ('돼지', 'Noun'), ('2', 'Number'), ('마리', 'Noun'), ('를', 'Josa'), ('사서', 'Noun'), ('트럭', 'Noun'), ('에서', 'Josa'), ('내리려', 'Verb'), ('하는데', 'Verb'), ('죽어도', 'Verb'), ('안', 'VerbPrefix'), ('내리려', 'Verb'), ('하며', 'Verb'), ('눈물', 'Noun'), ('을', 'Josa'), ('뚝뚝', 'Noun'), ('흘리드', 'Noun'), ('라', 'Josa'), ('...', 'Punctuation'), ('마음', 'Noun'), ('이', 'Josa'), ('너무', 'Adverb'), ('안좋은데', 'Adjective'), ('고기', 'Noun'), ('는', 'Josa'), ('맛있게', 'Adjective'), ('먹었다', 'Verb'), ('..', 'Punctuation'), ('동물학대', 'Noun'), ('를', 'Josa'), ('외치면서', 'Verb'), ('고기', 'Noun'), ('나', 'Josa'), ('생선', 'Noun'), ('을', 'Josa'), ('먹는건', 'Verb'), ('또', 'Noun'), ('참', 'Verb'), ('아이러니', 'Noun'), ('하다', 'Verb'), ('...', 'Punctuation'), ('나도', 'Verb'), ('동물학대', 'Noun'), ('반대', 'Noun'), ('자', 'Suffix'), ('지만', 'Josa'), (',', 'Punctuation'), ('고기', 'Noun'), ('를', 'Josa'), ('엄청', 'Adverb'), ('좋아하니', 'Adjective'), ('..', 'Punctuation'), ('반려동물', 'Noun'), ('은', 'Josa'), ('식용', 'Noun'), (',', 'Punctuation'), ('학', 'Noun'), ('대', 'Suffix'), ('을', 'Josa'), ('금지', 'Noun'), ('하고', 'Josa'), (',', 'Punctuation'), ('최소한', 'Noun'), ('식용', 'Noun'), ('동물', 'Noun'), ('의', 'Josa'), ('경우', 'Noun'), ('도', 'Josa'), ('쾌적하고', 'Adjective'), ('학대', 'Noun'), ('없이', 'Adverb'), ('지내다', 'Verb'), ('도축', 'Noun'), ('시', 'Noun'), ('고통', 'Noun'), ('없이', 'Adverb'), ('존중', 'Noun'), ('하며', 'Verb'), ('보내줘야', 'Verb'), ('할듯', 'Verb'), ('??', 'Punctuation'), ('(', 'Punctuation'), ('식용', 'Noun'), ('동물', 'Noun'), ('의', 'Josa'), ('운명', 'Noun'), ('이', 'Josa'), ('랄', 'Noun'), ('까', 'Verb'), ('...', 'Punctuation'), ('줸장', 'Noun'), ('.', 'Punctuation'), ('흙', 'Noun'), ('수저', 'Noun'), ('도', 'Josa'), ('아닌', 'Adjective'), ('먹이', 'Noun'), ('감', 'Noun'), ('으로', 'Josa'), ('태어나서리', 'Verb'), (')', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('ㆍ', 'Foreign'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('남녀', 'Noun'), ('노소', 'Noun'), ('누구', 'Noun'), ('나', 'Josa'), ('한번', 'Noun'), ('은', 'Josa'), ('꼭', 'Noun'), ('봐', 'Verb'), ('야할', 'Adjective'), ('영화', 'Noun'), ('무거운', 'Adjective'), ('주제', 'Noun'), ('를', 'Josa'), ('그래도', 'Adverb'), ('나름', 'Noun'), ('가볍게', 'Adjective'), ('볼수있을만큼', 'Verb'), ('풀어', 'Verb'), ('낸듯', 'Verb'), ('한', 'Determiner'), ('\n', 'Foreign')]
# ------------------------------
# [('인디아나', 'Noun'), ('미자', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('많은', 'Adjective'), ('생각', 'Noun'), ('을', 'Josa'), ('갖게', 'Verb'), ('합니다', 'Verb'), ('.', 'Punctuation'), ('우리', 'Noun'), ('의', 'Josa'), ('정서', 'Noun'), ('를', 'Josa'), ('곳곳', 'Noun'), ('에서', 'Josa'), ('느꼈습니다', 'Verb'), ('.', 'Punctuation'), ('집중', 'Noun'), ('을', 'Josa'), ('흐트러뜨리', 'Noun'), ('는', 'Josa'), ('몇몇', 'Noun'), ('요소', 'Noun'), ('가', 'Josa'), ('아쉽네요', 'Adjective'), ('.', 'Punctuation'), ('그래도', 'Adverb'), ('전반', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('좋았습니다', 'Adjective'), ('!', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('와', 'Josa'), ('미자', 'Noun'), ('의', 'Josa'), ('우정', 'Noun'), ('과', 'Josa'), ('사랑', 'Noun'), ('을', 'Josa'), ('지킬수', 'Verb'), ('있어', 'Adjective'), ('정말', 'Noun'), ('다행', 'Noun'), ('였지만', 'Verb'), ('마음', 'Noun'), ('이', 'Josa'), ('무거워', 'Noun'), ('지는', 'Josa'), ('영화', 'Noun'), ('입니다', 'Adjective'), ('..', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('좋았어요', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('한국', 'Noun'), ('식', 'Suffix'), ('휴먼', 'Noun'), ('드라마', 'Noun'), ('통', 'Noun'), ('하였느냐', 'Verb'), ('?', 'Punctuation'), ('그래도', 'Adverb'), ('나', 'Noun'), ('한테', 'Josa'), ('는', 'Verb'), ('통', 'Noun'), ('했다', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('봉준호', 'Noun'), ('감독', 'Noun'), ('의', 'Josa'), ('독창', 'Noun'), ('성', 'Suffix'), ('이', 'Josa'), ('돋보이는', 'Verb'), ('작품', 'Noun'), ('이지만', 'Josa'), ('...', 'Punctuation'), ('지루하다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('거대', 'Noun'), ('자본', 'Noun'), ('이', 'Josa'), ('들어가서', 'Verb'), ('긴장', 'Noun'), ('했는지', 'Verb'), ('..', 'Punctuation'), ('본인', 'Noun'), ('의', 'Josa'), ('색깔', 'Noun'), ('은', 'Josa'), ('잘', 'Verb'), ('표현', 'Noun'), ('했으나', 'Verb'), ('전작', 'Noun'), ('들', 'Suffix'), ('과', 'Josa'), ('비교', 'Noun'), ('했을', 'Verb'), ('때', 'Noun'), ('는', 'Josa'), ('확실히', 'Adjective'), ('점수', 'Noun'), ('를', 'Josa'), ('후', 'Noun'), ('하게', 'Verb'), ('줄', 'Noun'), ('수', 'Noun'), ('없는', 'Adjective'), ('평작', 'Noun'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('애썼다', 'Verb'), ('옥자', 'Noun'), ('야', 'Josa'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('고기', 'Noun'), ('먹는', 'Verb'), ('건', 'Noun'), ('나쁘지', 'Adjective'), ('않지만', 'Verb'), (',', 'Punctuation'), ('한번', 'Noun'), ('쯤', 'Suffix'), ('생각', 'Noun'), ('해볼', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('주제', 'Noun'), ('인거', 'Josa'), ('같다', 'Adjective'), ('......', 'Punctuation'), ('주제', 'Noun'), ('를', 'Josa'), ('제외', 'Noun'), ('하더라도', 'Verb'), ('영', 'Modifier'), ('상미', 'Noun'), ('는', 'Josa'), ('훌륭해', 'Adjective'), ('보인다', 'Verb'), ('....', 'Punctuation'), ('다만', 'Noun'), ('외국', 'Noun'), ('배우', 'Noun'), ('의', 'Josa'), ('모습', 'Noun'), ('이나', 'Josa'), (',', 'Punctuation'), ('약간', 'Noun'), ('전체', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('허', 'Verb'), ('술함', 'Noun'), ('이', 'Josa'), ('보이긴', 'Verb'), ('하지만', 'Conjunction'), ('...', 'Punctuation'), ('재미있다', 'Adjective'), ('..', 'Punctuation'), ('아이', 'Noun'), ('들', 'Suffix'), ('에겐', 'Josa'), ('더', 'Noun'), ('재미있을듯', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('를', 'Josa'), ('데리', 'Noun'), ('고', 'Josa'), ('나오는', 'Verb'), ('장면', 'Noun'), ('이', 'Josa'), ('다', 'Adverb'), ('한', 'Verb'), ('영화', 'Noun'), ('ㅠㅠ', 'KoreanParticle'), ('기대', 'Noun'), ('가', 'Josa'), ('큰', 'Verb'), ('만큼', 'Noun'), ('아쉬움', 'Noun'), ('도', 'Josa'), ('크네요', 'Verb'), ('ㅠㅠ', 'KoreanParticle'), ('봉준호', 'Noun'), ('감독', 'Noun'), ('님', 'Suffix'), ('은', 'Josa'), ('점점', 'Noun'), ('대중성', 'Noun'), ('과는', 'Josa'), ('멀어지는', 'Verb'), ('건가', 'Noun'), ('요', 'Josa'), ('ㅠㅠ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('웃기지도', 'Verb'), ('않는', 'Verb'), ('영화', 'Noun'), ('그래서', 'Adverb'), ('뭘', 'Noun'), ('어쩌', 'Noun'), ('겠다는', 'Verb'), ('건가', 'Noun'), ('?', 'Punctuation'), ('자본주의', 'Noun'), ('를', 'Josa'), ('까는것까진', 'Verb'), ('좋은데', 'Adjective'), ('까는', 'Verb'), ('방식', 'Noun'), ('이', 'Josa'), ('흥행', 'Noun'), ('위주', 'Noun'), ('에', 'Josa'), ('스타', 'Noun'), ('시스템', 'Noun'), ('중심', 'Noun'), ('으로', 'Josa'), ('지', 'Verb'), ('돈', 'Noun'), ('벌고', 'Verb'), ('다', 'Adverb'), ('벌면서', 'Verb'), ('까', 'Verb'), ('?', 'Punctuation'), ('이건', 'Noun'), ('자본주의', 'Noun'), ('중', 'Noun'), ('에서도', 'Josa'), ('가장', 'Noun'), ('천박한', 'Adjective'), ('자본주의', 'Noun'), ('아닌가', 'Adjective'), ('?', 'Punctuation'), ('비유', 'Noun'), ('컨', 'Noun'), ('대', 'Suffix'), ('피', 'Noun'), ('를', 'Josa'), ('씻는데', 'Verb'), ('똥물', 'Noun'), ('로', 'Josa'), ('씻는', 'Verb'), ('격', 'Noun'), ('?', 'Punctuation'), ('위선', 'Noun'), ('과', 'Josa'), ('아집', 'Noun'), ('과', 'Josa'), ('모순', 'Noun'), ('도', 'Josa'), ('이런', 'Adjective'), ('경우', 'Noun'), ('드물다', 'Adjective'), ('봉준호', 'Noun'), ('는', 'Josa'), ('자연인', 'Noun'), ('이', 'Josa'), ('되고싶은', 'Verb'), ('건가', 'Noun'), ('?', 'Punctuation'), ('그럼', 'Adjective'), ('월든', 'Noun'), ('숲', 'Noun'), ('에서', 'Josa'), ('살아라', 'Verb'), ('근데', 'Adverb'), ('혹시', 'Noun'), ('지금', 'Noun'), ('살고있는', 'Verb'), ('덴', 'Noun'), ('가장', 'Noun'), ('반', 'Modifier'), ('자연', 'Noun'), ('적', 'Suffix'), ('이고', 'Josa'), ('친', 'Noun'), ('문명', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('으리', 'Noun'), ('삐', 'Noun'), ('까', 'Verb'), ('뻔쩍', 'Noun'), ('한', 'Josa'), ('수십', 'Modifier'), ('억대', 'Noun'), ('최첨단', 'Noun'), ('아파트먼트', 'Noun'), ('는', 'Josa'), ('혹시', 'Noun'), ('아니', 'Adjective'), ('신지', 'Noun'), ('?', 'Punctuation'), ('봉준호', 'Noun'), ('는', 'Josa'), ('이제', 'Noun'), ('영화', 'Noun'), ('그만', 'Adverb'), ('만들었으면', 'Verb'), ('한다', 'Verb'), ('어깨', 'Noun'), ('에', 'Josa'), ('힘', 'Noun'), ('뺀', 'Verb'), ('영화', 'Noun'), ('라고', 'Josa'), ('들', 'Verb'), ('하는데', 'Verb'), ('내', 'Noun'), ('가볼', 'Verb'), ('땐', 'Noun'), ('설국열차', 'Noun'), ('때', 'Noun'), ('보다', 'Josa'), ('훨씬', 'Adverb'), ('더', 'Noun'), ('어깨', 'Noun'), ('에', 'Josa'), ('힘주고', 'Verb'), ('목', 'Noun'), ('에는', 'Josa'), ('기브스', 'Noun'), ('한', 'Josa'), ('채', 'Noun'), ('관객', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('향', 'Noun'), ('해서', 'Verb'), ('마치', 'Noun'), ('내', 'Noun'), ('가', 'Josa'), ('한', 'Verb'), ('수', 'Noun'), ('갈', 'Verb'), ('쳐', 'Verb'), ('주마', 'Noun'), ('고', 'Josa'), ('거', 'Noun'), ('들먹대는', 'Verb'), ('같지도', 'Adjective'), ('않은', 'Verb'), ('거만함이', 'Adjective'), ('푹푹', 'Adverb'), ('묻어', 'Verb'), ('난다', 'Verb'), ('이', 'Determiner'), ('젠', 'Noun'), ('의인화', 'Noun'), ('된', 'Verb'), ('상상', 'Noun'), ('속', 'Noun'), ('의', 'Josa'), ('짐승', 'Noun'), ('꺼내', 'Verb'), ('들고', 'Verb'), ('채식', 'Noun'), ('주의', 'Noun'), ('까지', 'Josa'), ('강요', 'Noun'), ('하냐', 'Verb'), ('?', 'Punctuation'), ('ㅋㅋ', 'KoreanParticle'), ('어이', 'Noun'), ('~', 'Punctuation'), ('봉씨', 'Noun'), ('영화', 'Noun'), ('관', 'Noun'), ('두고', 'Verb'), ('환경', 'Noun'), ('전문', 'Noun'), ('운동', 'Noun'), ('가나', 'Noun'), ('되시지', 'Verb'), ('?', 'Punctuation'), ('카악', 'Adverb'), ('~', 'Punctuation'), ('퉤', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('의식', 'Noun'), ('전환', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('릴리', 'Noun'), ('콜린스', 'Noun'), ('가', 'Josa'), ('나오다니', 'Verb'), ('...', 'Punctuation'), ('근데', 'Adverb'), ('뭔가', 'Noun'), ('슬프다', 'Adjective'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('삼겹살', 'Noun'), ('먹기', 'Noun'), ('미안해지는', 'Adjective'), ('영화', 'Noun'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('처음', 'Noun'), ('으로', 'Josa'), ('고기', 'Noun'), ('끊어야겠다는', 'Verb'), ('생각', 'Noun'), ('이', 'Josa'), ('듬', 'Noun'), ('..', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('연기', 'Noun'), ('..', 'Punctuation'), ('스토리', 'Noun'), ('..', 'Punctuation'), ('감동', 'Noun'), (',', 'Punctuation'), ('반성', 'Noun'), ('했다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('야', 'Josa'), ('..', 'Punctuation'), ('.', 'Punctuation'), ('ㅠㅠ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('어디', 'Noun'), ('선', 'Noun'), ('가', 'Josa'), ('벌어지고', 'Verb'), ('있을지도', 'Adjective'), ('모르는', 'Verb'), ('일', 'Noun'), ('이란', 'Josa'), ('생각', 'Noun'), ('이', 'Josa'), ('든다', 'Verb'), ('.', 'Punctuation'), ('육', 'Modifier'), ('실', 'Noun'), ('을', 'Josa'), ('즐기지는', 'Verb'), ('않지만', 'Verb'), ('...', 'Punctuation'), ('동물', 'Noun'), ('을', 'Josa'), ('소비', 'Noun'), ('하기', 'Verb'), ('위해', 'Noun'), ('우린', 'Noun'), ('얼마나', 'Noun'), ('많은', 'Adjective'), ('것', 'Noun'), ('을', 'Josa'), ('잃어야', 'Verb'), ('하는지', 'Verb'), ('생각', 'Noun'), ('게', 'Josa'), ('한다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('잔혹', 'Noun'), ('동화', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('육식', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('불편함은', 'Adjective'), ('분명', 'Noun'), ('고민', 'Noun'), ('해야', 'Verb'), ('할', 'Verb'), ('부분', 'Noun'), ('인거', 'Josa'), ('같다', 'Adjective'), ('.', 'Punctuation'), ('지금', 'Noun'), ('의', 'Josa'), ('사육', 'Noun'), ('환경', 'Noun'), ('을', 'Josa'), ('본다면', 'Verb'), ('이런', 'Adjective'), ('영화', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('주는', 'Verb'), ('메세지', 'Noun'), ('가', 'Josa'), ('결코', 'Noun'), ('가볍게', 'Adjective'), ('다가오지만은', 'Verb'), ('않는다', 'Verb'), ('.', 'Punctuation'), ('다만', 'Noun'), ('영화', 'Noun'), ('가', 'Josa'), ('주는', 'Verb'), ('메세지', 'Noun'), ('에', 'Josa'), ('비해', 'Verb'), ('연출', 'Noun'), ('은', 'Josa'), ('다소', 'Noun'), ('힘', 'Noun'), ('이', 'Josa'), ('빠진다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('10', 'Number'), ('점', 'Noun'), ('주는데도', 'Verb'), ('참', 'Verb'), ('고민', 'Noun'), ('이', 'Josa'), ('많았던', 'Adjective'), ('영화', 'Noun'), ('다', 'Josa'), ('.', 'Punctuation'), ('그만큼', 'Adverb'), ('생각', 'Noun'), ('하게', 'Verb'), ('되고', 'Verb'), ('어려운', 'Adjective'), ('주제가', 'Noun'), ('아닐까', 'Adjective'), ('싶다', 'Verb'), ('.', 'Punctuation'), ('특히', 'Adverb'), ('마지막', 'Noun'), ('장면', 'Noun'), ('에서는', 'Josa'), ('고기', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('불편한', 'Adjective'), ('시각', 'Noun'), ('을', 'Josa'), ('줄수', 'Verb'), ('있어', 'Adjective'), ('심히', 'Adjective'), ('우려', 'Noun'), ('가', 'Josa'), ('되는', 'Verb'), ('부분', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('왜냐하면', 'Adverb'), ('인류', 'Noun'), ('를', 'Josa'), ('생각', 'Noun'), ('하면', 'Verb'), ('필', 'Noun'), ('이', 'Josa'), ('없어서는', 'Adjective'), ('안될', 'Adjective'), ('중요한', 'Adjective'), ('자원', 'Noun'), ('이', 'Josa'), ('되기', 'Verb'), ('때문', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('그래서', 'Adverb'), ('영화', 'Noun'), ('자체', 'Noun'), ('만으로', 'Josa'), ('봐서', 'Verb'), ('10', 'Number'), ('점', 'Noun'), ('을', 'Josa'), ('주기', 'Noun'), ('로', 'Josa'), ('했다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('감독', 'Noun'), ('이', 'Josa'), ('채식주의자', 'Noun'), ('냐', 'Josa'), ('...', 'Punctuation'), ('양심', 'Noun'), ('껏', 'Noun'), ('일', 'Noun'), ('하고있는', 'Verb'), ('축산', 'Noun'), ('업계', 'Noun'), ('사람', 'Noun'), ('들', 'Suffix'), ('과', 'Josa'), ('..', 'Punctuation'), ('잘', 'VerbPrefix'), ('먹고있는', 'Verb'), ('사람', 'Noun'), ('들', 'Suffix'), ('에게', 'Josa'), ('왜', 'Noun'), ('고기', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('혐오', 'Noun'), ('감', 'Noun'), ('을', 'Josa'), ('갖게하는지', 'Verb'), ('모르겠네', 'Verb'), ('..', 'Punctuation'), ('재미', 'Noun'), ('도', 'Josa'), ('하나', 'Noun'), ('없고', 'Adjective'), ('이', 'Noun'), ('게', 'Josa'), ('뭔', 'Modifier'), ('영화', 'Noun'), ('인지', 'Josa'), ('..', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('예쁘고', 'Adjective'), ('현실', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('동화', 'Noun'), ('.', 'Punctuation'), ('그래서', 'Adverb'), ('옥자', 'Noun'), ('와', 'Josa'), ('미자', 'Noun'), ('는', 'Josa'), ('산', 'Noun'), ('속', 'Noun'), ('에서', 'Josa'), ('행복하게', 'Adjective'), ('살았을까', 'Verb'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('랑', 'Josa'), ('미자', 'Noun'), ('너무', 'Adverb'), ('사랑스럽고', 'Adjective'), ('..', 'Punctuation'), ('가슴', 'Noun'), ('아픈', 'Adjective'), ('장면', 'Noun'), ('도', 'Josa'), ('있었다', 'Adjective'), ('..', 'Punctuation'), ('동물학대', 'Noun'), ('하는', 'Verb'), ('것', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('인간계', 'Noun'), ('에서', 'Josa'), ('멸종', 'Noun'), ('되길', 'Verb'), ('..^^', 'Punctuation'), ('밑', 'Noun'), ('에', 'Josa'), ('평점', 'Noun'), ('3', 'Number'), ('점', 'Noun'), ('과', 'Josa'), ('1', 'Number'), ('점', 'Noun'), ('은', 'Josa'), ('건강한', 'Adjective'), ('마인드', 'Noun'), ('에서', 'Josa'), ('거리', 'Noun'), ('가', 'Josa'), ('먼듯', 'Adjective'), ('하다', 'Verb'), ('..', 'Punctuation'), ('미란', 'Noun'), ('도', 'Noun'), ('에서', 'Josa'), ('나오셨어요', 'Verb'), ('?', 'Punctuation'), ('ㅋㅋ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('호불호', 'Noun'), ('가', 'Josa'), ('분명히', 'Adjective'), ('있는', 'Adjective'), ('영화', 'Noun'), ('지만', 'Josa'), ('식량', 'Noun'), ('문제', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('서', 'Josa'), ('잘', 'Verb'), ('다룬', 'Verb'), ('영화', 'Noun'), ('였습니다', 'Verb'), ('.', 'Punctuation'), ('^&^', 'Punctuation'), ('우리나라', 'Noun'), ('보다', 'Verb'), ('북미', 'Noun'), ('즉', 'Noun'), (',', 'Punctuation'), ('미국', 'Noun'), ('시민', 'Noun'), ('들', 'Suffix'), ('에게', 'Josa'), ('더', 'Noun'), ('관심', 'Noun'), ('이', 'Josa'), ('많이', 'Adverb'), ('갈', 'Verb'), ('수', 'Noun'), ('밖에', 'Josa'), ('없는', 'Adjective'), ('주제', 'Noun'), ('의', 'Josa'), ('영화', 'Noun'), ('를', 'Josa'), ('우리나라', 'Noun'), ('감독', 'Noun'), ('이', 'Josa'), ('잘', 'Verb'), ('만들었습니다', 'Verb'), ('.', 'Punctuation'), ('^&^', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('봉준호', 'Noun'), ('감독', 'Noun'), ('님', 'Suffix'), ('의', 'Josa'), ('졸작', 'Noun'), ('.', 'Punctuation'), ('감동', 'Noun'), ('도', 'Josa'), ('없고', 'Adjective'), (',', 'Punctuation'), ('연출', 'Noun'), ('력', 'Suffix'), ('도', 'Josa'), ('많이', 'Adverb'), ('부족하고', 'Adjective'), ('....', 'Punctuation'), ('마더', 'Noun'), ('같은', 'Adjective'), ('영화', 'Noun'), ('를', 'Josa'), ('더', 'Noun'), ('많이', 'Adverb'), ('만들어', 'Verb'), ('주셨으면', 'Verb'), ('하는', 'Verb'), ('바람', 'Noun'), ('입니다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('철부지', 'Noun'), ('시골', 'Noun'), ('소녀', 'Noun'), ('의', 'Josa'), ('개인', 'Noun'), ('적', 'Suffix'), ('욕망', 'Noun'), ('에', 'Josa'), ('사회', 'Noun'), ('적', 'Suffix'), ('손실', 'Noun'), ('을', 'Josa'), ('감내하는', 'Verb'), ('영화', 'Noun'), ('.', 'Punctuation'), ('영화', 'Noun'), ('를', 'Josa'), ('통해', 'Noun'), ('각종', 'Noun'), ('이권', 'Noun'), ('자', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('비판', 'Noun'), ('하고자', 'Verb'), ('하는', 'Verb'), ('감독', 'Noun'), ('의', 'Josa'), ('의도', 'Noun'), ('는', 'Josa'), ('알겠으나', 'Verb'), (',', 'Punctuation'), ('그', 'Noun'), ('과정', 'Noun'), ('에서', 'Josa'), ('또', 'Noun'), ('희생', 'Noun'), ('되는', 'Verb'), ('다른', 'Noun'), ('다수', 'Noun'), ('의', 'Josa'), ('시민', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('이익', 'Noun'), ('과', 'Josa'), ('행복', 'Noun'), ('은', 'Josa'), ('깡그리', 'Noun'), ('무시', 'Noun'), ('하는', 'Verb'), ('영화', 'Noun'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('왜', 'Noun'), ('때려', 'Verb'), ('.', 'Punctuation'), ('그것', 'Noun'), ('도', 'Josa'), ('갑자기', 'Noun'), ('..', 'Punctuation'), ('재밌는', 'Adjective'), ('소재', 'Noun'), ('를', 'Josa'), ('망쳐놓은', 'Verb'), ('것', 'Noun'), ('같은', 'Adjective'), ('배우', 'Noun'), ('들', 'Suffix'), ('(', 'Punctuation'), ('주', 'Modifier'), ('연', 'Modifier'), ('배우', 'Noun'), ('빼고', 'Verb'), (')', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('혐오', 'Noun'), ('스런', 'Josa'), ('장면', 'Noun'), ('으로', 'Josa'), ('전세계', 'Noun'), ('국민', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('음식', 'Noun'), ('인', 'Josa'), ('고기', 'Noun'), ('에', 'Josa'), ('대해', 'Noun'), ('혐오', 'Noun'), ('감', 'Noun'), ('을', 'Josa'), ('갖게하지마라', 'Verb'), ('..', 'Punctuation'), ('누가', 'Noun'), ('보면', 'Verb'), ('지금', 'Noun'), ('현재', 'Noun'), ('고', 'Modifier'), ('기업체', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('다', 'Adverb'), ('저런줄', 'Verb'), ('알겠다', 'Verb'), ('.', 'Punctuation'), ('오', 'Modifier'), ('바하', 'Noun'), ('지', 'Josa'), ('마시길', 'Verb'), ('..', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('감동', 'Noun'), ('이', 'Josa'), ('스며든다', 'Verb'), ('동물', 'Noun'), ('과', 'Josa'), ('교감', 'Noun'), ('못', 'VerbPrefix'), ('하는', 'Verb'), ('종자', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('절대', 'Noun'), ('이해', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('없는', 'Adjective'), ('영화', 'Noun'), ('\n', 'Foreign')]
# ------------------------------
# [('돼지고기', 'Noun'), ('먹지말고', 'Verb'), ('개고기', 'Noun'), ('먹어라', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('봉', 'Noun'), ('감독', 'Noun'), ('님', 'Suffix'), ('채식주의자', 'Noun'), ('된건', 'Verb'), ('아니죠', 'Adjective'), ('?', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('가족', 'Noun'), ('이', 'Josa'), ('함께', 'Adverb'), ('보기', 'Noun'), ('에', 'Josa'), ('아주', 'Noun'), ('좋은', 'Adjective'), ('영화', 'Noun'), ('.', 'Punctuation'), ('허', 'Verb'), ('접하지', 'Verb'), ('않고', 'Verb'), ('아주', 'Noun'), ('잘', 'Verb'), ('만들어졌네요', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('감동', 'Noun'), ('이네', 'Josa'), ('요', 'Noun'), ('..', 'Punctuation'), ('ㅜ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('잘', 'VerbPrefix'), ('만들었다', 'Verb'), ('가슴', 'Noun'), ('아픈', 'Adjective'), ('영화', 'Noun'), ('네', 'Suffix'), ('요', 'Josa'), ('....', 'Punctuation'), ('충격', 'Noun'), ('적', 'Suffix'), ('이다', 'Josa'), ('회의', 'Noun'), ('감', 'Noun'), ('들', 'Suffix'), ('게', 'Josa'), ('하네요', 'Verb'), ('..', 'Punctuation'), ('세상', 'Noun'), ('에', 'Josa'), ('전기', 'Noun'), ('줄', 'Noun'), ('틈', 'Noun'), ('으로', 'Josa'), ('새끼', 'Noun'), ('내보내는', 'Verb'), ('것', 'Noun'), ('좀', 'Noun'), ('봐', 'Verb'), ('..', 'Punctuation'), ('ㅜㅡ', 'KoreanParticle'), ('\n', 'Foreign')]
# ------------------------------
# [('헐리웃', 'Noun'), ('스타', 'Noun'), ('도', 'Josa'), ('돈', 'Noun'), ('주면', 'Verb'), ('그냥', 'Noun'), ('나오는구나', 'Verb'), ('.', 'Punctuation'), ('그저', 'Adverb'), ('창피함', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('도', 'Josa'), ('재밌다', 'Adjective'), ('또', 'Noun'), ('보고싶다', 'Verb'), ('인기', 'Noun'), ('가', 'Josa'), ('많아요', 'Adjective'), ('옥자', 'Noun'), ('화이팅', 'Noun'), ('옥자', 'Noun'), ('는', 'Josa'), ('돼지', 'Noun'), ('에요', 'Josa'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('옥자', 'Noun'), ('잘', 'VerbPrefix'), ('봤어요', 'Verb'), ('~', 'Punctuation'), ('애니', 'Noun'), ("'", 'Punctuation'), ('아기', 'Noun'), ('기린', 'Noun'), ('자라', 'Noun'), ('파', 'Noun'), ("'", 'Punctuation'), ('랑', 'Josa'), ('많이', 'Adverb'), ('비슷한듯', 'Adjective'), ('하네요', 'Verb'), ('~', 'Punctuation'), ('근데', 'Adverb'), ('영어', 'Noun'), ('자막', 'Noun'), ('이', 'Josa'), ('욕설', 'Noun'), ('이', 'Josa'), ('심해서', 'Adjective'), ('보기', 'Noun'), ('가', 'Josa'), ('좀', 'Noun'), ('거북했어요', 'Adjective'), ('~', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('너무나', 'Adverb'), ('좋은', 'Adjective'), ('영화', 'Noun'), ('잘', 'Verb'), ('봤어요', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('이', 'Noun'), ('영화', 'Noun'), ('의', 'Josa'), ('주제', 'Noun'), ('는', 'Josa'), ('채식', 'Noun'), ('이냐', 'Josa'), ('육식', 'Noun'), ('이냐', 'Josa'), ('의', 'Noun'), ('문제', 'Noun'), ('가', 'Josa'), ('아니란다', 'Adjective'), ('..', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('주성치', 'Noun'), ('의', 'Josa'), ('광팬', 'Noun'), ('인', 'Josa'), ('봉준호', 'Noun'), ('감독', 'Noun'), ('의', 'Josa'), ('본격', 'Noun'), ('주성치', 'Noun'), ('따라잡기', 'Verb'), ('\n', 'Foreign')]
# ------------------------------
# [('특이한', 'Adjective'), ('장르', 'Noun'), ('여서', 'Josa'), ('7', 'Number'), ('점', 'Noun'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('이', 'Noun'), ('영화', 'Noun'), ('를', 'Josa'), ('통해', 'Noun'), ('무엇', 'Noun'), ('을', 'Josa'), ('말', 'Noun'), ('하고', 'Josa'), ('싶었던', 'Verb'), ('것', 'Noun'), ('일까', 'Verb'), ('?', 'Punctuation'), ('영화', 'Noun'), ('를', 'Josa'), ('보면서', 'Verb'), ('그', 'Noun'), ('어떠한', 'Adjective'), ('가치', 'Noun'), ('도', 'Josa'), ('느끼지', 'Verb'), ('못', 'VerbPrefix'), ('했다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('\n', 'Foreign')]
# ------------------------------
# [('감독', 'Noun'), ('이', 'Josa'), ('"', 'Punctuation'), ('옥자', 'Noun'), ('"', 'Punctuation'), ('를', 'Noun'), ('통해', 'Noun'), ('서', 'Josa'), ('뭘', 'Noun'), ('말', 'Noun'), ('하고', 'Josa'), ('싶었는지는', 'Verb'), ('모르겠지만', 'Verb'), ('....', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [('유쾌한', 'Adjective'), ('영화', 'Noun'), ('면서', 'Noun'), ('생각', 'Noun'), ('을', 'Josa'), ('많이', 'Adverb'), ('하게', 'Verb'), ('하지만', 'Conjunction'), ('억지', 'Noun'), ('같은', 'Adjective'), ('느낌', 'Noun'), ('을', 'Josa'), ('지울', 'Verb'), ('수가', 'Noun'), ('없다', 'Adjective'), ('.', 'Punctuation'), ('강요', 'Noun'), ('받는', 'Verb'), ('느낌', 'Noun'), ('을', 'Josa'), ('영화', 'Noun'), ('보는', 'Verb'), ('내내', 'Noun'), ('들었다', 'Verb'), ('.', 'Punctuation'), ('동물', 'Noun'), ('보호', 'Noun'), ('..', 'Punctuation'), ('삶', 'Noun'), ('과', 'Josa'), ('인간', 'Noun'), ('의', 'Josa'), ('욕구', 'Noun'), ('어려운', 'Adjective'), ('문제', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('\n', 'Foreign')]
# ------------------------------
# [[('\n', 'Foreign')], [('옥자', 'Noun'), ('!', 'Punctuation'), ('\n', 'Foreign')], [('재미있고', 'Adjective'), ('뭉클하고', 'Adjective'), ('동물', 'Noun'), ('을', 'Josa'), ('먹는데', 'Verb'), ('대해', 'Noun'), ('죄책감', 'Noun'), ('이', 'Josa'), ('들게', 'Verb'), ('한다', 'Verb'), ('.', 'Punctuation'), ('인간', 'Noun'), ('은', 'Josa'), ('너무나', 'Adverb'), ('잔인하다', 'Adjective'), ('.', 'Punctuation'), ('특히', 'Adverb'), ('살아있는', 'Verb'), ('생명체', 'Noun'), ('들', 'Suffix'), ('을', 'Josa'), ('잔인하게', 'Adjective'), (',', 'Punctuation'), ('생선', 'Noun'), ('들', 'Suffix'), ('은', 'Josa'), ('산', 'Noun'), ('채', 'Noun'), ('로', 'Josa'), ('요리', 'Noun'), ('해서', 'Verb'), ('꿈틀', 'Noun'), ('대', 'Suffix'), ('는', 'Josa'), ('걸', 'Noun'), ('먹기', 'Noun'), ('까지', 'Josa'), ('하는', 'Verb'), ('인간', 'Noun'), ('들', 'Suffix'), ('\n', 'Foreign')], [('[', 'Punctuation'), ('옥자', 'Noun'), (']', 'Punctuation'), ('를', 'Noun'), ('보기', 'Noun'), ('전', 'Noun'), (':', 'Punctuation'), ('촌스러운', 'Adjective'), ('이름', 'Noun'), ('이네', 'Josa'), ('.', 'Punctuation'), ('[', 'Punctuation'), ('옥자', 'Noun'), (']', 'Punctuation'), ('를', 'Noun'), ('본', 'Verb'), ('후', 'Noun'), (':', 'Punctuation'), ('옥자', 'Noun'), ('라는', 'Josa'), ('촌스러', 'Adjective'), ('움', 'Noun'), ('이', 'Josa'), ('귀엽다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('볼', 'Noun'), ('만', 'Josa'), ('하긴', 'Verb'), ('하지만', 'Conjunction'), ('확', 'Noun'), ('끌리진', 'Verb'), ('않음', 'Verb'), ('\n', 'Foreign')], [('\n', 'Foreign')], [('\n', 'Foreign')], [('미자', 'Noun'), ('또래', 'Noun'), ('의', 'Josa'), ('미성년', 'Noun'), ('자', 'Suffix'), ('를', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('영화인', 'Noun'), ('듯', 'Noun'), ('한', 'Determiner'), ('데', 'Noun'), ('...', 'Punctuation'), ('시종일관', 'Noun'), ('유머러스하게', 'Adjective'), ('그릴려고', 'Verb'), ('한', 'Verb'), ('부분', 'Noun'), ('은', 'Josa'), ('다분히', 'Adjective'), ('계산', 'Noun'), ('적', 'Suffix'), ('인', 'Josa'), ('성인영화', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation'), ('무엇', 'Noun'), ('보다', 'Josa'), ('흥미로웠던건', 'Adjective'), ('옥자', 'Noun'), ('의', 'Josa'), ('그럴듯한', 'Adjective'), ('실물', 'Noun'), ('화', 'Suffix'), ('인데', 'Josa'), ('이', 'Noun'), ('부분', 'Noun'), ('이', 'Josa'), ('선입견', 'Noun'), ('을', 'Josa'), ('깨고', 'Verb'), ('영화', 'Noun'), ('를', 'Josa'), ('시시하게', 'Adjective'), ('하지는', 'Verb'), ('않았다', 'Verb'), ('.', 'Punctuation'), ('마지막', 'Noun'), ('꽤', 'Noun'), ('길게', 'Adjective'), ('비춰주던', 'Verb'), ('할아버지', 'Noun'), ('와', 'Josa'), ('손녀', 'Noun'), ('가', 'Josa'), ('밥', 'Noun'), ('먹을', 'Verb'), ('때', 'Noun'), ('백', 'Modifier'), ('그', 'Modifier'), ('라운드', 'Noun'), ('에', 'Josa'), ('보', 'Noun'), ('이던', 'Josa'), ('옥자', 'Noun'), ('의', 'Josa'), ('얼굴', 'Noun'), ('과', 'Josa'), ('새끼', 'Noun'), ('돼지', 'Noun'), ('엉덩이', 'Noun'), ('가', 'Josa'), ('특히', 'Adverb'), ('인상', 'Noun'), ('적', 'Suffix'), ('이다', 'Josa'), ('.', 'Punctuation'), ('이', 'Noun'), ('정도', 'Noun'), ('의', 'Josa'), ('평화', 'Noun'), ('라면', 'Noun'), ('누구', 'Noun'), ('나', 'Josa'), ('다', 'Adverb'), ('수긍', 'Noun'), ('할만', 'Verb'), ('한', 'Determiner'), ('장면', 'Noun'), ('일터', 'Noun'), ('...', 'Punctuation'), ('솔직히', 'Adjective'), ('영화', 'Noun'), ('는', 'Josa'), ('썩', 'Noun'), ('재밌지는', 'Adjective'), ('않았지만', 'Verb'), ('깔끔한', 'Adjective'), ('영상', 'Noun'), ('과', 'Josa'), ('은은한', 'Adjective'), ('엔딩', 'Noun'), ('이', 'Josa'), ('나쁘지', 'Adjective'), ('않았다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign')], [('재밌게', 'Adjective'), ('봄', 'Noun'), ('\n', 'Foreign')], [('동물', 'Noun'), ('들', 'Suffix'), ('도', 'Josa'), ('인간', 'Noun'), ('과', 'Josa'), ('같은', 'Adjective'), ('감정', 'Noun'), ('이', 'Josa'), ('있긴', 'Adjective'), ('하다', 'Verb'), ('...', 'Punctuation'), ('군대', 'Noun'), ('때', 'Noun'), ('대대', 'Noun'), ('회식', 'Noun'), ('하는데', 'Verb'), ('생', 'Noun'), ('돼지', 'Noun'), ('2', 'Number'), ('마리', 'Noun'), ('를', 'Josa'), ('사서', 'Noun'), ('트럭', 'Noun'), ('에서', 'Josa'), ('내리려', 'Verb'), ('하는데', 'Verb'), ('죽어도', 'Verb'), ('안', 'VerbPrefix'), ('내리려', 'Verb'), ('하며', 'Verb'), ('눈물', 'Noun'), ('을', 'Josa'), ('뚝뚝', 'Noun'), ('흘리드', 'Noun'), ('라', 'Josa'), ('...', 'Punctuation'), ('마음', 'Noun'), ('이', 'Josa'), ('너무' ...
# 100
#
#
#
#
# [('영화', 31), ('옥자', 17), ('감독', 9), ('고기', 8), ('생각', 8), ('동물', 7), ('봉준호', 6), ('미자', 5), ('이', 5), ('장면', 5)]
