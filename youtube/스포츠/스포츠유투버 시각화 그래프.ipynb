# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm            # 폰트 지정방법
font_name=fm.FontProperties(fname='C:\\Windows\\Fonts\\malgun.ttf').get_name()     
plt.rc('font',family=font_name)


mpl.rcParams['axes.unicode_minus']=False

# %%
youtuber=pd.read_csv('C:\\Users\\acorn\\mywork\\pythonwork\\스포츠\\sports_sub.csv',encoding='cp949')

#youtuber=pd.read_csv('C:\\Users\\acorn\\mywork\\pythonwork\\스포츠\\sports_sub.csv')
youtuber.set_index('유투버',inplace=True)
youtuber=youtuber.sort_values(by='구독자수',ascending=False)
youtuber
# Out:
#                                 조회수합      조회수평균   댓글수합    댓글수평균    좋아요합  \
# 유투버
# 피지컬갤러리                      12770000  638500.00  28214  1410.70  160300
# Shoot for Love 슛포러브         11360000  568000.00  17852   892.60   82600
# 말왕TV                         8241000  412050.00  22754  1137.70   79600
# JK 아트사커 온라인                  4386000  219300.00  11079   553.95   46300
# 힙으뜸                          2689000  244454.55   3114   283.09   43154
# SomiFit                       819500   40975.00   1486    74.30   20166
# 석꾸축꾸                          452000   64571.43   3198   456.86    9976
# ROAD FIGHTING CHAMPIONSHIP    125803    6290.15    255    12.75     827
# 강하나스트레칭                      1553200   77660.00   2405   120.25   50532
# GoAle                        2733000  136650.00  18810   940.50   31226
# 꽁병지tv                         851900   42595.00   3905   195.25   11121
# 차도르                          2737000  248818.18   2435   221.36   15234
# ...

# %%
youtuber.to_csv('푸트유트버5.csv',encoding='utf-8')

# %%
youtuber['구독자수'].plot(kind='bar')
#data_result['소계'].plot.bar()
#data_result['소계'].plot(kind='bar',figsize=(10,5),grid=True)    #grid =눈금, figsize=그래프크기?

# %%
youtuber['구독자수'].plot(kind='barh',figsize=(10,5),grid=True)

# %%
youtuber['구독자수'].sort_values().plot(kind='barh',figsize=(10,5),grid=True)

# %% [markdown]
# ### 조회수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['조회수평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['조회수평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [9.76200964e-01 1.23221086e+06]
#
# 0.9762 x + 1.232e+06

# %%
fx=np.linspace(0,2500000,1000)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['조회수평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['조회수평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 댓글수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['댓글수평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['댓글수평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [2.60695833e+02 1.52771741e+06]
#
# 260.7 x + 1.528e+06

# %%
fx=np.linspace(0,4000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['댓글수평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['댓글수평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 좋아요평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['좋아요평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['좋아요평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [4.42635277e+01 1.24161750e+06]
#
# 44.26 x + 1.242e+06

# %%
fx=np.linspace(0,60000,1000)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['좋아요평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')                

plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['좋아요평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 싫어요평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['싫어요평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['싫어요평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [   1529.87357255 1282218.02271738]
#
# 1530 x + 1.282e+06

# %%
fx=np.linspace(0,2000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['싫어요평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['싫어요평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# ### 영상길이평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber['영상길이평균'],youtuber['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber['영상길이평균'],youtuber['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [-5.78163232e+02  2.21123166e+06]
#
# -578.2 x + 2.211e+06

# %%
fx=np.linspace(0,2000,100)

plt.figure(figsize=(8,8))
plt.scatter(youtuber['영상길이평균'],youtuber['구독자수'],s=60,c=youtuber['구독자수'])    


#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()
plt.colorbar()

for i in range(10):
    plt.text(youtuber['영상길이평균'][i],youtuber['구독자수'][i],youtuber.index[i],fontsize=11)

# %% [markdown]
# # 정규화

# %%
## Normalization (정규화) : MinMaxScaler() 

from sklearn import preprocessing         #sklearn 파이썬의 머신러닝 모듈

min_max_scaler = preprocessing.MinMaxScaler()

col1=['조회수평균','댓글수평균','좋아요평균','싫어요평균','영상길이평균','구독자수']
x=youtuber[col1].values
x


#정규화시키기        
x_scaled=min_max_scaler.fit_transform(x.astype(float))               #fit_transform 은 실수형태만 받는다. 
x_scaled
# Out:
# array([[1.00000000e+00, 8.19327485e-01, 1.00000000e+00, 7.24835610e-01,
#         1.58244140e-01, 1.00000000e+00],
#        [8.89112586e-01, 5.16345029e-01, 5.12770187e-01, 5.85483055e-01,
#         3.30745902e-01, 6.20253165e-01],
#        [6.43823335e-01, 6.59678363e-01, 4.93958225e-01, 5.11127972e-01,
#         2.11359089e-01, 3.62485616e-01],
#        [3.40652427e-01, 3.18304094e-01, 2.85145448e-01, 2.80475468e-01,
#         2.13967541e-01, 3.02071346e-01],
#        [3.80217292e-01, 1.59906433e-01, 4.86820967e-01, 2.23318159e-01,
#         4.01546726e-01, 2.80782509e-01],
#        [6.01701847e-02, 3.78070175e-02, 1.21268177e-01, 5.66514922e-02,
#         4.09658723e-01, 2.39355581e-01],
#        [9.72843279e-02, 2.61526316e-01, 1.73545365e-01, 2.78351037e-01,
#         0.00000000e+00, 1.86421174e-01],
#        [5.61538583e-03, 1.81286550e-03, 0.00000000e+00, 9.61052099e-03,
#         8.47202078e-02, 1.78365938e-01],
# ...

# %%
#정규화 시킨 후의 데이터프레임
youtuber2=pd.DataFrame(x_scaled,columns=col1,index=youtuber.index)
youtuber2
#youtuber2['구독자수']=youtuber['구독자수']
#youtuber2=youtuber2.round(3)
# Out:
#                                조회수평균     댓글수평균     좋아요평균     싫어요평균    영상길이평균  \
# 유투버
# 피지컬갤러리                      1.000000  0.819327  1.000000  0.724836  0.158244
# Shoot for Love 슛포러브         0.889113  0.516345  0.512770  0.585483  0.330746
# 말왕TV                        0.643823  0.659678  0.493958  0.511128  0.211359
# JK 아트사커 온라인                 0.340652  0.318304  0.285145  0.280475  0.213968
# 힙으뜸                         0.380217  0.159906  0.486821  0.223318  0.401547
# SomiFit                     0.060170  0.037807  0.121268  0.056651  0.409659
# 석꾸축꾸                        0.097284  0.261526  0.173545  0.278351  0.000000
# ROAD FIGHTING CHAMPIONSHIP  0.005615  0.001813  0.000000  0.009611  0.084720
# 강하나스트레칭                     0.117871  0.064678  0.311683  0.082195  0.483269
# GoAle                       0.210655  0.544357  0.190622  0.143905  0.266996
# 꽁병지tv                       0.062718  0.108538  0.064550  0.096864  0.137004
# ...

# %%
## 지금까지 내용을 파일로 저장
youtuber2.to_csv('스포츠유투버정규화.csv',encoding='utf-8',
                      sep=',')

# %%
sns.pairplot(youtuber2,vars=['구독자수','조회수평균','좋아요평균','댓글수평균'],size=4,kind='reg')   # kind='reg' -> 회귀선
# Out:
# C:\Users\acorn\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
## 구독자수와 조회수, 좋아요수와 댓글수에 대한 상관관계

sns.pairplot(youtuber2,x_vars=['구독자수','조회수평균'],
            y_vars=['댓글수평균','좋아요평균'])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(youtuber2[['조회수평균','댓글수평균','좋아요평균','싫어요평균','영상길이평균']],
           annot=True,fmt='f',cmap='RdPu',linewidths=5)             #annot=     fmt=숫자표시     camp =색     linewidths=테두리 

plt.title('스포츠유트브상관관계')
# Out:
# Text(0.5, 1, '스포츠유트브상관관계')

# %% [markdown]
# ### 영상길이평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['영상길이평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('영상길이평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber2['영상길이평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [-0.0950594   0.19125907]
#
# -0.09506 x + 0.1913

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['영상길이평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('영상길이평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('스포츠유튜버 영상길이와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['영상길이평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 조회수평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['조회수평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('조회수평균')
plt.ylabel('구독자수')
plt.grid()

# %%
fp1=np.polyfit(youtuber2['조회수평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.70581768 0.01571819]
#
# 0.7058 x + 0.01572

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['조회수평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('조회수평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('스포츠유튜버 조회수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['조회수평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 댓글수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['댓글수평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('댓글수평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['댓글수평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.49928652 0.06217284]
#
# 0.4993 x + 0.06217

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['댓글수평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('댓글수평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('스포츠유튜버 댓글수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['댓글수평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 좋아요수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['좋아요평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('좋아요평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['좋아요평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.71546787 0.01476299]
#
# 0.7155 x + 0.01476

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['좋아요평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('좋아요평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('스포츠유튜버 좋아요수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['좋아요평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')

# %% [markdown]
# ### 싫어요수 평균과 구독자수

# %%
plt.figure(figsize=(7,10))
plt.scatter(youtuber2['싫어요평균'],youtuber2['구독자수'],s=60)    #plt.scatter(x축,y축)    #  s= 점의 크기
plt.xlabel('싫어요평균')
plt.ylabel('구독자수')
plt.grid()

fp1=np.polyfit(youtuber2['싫어요평균'],youtuber2['구독자수'],1)
print(fp1)
f1=np.poly1d(fp1)
print(f1)
# Out:
# [0.53347711 0.05149779]
#
# 0.5335 x + 0.0515

# %%
fx=np.linspace(0,1)

plt.figure(figsize=(20,10))
plt.scatter(youtuber2['싫어요평균'],youtuber2['구독자수'],s=60,c=youtuber2['구독자수'])

#plt.plot(data_result['인구수'],f1(data_result['인구수']),lw=3,color='g',ls='dashed')
plt.plot(fx,f1(fx),lw=3,color='g',ls='dashed')             

plt.xlabel('싫어요평균',size=20)
plt.ylabel('구독자수',size=20)
plt.grid()
plt.colorbar()
plt.title('스포츠유튜버 싫어요수와 구독자수의 상관관계',size=30)
for i in range(5):
    plt.text(youtuber2['싫어요평균'][i],youtuber2['구독자수'][i],youtuber2.index[i],fontsize=12,fontweight='bold',horizontalalignment='right')
