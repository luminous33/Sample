# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt

# %%
comment_data = pd.read_csv('C:\\Users\\acorn\\Desktop\\Opensource\\Python\\Text Crawling\\아름송이\\comment/아름송이_comment_1.csv')

# %%
comment_data
# Out:
#     Unnamed: 0       youtube_id  \
# 0            0  areumsongee아름송이
# 1            1            XIANC
# 2            2         Twaddlex
# 3            3            risam
# 4            4         tasiyuso
# ..         ...              ...
# 76          76            tomoF
# 77          77             Miko
# 78          78              NaN
# 79          79              NaN
# 80          80              초코비
#
#                                               comment like_num
# 0   매그넘 루비는 CU, GS25, 마켓컬리에서 구매 할 수 있어요!!\n렌즈는 렌시스...      23개
# 1   I honestly can't understand how someone can be...       6개
# 2                               *당신은 너무 귀엽고 아름답습니다*🤍🤍       9개
# 3   いつもメイク動画楽しく見させてもらっていて、ほんとにソンイちゃんはいつ見ても綺麗で同じ女性と...      19개
# 4   ソンイちゃんのメイクとか参考にさせていただいてます！ほんと可愛くて大好きです！日本から応援さ...       9개
# ..                                                ...      ...
# 76                                             IloveU       1개
# 77                                         Enak pasti       1개
# 78                                            귀여워요💕💕💕       3개
# 79                          ほんとに可愛い、、使ってるコスメ全部欲しくなる🥺🥺       1개
# 80                                    아이스크림 광고받았나보네ㅋㅋ       0개
#
# [81 rows x 4 columns]

# %%
#이모티콘 제거
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

#분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~,".\n\r#\ufeff\u200d]')

# %%
comment_list = []
for i in range(len(comment_data)):
    comment_list.append(comment_data['comment'].iloc[i])

# %%
comment_result = []

for i in comment_list:
    tokens = re.sub(emoji_pattern,"",i)
    tokens = re.sub(han,"",tokens)
    comment_result.append(tokens)

comment_result = pd.DataFrame(comment_result, columns=["comment"])

# %%
comment_result
# Out:
#                                               comment
# 0   매그넘 루비는 CU GS25 마켓컬리에서 구매 할 수 있어요렌즈는 렌시스 신디 그레...
# 1   I honestly can't understand how someone can be...
# 2                               *당신은 너무 귀엽고 아름답습니다*🤍🤍
# 3   いつもメイク動画楽しく見させてもらっていて、ほんとにソンイちゃんはいつ見ても綺麗で同じ女性と...
# 4   ソンイちゃんのメイクとか参考にさせていただいてます！ほんと可愛くて大好きです！日本から応援さ...
# ..                                                ...
# 76                                             IloveU
# 77                                         Enak pasti
# 78                                               귀여워요
# 79                          ほんとに可愛い、、使ってるコスメ全部欲しくなる🥺🥺
# 80                                      아이스크림 광고받았나보네
#
# [81 rows x 1 columns]

# %% [markdown]
# # 형태소 분석기를 통한 명사 추출

# %%
#한글 형태소 분석기인 konlpy사용 
#이때 konlpy에는 hannanum, kommoran, kkma, twitter이 있는데 해당 분석에서는 kkma사용
from konlpy.tag import Kkma
from konlpy.tag import Mecab
from konlpy.tag import Twitter
#apply lambda사용

# %%
from konlpy.tag import Twitter

def get_noun(comment_txt):
    twitter = Twitter()
    noun = []
    
    if len(comment_txt)>0:
        tw = twitter.pos(comment_txt)
        for i,j in tw:
            if j == 'Noun':
                noun.append(i)
    return noun
 
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
# Out:
# D:\anaconda31\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
# Out:
# D:\anaconda31\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
comment_result
# Out:
#                                                comment  \
# 0    우리 리를 레이리스 앤 제늘맨
# 제가 드디어 MBTI 성격 유형 검사라는 걸 해봤어요...
# 1    타임라인❤(틀린게 있으면 말해주세요고칠께요)0:07:인사❤및 오프닝0:11:마스크로...
# 2                        오늘 완젼 아리아나그란데 재질…사배아나그란데 사랑해요
# 3                           메이크업 무슨일이야 언니가 너무 예뻐서 집중안됨
# 4    메포 픽서 진짜 분무기 같아서 비추 (얼굴도 좀 가려운 느낌) 복합성 수부지 민감성...
# 5    진짜 제 마음 속의 뷰튜버 원탑 중간에 픽서 뿌리실 때 입자 더 잘 보이라고 배경 ...
# 6    헐 이날 메이크업 너무 예뻐요 저거 흰색라인 저거 나도 따라해보고 싶어요 영상 만들...
# 7        꺄 언니 오늘 메컵 넘예쁜거 아님니꽈 오늘메이크업 가능하면 투툐리얼로 보고싶어요오
# 8                                   헤어스타일 어케 하신거에요이쁘시당
# 9                         언니 어반디케이 픽서 언니의 지겹템은 어디간거에요오
# 10   여러분 이 영상 보시고 나서 당장 리얼리사배 채널에 올라온 MBTI 영상 보러 달려...
# 11              와 메이크업 역대급 너무 예뻐서 울어요 진짜이 메이크업 해주세요 엉엉
# 12   뷰티관련 영상 예전에 너무 많이 봐서 나한테 맞는제품도 안정적이게 구비되어 있고 필...
# 13   오늘 징짜 너무 예뻐요혹시 아이들의 소연여자친구 신비청하레벨 슬기가 부른 wow t...
# 14   메포 픽서들이 다 분사력이 별로라 잘 안 쓰게 되더라구요 완전 침분사 구입하실 분들...
# 15         분사할때 어두운 배경지로 바꿔주는 정성 이래서 갓사배 갓사배 합니다 ♥ ♥ ♥
# 16                                      와 진짜 필요한 영상이었다
# 17   저렇게 픽서도 뿌리고 파우더까지 하면 마스크에 코부분 쓸려도 안 벗겨지나요 파우더만...
# 18                       쏘내추럴 픽서 저거 효과 1도 없재구매는 안할거같아요
# 19                                  언니 오늘 약간 예지+선미 같아후
# 20   언니 오늘 하이틴 드라마에 나오는 여주같아요나무 상큼하고 예쁘네여 영상도 잘보고 가...
# 21                      오늘 언니 메이크업 정말 최고에요  화이트아이라인 최고
# 22   헉 사배언니  오늘영상 에서 하신 메이크업 자세히 보고싶어요 포니테일과 이 메이크업...
# 23   진짜 메이크업 너무 예뻐요눈에 별 박힌거같아눈 맨날 번져서 고민이었는데 많은 도움되었어요
# 24              저렴이 위주로도 소개해주셨으면 좋겠어요  고렴이들 뿐이여서 아쉽네요
# 25   영상에서 하신 메이크업 보고 싶어요  사배언니 너무 예쁘셔외국에서 열심히 응원하고 ...
# 26   우와 진짜 지금 너무 딱 필요한 컨텐츠 픽서 사러 바로 갑니다아아아앙 MBTI 보러...
# 27                                    역쉬 언니는 내 맴을 잘 알어
# 28       언니 오늘 메컵 올려주는 거죠 그쳐  아 사랑행 ❤️❤️❤️❤️❤️❤️❤️❤️❤️
# 29                           오늘도 많이 알아 갑니다 썸네일부터 넘 이뻐요
# ..                                                 ...
# 110                                 3:36 언니 입에 안 들어갔어요
# 111  언니 아리아나 이번에 레이디 가가랑 같이 노래낸 뮤비속 메이크업 해주세요 진짜찰떡일...
# 112  언니 저는 베이스 후에 파우더로 한번 고정하고 아이메이크업 등 모든 메이크업 끝내고...
# 113                           언니 정리 너무 잘됐어요 머리에 완전 쏙쏙
# 114                  사배 언니 진짜 너무 예뻐요 언니 퍼스널 컬러 뭔지 아세요
# 115  정말 안그래도 이것때문에 요즘 완전 고민이였는데 이 영상으로 한번에 해결됐어요 감사합니당
# 116                                      Hey Beautiful
# 117                                         사베사렁 헌다  ♡
# 118  참고해서 구매해야겠어요 언니  저는 복합성인지 수부지인지 잘 모르겠지만 픽서랑 파우...
# 119  건성인데 파우더로 수정하면 너무 건조하지않을까요 수정으로 화사해보이고 다시 처음 메...
# 120                               사베님 오늘 엄청 시원시원해 보여요♥
# 121                      픽서꿀팁이라니 넘넘 필요했어요 시기적절 사배언니 쵝오
# 122                                  사배언니이쁘시다 메이크업잘하심
# 123                             헤어 메이크업 다  완벽해요넘 이뻐서
# 124                     이사배님의 인사로 갑자기 꼬마아가씨가 된 낼모레 마흔
# 125                                  머리 너무 이쁘게 묶으셨어요 ♥
# 126  언니 근데 혹시 비슷하지만 가격 저렴한 제품 추천 없어요 지금 디오 사고 싶으면 땅...
# 127  메이크업 포에버 파우더 다써가지구 새로 사야하는데 면세점에서 샀던거라 정가주고 사려...
# 128                    언니 앞니라인이 정갈해진거 같아요 라미네이트 하신건가요🤔
# 129                                              헐청하인줄
# 130                        파우더 제품 넘 비싸요  저렴한 제품으로는 없나요
# 131  더운 날씨에 마스크 안 써도 T존에 기름이 나는데 학생이라서 마스크 하루종일 쓰느라...
# 132                                   언니 항상 좋은 영상 감사해요
# 133                       볼수록 너무 이쁘다 너무이뻐서 언니 얼굴밖에 안보여
# 134                                             역시 갓사배
# 135  픽서 뿌리면 아무래도 클렌징을 더 꼼꼼히 해야하나요 아니면  그냥 클렌징 티슈로 닦...
# 136                                  진짜또박또박 발음좋으시다전달력갑
# 137                               이제 어반디케이 픽서는 한물갔나여88
# 138                          디올 루스 파우더는 어떻게 사용하면 되는건가요
# 139                              사배 언니가 또 다시 나의 지갑을 연다
#
#                                                  token
# 0    [우리, 리, 레이, 리스, 앤, 늘맨, 제, 성격, 유형, 검사, 걸, 오오, 결...
# 1    [타임, 라인, 말, 인사, 및, 오프닝, 마스크, 메이크업, 추천, 픽, 파우더,...
# 2                     [오늘, 완젼, 아리아나, 데, 재질, 배아, 데, 사랑]
# 3                                   [메이크업, 일이, 언니, 집중]
# 4    [메포, 픽, 진짜, 분무기, 얼굴, 좀, 느낌, 복합, 부지, 민감, 투쿨, 포스...
# 5    [진짜, 제, 마음, 속, 뷰튜버, 탑, 중간, 픽, 때, 입자, 더, 보이, 배경...
# 6                      [날, 메이크업, 거, 흰색, 라인, 거, 영상, 여름]
# 7                [꺄, 언니, 오늘, 메컵, 꽈, 오늘, 메이크업, 투툐리얼, 오]
# 8                                          [헤어스타일, 어케]
# 9                        [언니, 어, 디케이, 픽, 언니, 템, 어디, 오]
# 10   [여러분, 이, 영상, 보시, 당장, 리얼리, 사배, 채널, 영상, 그, 영상, 안...
# 11                            [메이크업, 역대, 진짜, 메이크업, 엉엉]
# 12   [뷰티, 관련, 영상, 예전, 나, 제품, 안정, 게, 구비, 정보, 시국, 물욕,...
# 13   [오늘, 징, 혹시, 아이, 소연, 여자친구, 신비, 청, 레벨, 슬기, 오늘, 약...
# 14          [메포, 픽서들, 분사, 별로, 안, 완전, 침, 분사, 구입, 분, 참고]
# 15                  [분사, 때, 어, 두운, 배경, 지로, 정성, 사배, 사배]
# 16                                            [진짜, 영상]
# 17               [픽서, 뿌리, 파우더, 마스크, 코, 부분, 안, 파우더, 화장]
# 18                              [내추럴, 픽, 거, 효과, 도, 구매]
# 19                             [언니, 오늘, 약간, 예지, 선미, 후]
# 20   [언니, 오늘, 하이, 틴, 드라마, 여주, 나무, 상큼, 여, 영상, 가요, 마침...
# 21               [오늘, 언니, 메이크업, 정말, 최고, 화이트, 아이라인, 최고]
# 22           [사배, 오늘, 영상, 메이크업, 포니테일, 이, 메이크업, 여름, 찰떡]
# 23                      [진짜, 메이크업, 눈, 별, 눈, 번, 고민, 도움]
# 24                                  [저렴, 위주, 도, 소개, 이]
# 25                  [영상, 메이크업, 보고, 사배, 외국, 응원, 사랑, 언니]
# 26                                [진짜, 지금, 컨텐츠, 픽, 바로]
# 27                                      [역쉬, 언니, 내, 맴]
# 28                              [언니, 오늘, 메컵, 거, 사랑, 행]
# 29                                        [오늘, 알, 썸네일]
# ..                                                 ...
# 110                                         [언니, 입, 안]
# 111   [언니, 아리아나, 이번, 레이디, 가가, 노래, 뮤비, 속, 메이크업, 진짜, 찰떡]
# 112  [언니, 저, 베이스, 후, 파우더, 한번, 고정, 아이, 메이크업, 등, 모든, ...
# 113                               [언니, 정리, 머리, 완전, 쏙쏙]
# 114                        [사배, 언니, 진짜, 언니, 퍼스, 널, 컬러]
# 115             [정말, 것, 때문, 요즘, 완전, 고민, 이, 영상, 한번, 해결]
# 116                                                 []
# 117                                            [베사, 렁]
# 118  [참고, 구매, 언니, 저, 복합, 부지, 픽서, 파우더, 후, 시간, 금방, 번,...
# 119  [건성, 파우더, 수정, 수정, 화사, 다시, 처음, 메이크업, 뭐, 제일, 꼭, ...
# 120                                            [베, 오늘]
# 121                             [픽서꿀팁, 시기, 적절, 사배, 쵝오]
# 122                                      [사배, 메이크업, 심]
# 123                                         [헤어, 메이크업]
# 124                 [이사배, 인사, 갑자기, 꼬마, 아가씨, 낼, 모레, 마흔]
# 125                                               [머리]
# 126         [언니, 혹시, 가격, 제품, 추천, 지금, 디오, 사고, 땅, 삽질, 중]
# 127      [메이크업, 포에버, 파우더, 면세점, 정가, 사려, 눈데, 그냥, 이걸루, 오]
# 128                            [언니, 앞니, 라인, 라미, 트, 가요]
# 129                                             [청, 줄]
# 130                                      [파우더, 제품, 제품]
# 131  [날씨, 마스크, 안, 존, 기름, 학생, 마스크, 하루, 종일, 마스크, 존, 땀...
# 132                                       [언니, 항상, 영상]
# 133                                       [언니, 얼굴, 안보]
# 134                                           [역시, 사배]
# 135     [픽, 뿌리, 클렌징, 더, 클렌징, 티슈, 폼클렌징, 세안, 비누, 세수, 해도]
# 136                              [진짜, 또박또박, 발음, 전달, 갑]
# 137                                   [이제, 어, 디케이, 픽서]
# 138                              [디올, 루스, 파우더, 사용, 가요]
# 139                          [사배, 언니, 또, 다시, 나, 지갑, 연]
#
# [140 rows x 2 columns]

# %% [markdown]
# # wordcloud 란?
# - 자연어처리(NLP)시에 doc에서 언급된 단어들의 빈도수를 파악해서 빈도수가 높은 단어일 수록 크게 빈도수가 낮은 단어일 수록 작게 표현하는 시각화 기법.

# %%
from collections import Counter
from wordcloud import WordCloud
#import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np

# %%
noun_list = []
for i in range(len(comment_result)):
    for j in range(len(comment_result['token'].iloc[i])):
        noun_list.append(comment_result['token'].iloc[i][j])

# %%
counts = Counter(noun_list)
tags = counts.most_common(30)

# %%
tags = counts.most_common(30)

# %%
#bar chart
test = pd.DataFrame({'word':[],
                    'count':[]})
for i in range(len(tags)):
    word = tags[i][0]
    count = tags[i][1]
    
    insert_data = pd.DataFrame({'word':[word],
                                'count':[count]})
    test = test.append(insert_data)

test.index = range(len(test))

# %%
index = np.arange(len(test))
plt.bar(index,test['count'].tolist() )
plt.xlabel('word', fontsize=5)
plt.ylabel('count', fontsize=5)
plt.xticks(index, test['word'].tolist(), fontsize=5, rotation=30)
plt.title('단어 빈도수 시각화')
plt.show()

# %%
wc = WordCloud(font_path='NanumGothic.ttf',background_color='white', width=800, height=600)

print(dict(tags))
cloud = wc.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# {'파우더': 58, '언니': 50, '메이크업': 47, '영상': 40, '사배': 38, '오늘': 33, '픽': 30, '픽서': 23, '추천': 21, '진짜': 19, '더': 15, '화장': 15, '때': 14, '제품': 14, '사용': 13, '경우': 12, '고정': 12, '때문': 12, '수정': 11, '것': 11, '이': 10, '혹시': 10, '부분': 9, '후': 9, '요즘': 9, '제': 8, '마스크': 8, '베이스': 8, '미스트': 8, '수': 8}
