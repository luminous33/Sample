# %%
import requests # 웹 페이지 소스를 얻기 위한 패키지(기본 내장 패키지이다.)
from bs4 import BeautifulSoup # 웹 페이지 소스를 얻기 위한 패키지, 더 간단히 얻을 수 있다는 장점이 있다고 한다.
from datetime import datetime                                # (!pip install beautifulsoup4 으로 다운받을 수 있다.)
import pandas as pd # 데이터를 처리하기 위한 가장 기본적인 패키지
import time # 사이트를 불러올 때, 작업 지연시간을 지정해주기 위한 패키지이다. (사이트가 늦게 켜지면 에러가 발생하기 때문)
import urllib.request #
from selenium.webdriver import Chrome
import json
import re     
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import datetime as dt
import os
import glob
from pandas import DataFrame

# %%
#폴더명 입력해주기
youtube_channel = input("유투브 채널 이름 입력하시오.")
path =  str(youtube_channel) + "/comment"
path2 = str(youtube_channel) + '\\result.csv'
arg_youtube = str(youtube_channel) + "*"


allFile_list = glob.glob(os.path.join(path,arg_youtube))
print(allFile_list)
allData = []
for file in allFile_list:
    df = pd.read_csv(file)
    allData.append(df)
    
dataCombine = pd.concat(allData,axis =0, ignore_index = True)

dataCombine.to_csv(path2, index = False)
# Out:
# 유투브 채널 이름 입력하시오.producerdk
# ['producerdk/comment\\producerdk_comment_1.csv', 'producerdk/comment\\producerdk_comment_10.csv', 'producerdk/comment\\producerdk_comment_2.csv', 'producerdk/comment\\producerdk_comment_3.csv', 'producerdk/comment\\producerdk_comment_4.csv', 'producerdk/comment\\producerdk_comment_5.csv', 'producerdk/comment\\producerdk_comment_6.csv', 'producerdk/comment\\producerdk_comment_7.csv', 'producerdk/comment\\producerdk_comment_8.csv', 'producerdk/comment\\producerdk_comment_9.csv']

# %%
cdPath = str(youtube_channel) + '/result.csv'
comment_data = pd.read_csv(cdPath)

# %%
comment_data
# Out:
#       Unnamed: 0       youtube_id  \
# 0              0       kimhuynmin
# 1              1          별빛숲Mage
# 2              2           peitho
# 3              3     bestzealot01
# 4              4        SukwonKim
# 5              5        SurkiSohn
# 6              6              염경민
# 7              7              김동근
# 8              8       JohnnyPark
# 9              9               수라
# 10            10         SEOKJUNA
# 11            11             Styx
# 12            12         asdfadsf
# 13            13               블루
# 14            14           hiharu
# 15            15              박진우
# 16            16       ChanilPark
# 17            17             Styx
# 18            18       CrazioChae
# 19            19              이우람
# 20            20              이포링
# 21            21              김태성
# 22            22  McCartneyLennon
# 23            23              이수형
# 24            24              김지훈
# 25            25        IkhyunKim
# 26            26              사마진
# 27            27         SmithKim
# 28            28             나비아빠
# 29            29              연체어
# ...          ...              ...
# 1233         130              김민규
# 1234         131           MARCOK
# 1235         132          별빛숲Mage
# 1236         133       guesungkim
# 1237         134           NDMoon
# 1238         135       JohnnyPark
# 1239         136              박세현
# 1240         137          NODREAM
# 1241         138      SungtackLim
# 1242         139              쉬는날
# 1243         140        Rainsurte
# 1244         141       HellowKick
# 1245         142             SeeL
# 1246         143             노박노박
# 1247         144        kiyongAhn
# 1248         145             까망별빛
# 1249         146           Gessen
# 1250         147           KenLee
# 1251         148               둔둔
# 1252         149              전상윤
# 1253         150              Cho
# 1254         151              정환이
# 1255         152        pigonhama
# 1256         153           청학동서당개
# 1257         154           ANALOG
# 1258         155          SOLOIST
# 1259         156            nKras
# 1260         157           어쿠스틱멜로
# 1261         158        LeeSeHwan
# 1262         159              최수겸
#
#                                                 comment like_num
# 0        한줄 요약 : 솔로 남성들이 20대후반 30대초반 여성들에게 선물용으로 사는 스피커       9개
# 1          asmr마이크를 아주 전문적으로 엔지니어(겸 저울)가 세팅하는 유튭채널 캬...       6개
# 2                                허허.. 선물할 이성이 없으니 패스입니다       5개
# 3     19:11 40만원 짜린데 주려다 실패했다는게 너무 슬프네요 ㅠㅠ (내 이야기 아님...       5개
# 4                                      내 돈 주고.... ㅋㅋㅋㅋㅋ       3개
# 5                       캠브리지 오디오의 블루투스 스피커 리뷰도 부탁드려요...       2개
# 6                         저도 마샬 stand more 사고 후회 했는데 ㅜㅠ       1개
# 7                         숲형님...\r\n 마지막 멘트는 너무 슬퍼요..ㅜㅠ       0개
# 8                                    08:08 회장님 오랜만이에요 🙋       0개
# 9     40만짜리가.. 149불이면... 살만..... 하긴 하네요 ㅎㅎ 3DIO 마이크가...       1개
# 10                               v-moda remix 도 리뷰해주세요!       0개
# 11    카카오 이어폰에 이어서 BT21 블루투스 이어폰도 있던데... 과연 그 이어폰으로 ...       0개
# 12                                 이미 액톤2를 질러서 패스해야 겠네요       1개
# 13                           특별한 용도라고 해서 이상한거 상상했다. . .       2개
# 14                                      이숲님에 선물 드려야 ㅎㅎㅎ       0개
# 15                                                   ㅋㅋ       0개
# 16                               이숲님 사용한 헤드폰은.. 예고편인가요?       0개
# 17                                            "고백용 스피커"       1개
# 18                                          마샬 흑우에디션 ㅋㅋ       0개
# 19                                      역시 믿거 마샬인가요....       1개
# 20                                  기타 앰프처럼 보이긴 합니다. ㅋㅋ       0개
# 21                                영상 중간에 하얀옷을 입은 선녀님이?!       0개
# 22                                 액톤 써서 안지를듯 ㅋ 막상 안씀 ㅠ       0개
# 23                  솔직히 저런 스피커나 앰프보면 알파벳 알아보기 힘듬....ㅋㅋㅋ       0개
# 24    스톡웰 1을 쓰고있는데 소리가 좋습니다. ㅎㅎ\r\n2가 1보다 좋지 않은 모양이네...       0개
# 25    마샬 껍데기에 팬더를 넣으면 제일 좋은가요? ㅋㅋㅋ 아이스크림이 오늘은 오래동안 재...       0개
# 26                                               2등인가..       0개
# 27                                                 2:22       0개
# 28                                             기습 영상이네요       0개
# 29                                              용도의 발견!       0개
# ...                                                 ...      ...
# 1233  슈어는 유선과 무선 모두 음질이 동일합니다.\r\n이숲님의 손저울은 전자저울과 측정...       1개
# 1234  왜 전....슈어라기 보단 화면을 멀리서 보면  MDR~~~~???  제 눈이 이상...       0개
# 1235  안녕하세요 저울이 숲\r\n\r\n저도 소니 좋아해서 엘덱 잘 쓰는데\r\n특유의 ...       0개
# 1236                                     린 클라이막스 지원하나요?       0개
# 1237                    썸네일의 dk님 모습은 텅장인데 영상본 나의 모습이었다.       0개
# 1238  예판 받는거 웹페이지 가보니까 갈색 배색도 이쁘네요\r\nLDAC는 음질은 우월한데...       0개
# 1239                        Campfire 제품들 리뷰 부탁드려도 될까용?ㅠ       0개
# 1240  50만원보다 330g이 더 무시무시한 충격이다 ㅎㄷㄷ ... 고기를 얼마나 드시면 ...       0개
# 1241     근데 무선헤드폰 궁굼한게 있는데요 베터리 교환이 돼나요 ? 그게 제일궁굼했음 전부터       0개
# 1242               다음 자기소개에 엔지니어 말고 인간저울이라고 소개하셔도...ㅋㅋㅋ       0개
# 1243            중저가형 사운드바도 추천좀 해주세요~~ 아니면 사운드바 단점이라도좀 ㅎ       0개
# 1244           슈어 1540 + dk799 조합으로 듣는데 날것+날것으로 듣는 난 뭐지       0개
# 1245                       음질은 소니 wh1000xm3보다 얼마나 좋은가요?       1개
# 1246                          저기다 탬버린을 넣고 다니면 좋을것 같습니다.       0개
# 1247                      이 제품 야금 야금 정식 출시가 조금씩 미루어지네요.       0개
# 1248  두 분이 리뷰한 것은 아니지만 dk님께서 리뷰하신 헤드폰 중 모비우스가 ldac가 ...       0개
# 1249  가격과 브랜드 성향을 생각해보니 베이어다이나믹 라군이 생각나네요.\r\n그리고 이숲...       0개
# 1250             조이콘 하우징 방법과 산 곳 어딘지 궁금합니다.( 닌텐도 화이트 편)       0개
# 1251                                      그래서 공구 언제하시죠?       0개
# 1252  이 리뷰만 기다렸습니다. 그리고 보자마자 몇달을 주저하던 결정을 단번에 내렸습니다....       0개
# 1253                  리플 한번 쓱 보고 네이버찜하고 방송 끝까지 보기를 잘했네.       0개
# 1254  DK님 리뷰 잘보았습니다 다름이 아니라 제가 운전할때 MDR-1000X 를 사용하며...       0개
# 1255                                 저울의 명가 주식회사 숲.....       0개
# 1256                                  라군이랑 비교해서는 어떨까요??       0개
# 1257                               가격이 비싸..? 그럼 공구해야 읍읍       0개
# 1258                                           이건 가져야겠당       0개
# 1259                  이쯤되면 이숲님 별자리가 천칭좌가 아닐까 하는 궁금증이...       0개
# 1260                  완충된 상태에서 음악을 들었을 때 사용시간이 얼마나 되나요?       0개
# 1261  괜찮다. 나는 TH909가 있다. 가격도 알아보고 사는 곳도 알아보는데 절대 안 살거다.       0개
# 1262                10:49 강도가 쎄지않아서 다행이네요 쎄면 경찰 불러야함..ㅋ       1개
#
# [1263 rows x 4 columns]

# %%
#이모티콘 제거
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)

#분석에 어긋나는 불용어구 제외 (특수문자, 의성어)
han = re.compile(r'[ㄱ-ㅎㅏ-ㅣ!?~,".\n\r#\ufeff\u200d]')

# %%
comment_list = []
for i in range(len(comment_data)):
    comment_list.append(comment_data['comment'].iloc[i])

# %%
comment_result = []

for i in comment_list:
    tokens = re.sub(emoji_pattern,"",i)
    tokens = re.sub(han,"",tokens)
    comment_result.append(tokens)

comment_result = pd.DataFrame(comment_result, columns=["comment"])

# %%
comment_result
# Out:
#                                                 comment
# 0        한줄 요약 : 솔로 남성들이 20대후반 30대초반 여성들에게 선물용으로 사는 스피커
# 1             asmr마이크를 아주 전문적으로 엔지니어(겸 저울)가 세팅하는 유튭채널 캬
# 2                                  허허 선물할 이성이 없으니 패스입니다
# 3     19:11 40만원 짜린데 주려다 실패했다는게 너무 슬프네요  (내 이야기 아님 아...
# 4                                               내 돈 주고
# 5                          캠브리지 오디오의 블루투스 스피커 리뷰도 부탁드려요
# 6                           저도 마샬 stand more 사고 후회 했는데
# 7                                    숲형님 마지막 멘트는 너무 슬퍼요
# 8                                     08:08 회장님 오랜만이에요
# 9            40만짜리가 149불이면 살만 하긴 하네요  3DIO 마이크가 도움이 되네요
# 10                                v-moda remix 도 리뷰해주세요
# 11    카카오 이어폰에 이어서 BT21 블루투스 이어폰도 있던데 과연 그 이어폰으로 BTS...
# 12                                 이미 액톤2를 질러서 패스해야 겠네요
# 13                              특별한 용도라고 해서 이상한거 상상했다
# 14                                         이숲님에 선물 드려야
# 15
# 16                                  이숲님 사용한 헤드폰은 예고편인가요
# 17                                              고백용 스피커
# 18                                            마샬 흑우에디션
# 19                                          역시 믿거 마샬인가요
# 20                                     기타 앰프처럼 보이긴 합니다
# 21                                  영상 중간에 하얀옷을 입은 선녀님이
# 22                                   액톤 써서 안지를듯  막상 안씀
# 23                         솔직히 저런 스피커나 앰프보면 알파벳 알아보기 힘듬
# 24    스톡웰 1을 쓰고있는데 소리가 좋습니다 2가 1보다 좋지 않은 모양이네요 1이랑 비...
# 25     마샬 껍데기에 팬더를 넣으면 제일 좋은가요  아이스크림이 오늘은 오래동안 재생되었군요
# 26                                                 2등인가
# 27                                                 2:22
# 28                                             기습 영상이네요
# 29                                               용도의 발견
# ...                                                 ...
# 1233  슈어는 유선과 무선 모두 음질이 동일합니다이숲님의 손저울은 전자저울과 측정치가 동일합니다
# 1234          왜 전슈어라기 보단 화면을 멀리서 보면  MDR  제 눈이 이상한가 봅니다
# 1235  안녕하세요 저울이 숲저도 소니 좋아해서 엘덱 잘 쓰는데특유의 버퍼링 등 연결 문제는...
# 1236                                      린 클라이막스 지원하나요
# 1237                     썸네일의 dk님 모습은 텅장인데 영상본 나의 모습이었다
# 1238  예판 받는거 웹페이지 가보니까 갈색 배색도 이쁘네요LDAC는 음질은 우월한데 연결성...
# 1239                          Campfire 제품들 리뷰 부탁드려도 될까용
# 1240  50만원보다 330g이 더 무시무시한 충격이다   고기를 얼마나 드시면 저걸 근의 ...
# 1241      근데 무선헤드폰 궁굼한게 있는데요 베터리 교환이 돼나요  그게 제일궁굼했음 전부터
# 1242                     다음 자기소개에 엔지니어 말고 인간저울이라고 소개하셔도
# 1243               중저가형 사운드바도 추천좀 해주세요 아니면 사운드바 단점이라도좀
# 1244           슈어 1540 + dk799 조합으로 듣는데 날것+날것으로 듣는 난 뭐지
# 1245                        음질은 소니 wh1000xm3보다 얼마나 좋은가요
# 1246                           저기다 탬버린을 넣고 다니면 좋을것 같습니다
# 1247                       이 제품 야금 야금 정식 출시가 조금씩 미루어지네요
# 1248  두 분이 리뷰한 것은 아니지만 dk님께서 리뷰하신 헤드폰 중 모비우스가 ldac가 ...
# 1249  가격과 브랜드 성향을 생각해보니 베이어다이나믹 라군이 생각나네요그리고 이숲님 이번엔...
# 1250              조이콘 하우징 방법과 산 곳 어딘지 궁금합니다( 닌텐도 화이트 편)
# 1251                                       그래서 공구 언제하시죠
# 1252  이 리뷰만 기다렸습니다 그리고 보자마자 몇달을 주저하던 결정을 단번에 내렸습니다 소...
# 1253                   리플 한번 쓱 보고 네이버찜하고 방송 끝까지 보기를 잘했네
# 1254  DK님 리뷰 잘보았습니다 다름이 아니라 제가 운전할때 MDR-1000X 를 사용하며...
# 1255                                      저울의 명가 주식회사 숲
# 1256                                    라군이랑 비교해서는 어떨까요
# 1257                                  가격이 비싸 그럼 공구해야 읍읍
# 1258                                           이건 가져야겠당
# 1259                     이쯤되면 이숲님 별자리가 천칭좌가 아닐까 하는 궁금증이
# 1260                   완충된 상태에서 음악을 들었을 때 사용시간이 얼마나 되나요
# 1261     괜찮다 나는 TH909가 있다 가격도 알아보고 사는 곳도 알아보는데 절대 안 살거다
# 1262                   10:49 강도가 쎄지않아서 다행이네요 쎄면 경찰 불러야함
#
# [1263 rows x 1 columns]

# %%
#한글 형태소 분석기인 konlpy사용 
#이때 konlpy에는 hannanum, kommoran, kkma, twitter이 있는데 해당 분석에서는 kkma사용
from konlpy.tag import Kkma
from konlpy.tag import Mecab
from konlpy.tag import Twitter
#apply lambda사용

# %%
from konlpy.tag import Twitter

def get_noun(comment_txt):
    twitter = Twitter()
    noun = []
    
    if len(comment_txt)>0:
        tw = twitter.pos(comment_txt)
        for i,j in tw:
            if j == 'Noun':
                noun.append(i)
    return noun
 
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
# Out:
# D:\anaconda31\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
comment_result['token'] = comment_result['comment'].apply(lambda x: get_noun(x))
# Out:
# D:\anaconda31\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
comment_result
# Out:
#                                                 comment  \
# 0        한줄 요약 : 솔로 남성들이 20대후반 30대초반 여성들에게 선물용으로 사는 스피커
# 1             asmr마이크를 아주 전문적으로 엔지니어(겸 저울)가 세팅하는 유튭채널 캬
# 2                                  허허 선물할 이성이 없으니 패스입니다
# 3     19:11 40만원 짜린데 주려다 실패했다는게 너무 슬프네요  (내 이야기 아님 아...
# 4                                               내 돈 주고
# 5                          캠브리지 오디오의 블루투스 스피커 리뷰도 부탁드려요
# 6                           저도 마샬 stand more 사고 후회 했는데
# 7                                    숲형님 마지막 멘트는 너무 슬퍼요
# 8                                     08:08 회장님 오랜만이에요
# 9            40만짜리가 149불이면 살만 하긴 하네요  3DIO 마이크가 도움이 되네요
# 10                                v-moda remix 도 리뷰해주세요
# 11    카카오 이어폰에 이어서 BT21 블루투스 이어폰도 있던데 과연 그 이어폰으로 BTS...
# 12                                 이미 액톤2를 질러서 패스해야 겠네요
# 13                              특별한 용도라고 해서 이상한거 상상했다
# 14                                         이숲님에 선물 드려야
# 15
# 16                                  이숲님 사용한 헤드폰은 예고편인가요
# 17                                              고백용 스피커
# 18                                            마샬 흑우에디션
# 19                                          역시 믿거 마샬인가요
# 20                                     기타 앰프처럼 보이긴 합니다
# 21                                  영상 중간에 하얀옷을 입은 선녀님이
# 22                                   액톤 써서 안지를듯  막상 안씀
# 23                         솔직히 저런 스피커나 앰프보면 알파벳 알아보기 힘듬
# 24    스톡웰 1을 쓰고있는데 소리가 좋습니다 2가 1보다 좋지 않은 모양이네요 1이랑 비...
# 25     마샬 껍데기에 팬더를 넣으면 제일 좋은가요  아이스크림이 오늘은 오래동안 재생되었군요
# 26                                                 2등인가
# 27                                                 2:22
# 28                                             기습 영상이네요
# 29                                               용도의 발견
# ...                                                 ...
# 1233  슈어는 유선과 무선 모두 음질이 동일합니다이숲님의 손저울은 전자저울과 측정치가 동일합니다
# 1234          왜 전슈어라기 보단 화면을 멀리서 보면  MDR  제 눈이 이상한가 봅니다
# 1235  안녕하세요 저울이 숲저도 소니 좋아해서 엘덱 잘 쓰는데특유의 버퍼링 등 연결 문제는...
# 1236                                      린 클라이막스 지원하나요
# 1237                     썸네일의 dk님 모습은 텅장인데 영상본 나의 모습이었다
# 1238  예판 받는거 웹페이지 가보니까 갈색 배색도 이쁘네요LDAC는 음질은 우월한데 연결성...
# 1239                          Campfire 제품들 리뷰 부탁드려도 될까용
# 1240  50만원보다 330g이 더 무시무시한 충격이다   고기를 얼마나 드시면 저걸 근의 ...
# 1241      근데 무선헤드폰 궁굼한게 있는데요 베터리 교환이 돼나요  그게 제일궁굼했음 전부터
# 1242                     다음 자기소개에 엔지니어 말고 인간저울이라고 소개하셔도
# 1243               중저가형 사운드바도 추천좀 해주세요 아니면 사운드바 단점이라도좀
# 1244           슈어 1540 + dk799 조합으로 듣는데 날것+날것으로 듣는 난 뭐지
# 1245                        음질은 소니 wh1000xm3보다 얼마나 좋은가요
# 1246                           저기다 탬버린을 넣고 다니면 좋을것 같습니다
# 1247                       이 제품 야금 야금 정식 출시가 조금씩 미루어지네요
# 1248  두 분이 리뷰한 것은 아니지만 dk님께서 리뷰하신 헤드폰 중 모비우스가 ldac가 ...
# 1249  가격과 브랜드 성향을 생각해보니 베이어다이나믹 라군이 생각나네요그리고 이숲님 이번엔...
# 1250              조이콘 하우징 방법과 산 곳 어딘지 궁금합니다( 닌텐도 화이트 편)
# 1251                                       그래서 공구 언제하시죠
# 1252  이 리뷰만 기다렸습니다 그리고 보자마자 몇달을 주저하던 결정을 단번에 내렸습니다 소...
# 1253                   리플 한번 쓱 보고 네이버찜하고 방송 끝까지 보기를 잘했네
# 1254  DK님 리뷰 잘보았습니다 다름이 아니라 제가 운전할때 MDR-1000X 를 사용하며...
# 1255                                      저울의 명가 주식회사 숲
# 1256                                    라군이랑 비교해서는 어떨까요
# 1257                                  가격이 비싸 그럼 공구해야 읍읍
# 1258                                           이건 가져야겠당
# 1259                     이쯤되면 이숲님 별자리가 천칭좌가 아닐까 하는 궁금증이
# 1260                   완충된 상태에서 음악을 들었을 때 사용시간이 얼마나 되나요
# 1261     괜찮다 나는 TH909가 있다 가격도 알아보고 사는 곳도 알아보는데 절대 안 살거다
# 1262                   10:49 강도가 쎄지않아서 다행이네요 쎄면 경찰 불러야함
#
#                                                   token
# 0               [줄, 요약, 솔로, 남성, 후반, 초반, 여성, 선물, 용, 스피커]
# 1              [마이크, 아주, 전문, 엔지니어, 겸, 저울, 팅, 유튭, 채널, 캬]
# 2                                          [선물, 이성, 패스]
# 3                                          [린데, 내, 이야기]
# 4                                                [내, 돈]
# 5                            [캠브리지, 오디오, 블루투스, 스피커, 리뷰]
# 6                                       [저, 마샬, 사고, 후회]
# 7                                      [숲, 형님, 마지막, 멘트]
# 8                                              [회장, 만이]
# 9                                          [살, 마이크, 도움]
# 10                                              [도, 리뷰]
# 11    [카카오, 이어폰, 블루투스, 이어폰, 과연, 그, 이어폰, 노래, 때, 저, 소리...
# 12                                          [액톤, 를, 패스]
# 13                                             [용도, 상상]
# 14                                              [숲, 선물]
# 15                                                   []
# 16                                    [숲, 사용, 헤드폰, 예고편]
# 17                                         [고백, 용, 스피커]
# 18                                      [마샬, 흑우, 에디, 션]
# 19                                             [역시, 마샬]
# 20                                             [기타, 앰프]
# 21                                      [영상, 중간, 옷, 선녀]
# 22                                             [액톤, 막상]
# 23                                   [저런, 스피커, 앰프, 알파벳]
# 24         [스톡, 웰, 소리, 모양, 요, 비교, 더, 생각, 영상, 날, 질병, 사람]
# 25                 [마샬, 껍데기, 팬더, 제일, 아이스크림, 오늘, 동안, 재생]
# 26                                                   []
# 27                                                   []
# 28                                             [기습, 상이]
# 29                                             [용도, 발견]
# ...                                                 ...
# 1233     [슈어, 유선, 무선, 모두, 음질, 숲, 손, 저울, 전자, 저울, 측정, 치가]
# 1234                               [왜, 슈, 화면, 멀리, 제, 눈]
# 1235  [저울, 숲, 도, 소니, 엘덱, 특, 유의, 버퍼링, 등, 연결, 문제, 정말, ...
# 1236                                   [린, 막스, 지원, 하나요]
# 1237                            [썸네일, 모습, 텅, 영상, 나, 모습]
# 1238  [판, 웹페이지, 가보, 갈색, 배색, 음질, 연결, 문제, 라이센스, 문제, 생태...
# 1239                                        [제품, 리뷰, 용]
# 1240                      [이, 더, 충격, 고기, 얼마나, 저걸, 의, 감]
# 1241                 [무선, 헤드폰, 궁굼한, 베터리, 교환, 그게, 궁굼, 전]
# 1242                     [다음, 자기, 소개, 엔지니어, 인간, 저울, 소개]
# 1243              [중, 가형, 사운드, 바, 추천, 좀, 사운드, 바, 단점, 좀]
# 1244                                     [슈어, 조합, 난, 뭐]
# 1245                                      [음질, 소니, 얼마나]
# 1246                                          [저기, 탬버린]
# 1247                            [이, 제품, 야금, 야금, 정식, 출시]
# 1248  [두, 분, 리뷰, 것, 님, 리뷰, 헤드폰, 중, 모비우스, 지원, 폰, 동시, ...
# 1249      [가격, 브랜드, 성향, 생각, 베이어, 다이나믹, 군, 숲, 이번, 오차, 엌]
# 1250                 [이콘, 징, 방법, 산, 곳, 어딘, 닌텐도, 화이트, 편]
# 1251                                           [공구, 언제]
# 1252                    [이, 리뷰, 달, 주저, 결정, 단번, 소득공제, 수]
# 1253                 [리플, 한번, 쓱, 보고, 네이버, 찜, 방송, 끝, 보기]
# 1254      [리뷰, 제, 운전, 때, 를, 사용, 통화, 음악, 통화, 음질, 대비, 가요]
# 1255                                  [저울, 명가, 주식회사, 숲]
# 1256                                         [군, 비교, 요]
# 1257                                       [가격, 공구, 읍읍]
# 1258                                               [이건]
# 1259                           [이쯤, 숲, 별자리, 천칭, 좌, 궁금증]
# 1260                       [완충, 상태, 음악, 때, 사용, 시간, 얼마나]
# 1261                                 [나, 가격, 곳도, 절대, 안]
# 1262                                    [강도, 다행, 요, 경찰]
#
# [1263 rows x 2 columns]

# %%
pd_Path = str(youtube_channel) +'/token_result.csv'
comment_result.to_csv(pd_Path, index = False)

# %%
pd_testPath = str(youtube_channel) +'/token_result.csv'
pdtest = pd.read_csv(pd_testPath)

# %%
pdtest
# Out:
#                                                 comment  \
# 0        한줄 요약 : 솔로 남성들이 20대후반 30대초반 여성들에게 선물용으로 사는 스피커
# 1             asmr마이크를 아주 전문적으로 엔지니어(겸 저울)가 세팅하는 유튭채널 캬
# 2                                  허허 선물할 이성이 없으니 패스입니다
# 3     19:11 40만원 짜린데 주려다 실패했다는게 너무 슬프네요  (내 이야기 아님 아...
# 4                                               내 돈 주고
# 5                          캠브리지 오디오의 블루투스 스피커 리뷰도 부탁드려요
# 6                           저도 마샬 stand more 사고 후회 했는데
# 7                                    숲형님 마지막 멘트는 너무 슬퍼요
# 8                                     08:08 회장님 오랜만이에요
# 9            40만짜리가 149불이면 살만 하긴 하네요  3DIO 마이크가 도움이 되네요
# 10                                v-moda remix 도 리뷰해주세요
# 11    카카오 이어폰에 이어서 BT21 블루투스 이어폰도 있던데 과연 그 이어폰으로 BTS...
# 12                                 이미 액톤2를 질러서 패스해야 겠네요
# 13                              특별한 용도라고 해서 이상한거 상상했다
# 14                                         이숲님에 선물 드려야
# 15                                                  NaN
# 16                                  이숲님 사용한 헤드폰은 예고편인가요
# 17                                              고백용 스피커
# 18                                            마샬 흑우에디션
# 19                                          역시 믿거 마샬인가요
# 20                                     기타 앰프처럼 보이긴 합니다
# 21                                  영상 중간에 하얀옷을 입은 선녀님이
# 22                                   액톤 써서 안지를듯  막상 안씀
# 23                         솔직히 저런 스피커나 앰프보면 알파벳 알아보기 힘듬
# 24    스톡웰 1을 쓰고있는데 소리가 좋습니다 2가 1보다 좋지 않은 모양이네요 1이랑 비...
# 25     마샬 껍데기에 팬더를 넣으면 제일 좋은가요  아이스크림이 오늘은 오래동안 재생되었군요
# 26                                                 2등인가
# 27                                                 2:22
# 28                                             기습 영상이네요
# 29                                               용도의 발견
# ...                                                 ...
# 1233  슈어는 유선과 무선 모두 음질이 동일합니다이숲님의 손저울은 전자저울과 측정치가 동일합니다
# 1234          왜 전슈어라기 보단 화면을 멀리서 보면  MDR  제 눈이 이상한가 봅니다
# 1235  안녕하세요 저울이 숲저도 소니 좋아해서 엘덱 잘 쓰는데특유의 버퍼링 등 연결 문제는...
# 1236                                      린 클라이막스 지원하나요
# 1237                     썸네일의 dk님 모습은 텅장인데 영상본 나의 모습이었다
# 1238  예판 받는거 웹페이지 가보니까 갈색 배색도 이쁘네요LDAC는 음질은 우월한데 연결성...
# 1239                          Campfire 제품들 리뷰 부탁드려도 될까용
# 1240  50만원보다 330g이 더 무시무시한 충격이다   고기를 얼마나 드시면 저걸 근의 ...
# 1241      근데 무선헤드폰 궁굼한게 있는데요 베터리 교환이 돼나요  그게 제일궁굼했음 전부터
# 1242                     다음 자기소개에 엔지니어 말고 인간저울이라고 소개하셔도
# 1243               중저가형 사운드바도 추천좀 해주세요 아니면 사운드바 단점이라도좀
# 1244           슈어 1540 + dk799 조합으로 듣는데 날것+날것으로 듣는 난 뭐지
# 1245                        음질은 소니 wh1000xm3보다 얼마나 좋은가요
# 1246                           저기다 탬버린을 넣고 다니면 좋을것 같습니다
# 1247                       이 제품 야금 야금 정식 출시가 조금씩 미루어지네요
# 1248  두 분이 리뷰한 것은 아니지만 dk님께서 리뷰하신 헤드폰 중 모비우스가 ldac가 ...
# 1249  가격과 브랜드 성향을 생각해보니 베이어다이나믹 라군이 생각나네요그리고 이숲님 이번엔...
# 1250              조이콘 하우징 방법과 산 곳 어딘지 궁금합니다( 닌텐도 화이트 편)
# 1251                                       그래서 공구 언제하시죠
# 1252  이 리뷰만 기다렸습니다 그리고 보자마자 몇달을 주저하던 결정을 단번에 내렸습니다 소...
# 1253                   리플 한번 쓱 보고 네이버찜하고 방송 끝까지 보기를 잘했네
# 1254  DK님 리뷰 잘보았습니다 다름이 아니라 제가 운전할때 MDR-1000X 를 사용하며...
# 1255                                      저울의 명가 주식회사 숲
# 1256                                    라군이랑 비교해서는 어떨까요
# 1257                                  가격이 비싸 그럼 공구해야 읍읍
# 1258                                           이건 가져야겠당
# 1259                     이쯤되면 이숲님 별자리가 천칭좌가 아닐까 하는 궁금증이
# 1260                   완충된 상태에서 음악을 들었을 때 사용시간이 얼마나 되나요
# 1261     괜찮다 나는 TH909가 있다 가격도 알아보고 사는 곳도 알아보는데 절대 안 살거다
# 1262                   10:49 강도가 쎄지않아서 다행이네요 쎄면 경찰 불러야함
#
#                                                   token
# 0     ['줄', '요약', '솔로', '남성', '후반', '초반', '여성', '선물'...
# 1     ['마이크', '아주', '전문', '엔지니어', '겸', '저울', '팅', '유...
# 2                                    ['선물', '이성', '패스']
# 3                                    ['린데', '내', '이야기']
# 4                                            ['내', '돈']
# 5                  ['캠브리지', '오디오', '블루투스', '스피커', '리뷰']
# 6                               ['저', '마샬', '사고', '후회']
# 7                              ['숲', '형님', '마지막', '멘트']
# 8                                          ['회장', '만이']
# 9                                    ['살', '마이크', '도움']
# 10                                          ['도', '리뷰']
# 11    ['카카오', '이어폰', '블루투스', '이어폰', '과연', '그', '이어폰'...
# 12                                    ['액톤', '를', '패스']
# 13                                         ['용도', '상상']
# 14                                          ['숲', '선물']
# 15                                                   []
# 16                            ['숲', '사용', '헤드폰', '예고편']
# 17                                   ['고백', '용', '스피커']
# 18                              ['마샬', '흑우', '에디', '션']
# 19                                         ['역시', '마샬']
# 20                                         ['기타', '앰프']
# 21                              ['영상', '중간', '옷', '선녀']
# 22                                         ['액톤', '막상']
# 23                           ['저런', '스피커', '앰프', '알파벳']
# 24    ['스톡', '웰', '소리', '모양', '요', '비교', '더', '생각', ...
# 25    ['마샬', '껍데기', '팬더', '제일', '아이스크림', '오늘', '동안',...
# 26                                                   []
# 27                                                   []
# 28                                         ['기습', '상이']
# 29                                         ['용도', '발견']
# ...                                                 ...
# 1233  ['슈어', '유선', '무선', '모두', '음질', '숲', '손', '저울',...
# 1234                   ['왜', '슈', '화면', '멀리', '제', '눈']
# 1235  ['저울', '숲', '도', '소니', '엘덱', '특', '유의', '버퍼링',...
# 1236                           ['린', '막스', '지원', '하나요']
# 1237                ['썸네일', '모습', '텅', '영상', '나', '모습']
# 1238  ['판', '웹페이지', '가보', '갈색', '배색', '음질', '연결', '문...
# 1239                                  ['제품', '리뷰', '용']
# 1240      ['이', '더', '충격', '고기', '얼마나', '저걸', '의', '감']
# 1241  ['무선', '헤드폰', '궁굼한', '베터리', '교환', '그게', '궁굼', ...
# 1242       ['다음', '자기', '소개', '엔지니어', '인간', '저울', '소개']
# 1243  ['중', '가형', '사운드', '바', '추천', '좀', '사운드', '바',...
# 1244                             ['슈어', '조합', '난', '뭐']
# 1245                                ['음질', '소니', '얼마나']
# 1246                                      ['저기', '탬버린']
# 1247                ['이', '제품', '야금', '야금', '정식', '출시']
# 1248  ['두', '분', '리뷰', '것', '님', '리뷰', '헤드폰', '중', '...
# 1249  ['가격', '브랜드', '성향', '생각', '베이어', '다이나믹', '군', ...
# 1250  ['이콘', '징', '방법', '산', '곳', '어딘', '닌텐도', '화이트'...
# 1251                                       ['공구', '언제']
# 1252    ['이', '리뷰', '달', '주저', '결정', '단번', '소득공제', '수']
# 1253  ['리플', '한번', '쓱', '보고', '네이버', '찜', '방송', '끝',...
# 1254  ['리뷰', '제', '운전', '때', '를', '사용', '통화', '음악', ...
# 1255                          ['저울', '명가', '주식회사', '숲']
# 1256                                   ['군', '비교', '요']
# 1257                                 ['가격', '공구', '읍읍']
# 1258                                             ['이건']
# 1259               ['이쯤', '숲', '별자리', '천칭', '좌', '궁금증']
# 1260         ['완충', '상태', '음악', '때', '사용', '시간', '얼마나']
# 1261                       ['나', '가격', '곳도', '절대', '안']
# 1262                            ['강도', '다행', '요', '경찰']
#
# [1263 rows x 2 columns]
